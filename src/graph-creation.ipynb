# %% [markdown]
# # Data Preparation

# %% [markdown]
# This notebook connects to the Neo4J Workspace and creates the corresponding objects for Stops and Schools with the given properties in the json-files. Running this notebook takes around 1 hour.

# %% [markdown]
# ## Paths + Imports

# %%
from neomodel import db, config
from credentials import Credentials
from models import *
import json, csv

# %%
stops_paths = "../data/haltestellen-wien.json"
schools_paths = "../data/schulen-wien.json"
lines_paths = '../data/haltestellen-linien.csv'

with open(stops_paths, 'r') as file:
    stops_data = json.load(file)

with open(schools_paths, 'r') as file:
    schools_data = json.load(file)

# %%
config.DATABASE_URL = Credentials.getNeo4JDatabaseURI()

# %% [markdown]
# ## Insert data into Graph DB

# %% [markdown]
# ### Remove and clean data if it exists

# %%
def clear_neo4j_database():
    db.cypher_query('MATCH (n) DETACH DELETE n')

def clear_class_registry():
    db._NODE_CLASS_REGISTRY.clear()

clear_neo4j_database()
clear_class_registry()

# %% [markdown]
# ### Populate the graph with school data

# %%
def populate_schools(schools_data):
    count = 1
    for feature in schools_data['features']:
        print(f"running instance {count}..")
        count = count+1
        properties = feature['properties']
        geometry = feature['geometry']['coordinates']

        school_node = School.nodes.get_or_none(school_id=feature['id'])
        if not school_node:
            school_node = School(
                school_id=feature['id'],
                address=properties['ADRESSE'],
                type=str(properties['ART']),
                type_text=properties.get('ART_TXT'),
                care=properties.get('BETREUUNG'),
                phone=properties.get('TELEFON'),
                website=properties.get('WEBLINK1'),
                location_latitude=geometry[1], 
                location_longitude=geometry[0],
                name=properties['NAME']
            ).save()
            print(f"School {school_node.name} ADDED.")
        else:
            print(f"School with ID {school_node.name} ALREADY EXISTED.\n")

# %%
populate_schools(schools_data)
# Out:
# running instance 1..
# School GRg 3 Kundmanngasse 20-22 added.
# running instance 2..
# School VS Kolonitzgasse 15 added.
# running instance 3..
# School SPR Landstraßer Hauptstraße 146 added.
# running instance 4..
# School SPR Landstraßer Hauptstraße 146 added.
# running instance 5..
# School GRg 3 Hagenmüllergasse 30 added.
# running instance 6..
# School PMS Erdbergstraße 70 added.
# running instance 7..
# School VS Petrusgasse 10 added.
# running instance 8..
# School PNMS Schützengasse 31 added.
# running instance 9..
# School VS Reisnerstraße 43 added.
# running instance 10..
# School PMS Fasangasse 4 added.
# running instance 11..
# School pRgORg 3 Schützengasse 31 added.
# running instance 12..
# School ORg 3 Ballsportgymnasium Wien added.
# running instance 13..
# School PVS Apostelgasse 5 added.
# running instance 14..
# School PVS Rennweg 31 added.
# running instance 15..
# School PVS Sebastianplatz 3 added.
# running instance 16..
# School GTVS Landstraßer Hauptstraße 146 added.
# running instance 17..
# School Saudische Schule in Wien des Königreichs Saudi-Arabien added.
# running instance 18..
# School VS 3 Otto Preminger Straße 1 added.
# running instance 19..
# School Handelsakademie und Handelsschule Marienanstalt - Sacré Coeur der Schulstiftung Erzdiözese Wien added.
# running instance 20..
# School Schule für Sozialbetreuungsberufe des AWZ soziales Wien GmbH added.
# running instance 21..
# School Höhere Lehranstalt für wirtschaftliche Berufe des Schulvereins der Schulschwestern added.
# running instance 22..
# School Camillo Sitte Bautechnikum, Höhere Technische Bundeslehr- und Versuchsanstalt added.
# running instance 23..
# School Bundeshandelsakademie und Bundeshandelsschule und Höhere Technische Bundeslehranstalt Schulzentrum Ungargasse Wien 3 added.
# running instance 24..
# School Bundeshandelsakademie und Bundeshandelsschule und Höhere Technische Bundeslehranstalt Schulzentrum Ungargasse Wien 3 added.
# running instance 25..
# School Wiener Musikakademie der EWADA HandelsgmbH added.
# running instance 26..
# School Höhere Technische Bundeslehranstalt Wien 3 Rennweg added.
# running instance 27..
# School Musikinstitut Polyhymnia des Herrn Mag. Friedrich Trinbacher added.
# running instance 28..
# School Musikinstitut Polyhymnia des Herrn Mag. Friedrich Trinbacher added.
# running instance 29..
# School BSH Bundesschüler/innen-Wohnheim Juchgasse added.
# running instance 30..
# School VS Sankt-Elisabeth-Platz 8 added.
# running instance 31..
# School GTMS Schäffergasse 3 added.
# running instance 32..
# School NMS Schäffergasse 3 added.
# running instance 33..
# School VS Phorusgasse 4 added.
# running instance 34..
# School PPTS Karlsplatz 14 added.
# running instance 35..
# School Rg 4 Waltergasse 7 added.
# running instance 36..
# School VS Waltergasse 16 added.
# running instance 37..
# School PWMS Karlsplatz 14 added.
# running instance 38..
# School GRg 4 Wiedner Gürtel 68 added.
# running instance 39..
# School PVS Karlsplatz 14 added.
# running instance 40..
# School PVS Wiedner Hauptstraße 82 added.
# running instance 41..
# School PVS  Favoritenstraße 15 added.
# running instance 42..
# School Technisch-Gewerbliche Abendschule des bfi Wien - Werkmeisterschule added.
# running instance 43..
# School Prayner Konservatorium des Herrn Mag. Josef Schmid added.
# running instance 44..
# School VS Einsiedlergasse 7 added.
# running instance 45..
# School ASO Diehlgasse 2 added.
# running instance 46..
# School GRg 5 Reinprechtsdorfer Straße 24 added.
# running instance 47..
# School VS Gassergasse 46 added.
# running instance 48..
# School MS Gassergasse 44 added.
# running instance 49..
# School Berufsschule für Verwaltungsberufe added.
# running instance 50..
# School GRg 5 Rainergasse 39 added.
# running instance 51..
# School VS Pannaschgasse 6 added.
# running instance 52..
# School MS Viktor-Christ-Gasse 24 added.
# running instance 53..
# School NMS Viktor-Christ-Gasse 24 added.
# running instance 54..
# School VS Stolberggasse 53 added.
# running instance 55..
# School Höhere Bundeslehr- und Versuchsanstalt für Textilindustrie und Informatik added.
# running instance 56..
# School Schulen des BFI Wien, Kolleg der Handelsakademie für Berufstätige added.
# running instance 57..
# School ASO Spalowskygasse 5 added.
# running instance 58..
# School VS Corneliusgasse 6 added.
# running instance 59..
# School PMS Liniengasse 21 added.
# running instance 60..
# School SES Mittelgasse 24 added.
# running instance 61..
# School SES Mittelgasse 24 added.
# running instance 62..
# School GRg 6 Rahlgasse 4 added.
# running instance 63..
# School VS Sonnenuhrgasse 3 added.
# running instance 64..
# School GRg 6 Amerlingstraße 6 added.
# running instance 65..
# School PVS Lutherplatz 1 added.
# running instance 66..
# School PVS Liniengasse 21 added.
# running instance 67..
# School Berufsschule für Elektrotechnik und Mechatronik added.
# running instance 68..
# School Privatschule der Islamischen Republik Iran added.
# running instance 69..
# School Berufsschule für Sanitär-, Heizungs- und Klimatechnik added.
# running instance 70..
# School Berufsschule für Metalltechnik, Glasbautechnik und Technische Zeichner added.
# running instance 71..
# School Berufsschule für Informationstechnik added.
# running instance 72..
# School Berufsschule für Elektro-, Veranstaltungs- und Informationstechnik Austria added.
# running instance 73..
# School VS Neustiftgasse 98-102 added.
# running instance 74..
# School MS Neubaugasse 42 added.
# running instance 75..
# School PPTS Kenyongasse 4-12 added.
# running instance 76..
# School VS Stiftgasse 35 added.
# running instance 77..
# School PTS Burggasse 14-16 added.
# running instance 78..
# School Berufsschule für Maschinen-, Fertigungstechnik und Elektronik added.
# running instance 79..
# School GRg 7 Kandlgasse 39 added.
# running instance 80..
# School VS Zieglergasse 21 added.
# running instance 81..
# School pGRg 7 Kenyongasse 4-12 added.
# running instance 82..
# School PVS Burggasse 37 added.
# running instance 83..
# School PVS Kenyongasse 4-12 added.
# running instance 84..
# School PMS Kenyongasse 4-12 added.
# running instance 85..
# School RgORg 7 Neustiftgasse 95-99 added.
# running instance 86..
# School Islamische Fachschule für soziale Bildung - Dr. A.K. Hammerschmidt der Islamischen Religionsgemeinde Wien added.
# running instance 87..
# School Konservatorium Sunrise_Studios des Herrn Mike Loewenrosen added.
# running instance 88..
# School Private Bildungsanstalt für Sozialpädagogik - Kolleg für Sozialpädagogik für Berufstätige der MERA Bildungsholding GmbH Schottenfeldgasse 69 added.
# running instance 89..
# School BAFEP 7 Kenyongasse 4-12 added.
# running instance 90..
# School VS Lange Gasse 36 added.
# running instance 91..
# School VS Pfeilgasse 42b added.
# running instance 92..
# School VS Zeltgasse 7 added.
# running instance 93..
# School GRg 8 Albertgasse 18-22 added.
# running instance 94..
# School PVS  Piaristengasse 43 added.
# running instance 95..
# School Rg 8 Feldgasse 6-8 added.
# running instance 96..
# School Vienna Business School -  Handelsakademie und Handelsschule Hamerlingplatz der Wiener Kaufmannschaft added.
# running instance 97..
# School Vienna Business School -  Handelsakademie und Handelsschule Schönborngasse der Wiener Kaufmannschaft added.
# running instance 98..
# School BAFEP 8 Lange Gasse 47 + Albertgasse 38 added.
# running instance 99..
# School Mayflower Christian Academy - Primar des Vereins MCA added.
# running instance 100..
# School VS Rudolf Friemel-Gasse 3 added.
# running instance 101..
# School PVS Gudrunstraße 11 added.
# running instance 102..
# School VS Hlawkagasse 2 added.
# running instance 103..
# School Lernwerkstatt Sowiedu added.
# running instance 104..
# School Höhere Technische Bundeslehranstalt Wien 10 added.
# running instance 105..
# School GTVS Grundäckergasse 14 added.
# running instance 106..
# School Bundeshandelsakademie und Bundeshandelsschule Wien 10 added.
# running instance 107..
# School VS Landgutgasse 30 - Bildungscampus Innerfavoriten added.
# running instance 108..
# School Höhere Bundeslehranstalt für wirtschaftliche Berufe Wien 10 added.
# running instance 109..
# School Schule für Sozialbetreuungsberufe added.
# running instance 110..
# School BAFEP 10 Ettenreichgasse 45c added.
# running instance 111..
# School VS Braunhubergasse 3 added.
# running instance 112..
# School MS Enkplatz 4/II added.
# running instance 113..
# School ASO Herderplatz 1A added.
# running instance 114..
# School GRg 11 Gottschalkgasse 21 added.
# running instance 115..
# School Expos. der HS 1110, Enkplatz 4/I added.
# running instance 116..
# School SES Hoefftgasse 7 added.
# running instance 117..
# School SES Hoefftgasse 7 added.
# running instance 118..
# School VS Hertha Firnbergstraße 12 added.
# running instance 119..
# School SES Hoefftgasse 7 added.
# running instance 120..
# School SES Hoefftgasse 7 added.
# running instance 121..
# School Private "Bildungsanstalt für Sozialpädagogik - Kolleg für Berufstätige" des Vereins die "bildungsakademie, Verein für Durchlässigkeit und soziale Gerechtigkeit in der Bildung added.
# running instance 122..
# School VS Galileigasse 5 added.
# running instance 123..
# School SES Galileigasse 3 added.
# running instance 124..
# School SES Galileigasse 3 added.
# running instance 125..
# School SES Galileigasse 3 added.
# running instance 126..
# School GRg 9 Wasagasse 10 added.
# running instance 127..
# School VS Gilgegasse 12 added.
# running instance 128..
# School Rg 9 Glasergasse 25 added.
# running instance 129..
# School VS Grünentorgasse 9 added.
# running instance 130..
# School SchülerInnenschule und Werkcollege Währinger Straße 59 added.
# running instance 131..
# School Lycée Liechtensteinstraße 37a Francais de Vienne added.
# running instance 132..
# School VS Marktgasse 31 added.
# running instance 133..
# School PVS Liechtensteinstraße 37a added.
# running instance 134..
# School Schulkollektiv Währinger Straße 59 added.
# running instance 135..
# School Höhere Bundeslehranstalt für Mode und für wirtschaftliche Berufe Wien 9 added.
# running instance 136..
# School Fachschule der Stadt Wien für wirtschaftliche Berufe added.
# running instance 137..
# School Caritas Ausbildungszentrum für Sozialberufe added.
# running instance 138..
# School VS Ada-Christen-Gasse 9 added.
# running instance 139..
# School ASO Quellenstraße 52 added.
# running instance 140..
# School GRG 10 Ettenreichgasse 41-43 added.
# running instance 141..
# School VS Alxingergasse 82 added.
# running instance 142..
# School MS Georg-Wilhelm-Pabst-Gasse 2a added.
# running instance 143..
# School ASO Hebbelplatz 2 added.
# running instance 144..
# School pGRg 10 Ludwig-von-Höhnel-Gasse 17-19 added.
# running instance 145..
# School VS Quellenstraße 142 added.
# running instance 146..
# School Praxis-MS Grenzackerstraße 18 added.
# running instance 147..
# School PTS Pernerstorfergasse 30-32 added.
# running instance 148..
# School PTS Pernerstorfergasse 30-32 added.
# running instance 149..
# School GRg 10 Laaer Berg-Straße 25-29 added.
# running instance 150..
# School MS Herzgasse 27 added.
# running instance 151..
# School GRg 10 Pichelmayergasse 1 added.
# running instance 152..
# School VS Carl-Prohaska-Platz 1 added.
# running instance 153..
# School VS Georg-Wilhelm-Pabst-Gasse 2 added.
# running instance 154..
# School VS Hebbelplatz 1 added.
# running instance 155..
# School VS Herzgasse 87 added.
# running instance 156..
# School VS Jagdgasse 22 added.
# running instance 157..
# School MS Leibnizgasse 33 added.
# running instance 158..
# School VS Jagdgasse 23 added.
# running instance 159..
# School VS Keplerplatz 7 added.
# running instance 160..
# School VS Klausenburger Straße 25 added.
# running instance 161..
# School PMS Ludwig v. Höhnel-Gasse 17-19 added.
# running instance 162..
# School VS Laaer-Berg-Straße 170 added.
# running instance 163..
# School VS Laimäckergasse 17 added.
# running instance 164..
# School VS Oberlaaer Platz 1 added.
# running instance 165..
# School VS Quellenstraße 54 added.
# running instance 166..
# School VS Selma-Lagerlöf-Gasse 20 added.
# running instance 167..
# School PNMS Gudrunstraße 11 added.
# running instance 168..
# School MS Gudrunstraße 110 added.
# running instance 169..
# School Praxis-VS Grenzackerstraße 18 added.
# running instance 170..
# School MS Quellenstraße 144 added.
# running instance 171..
# School PVS Alxingergasse 8 added.
# running instance 172..
# School PVS Ludwig-von-Höhnel Gasse 17-19 added.
# running instance 173..
# School VS Wendstattgasse 3 added.
# running instance 174..
# School MS Landgutgasse 30 - Bildungscampus Innerfavoriten added.
# running instance 175..
# School PVS Quellenstraße 87 added.
# running instance 176..
# School PVS Quellenstraße 87 added.
# running instance 177..
# School VS Neilreichgasse 111 added.
# running instance 178..
# School VS Tesarekplatz 4 added.
# running instance 179..
# School ALF-Schule (Aktives Lernen Favoriten) added.
# running instance 180..
# School VS Knöllgasse 59 added.
# running instance 181..
# School VS Maria-Rekker-Gasse 3 added.
# running instance 182..
# School VS Börsegasse 5 added.
# running instance 183..
# School MS Renngasse 20 added.
# running instance 184..
# School AkG Beethovenplatz 1 added.
# running instance 185..
# School VS Stubenbastei 3 added.
# running instance 186..
# School pG 1 Freyung 6 added.
# running instance 187..
# School PVS Judenplatz 6 added.
# running instance 188..
# School Rg 1 Schottenbastei 7-9 added.
# running instance 189..
# School GRg 1 Stubenbastei 6-8 added.
# running instance 190..
# School ORg 1/H 14  Hegelgasse 14 added.
# running instance 191..
# School Montessori-Schule Wien 1 im Heiligenkreuzerhof Grashofgasse 3/7/22 added.
# running instance 192..
# School ORg 1/H 12 Hegelgasse 12 added.
# running instance 193..
# School Vienna Business School - Handelsakademie und Handelsschule Akademiestraße der Wiener Kaufmannschaft added.
# running instance 194..
# School Gastgewerbefachschule des Schulvereins der Wiener Gastwirte added.
# running instance 195..
# School Schauspielschule Krauss added.
# running instance 196..
# School Diözesankonservatorium für Kirchenmusik der Erzdiözese Wien added.
# running instance 197..
# School VS Aspernallee 5 added.
# running instance 198..
# School RgORg 2 Lessinggasse 14 added.
# running instance 199..
# School VS Czerninplatz 3 added.
# running instance 200..
# School MS Feuerbachstraße 1 added.
# running instance 201..
# School ASO Holzhausergasse 5-7 added.
# running instance 202..
# School GRg 2 Wohlmutstraße 3 added.
# running instance 203..
# School VS Darwingasse 14 added.
# running instance 204..
# School SSB Leopoldsgasse 3 added.
# running instance 205..
# School GRg 2 Zirkusgasse 48 added.
# running instance 206..
# School GRg 2 Kleine Sperlgasse 4 added.
# running instance 207..
# School VS Kleine Sperlgasse 2A added.
# running instance 208..
# School MS Obere Augartenstraße 38 added.
# running instance 209..
# School BBI Wittelsbachstraße 5 added.
# running instance 210..
# School pRg 2 Simon-Wiesenthal-Gasse 3 added.
# running instance 211..
# School MS Pazmanitengasse 26 added.
# running instance 212..
# School FIT - Fachspezifische Schule für individualisierte Teilausbildungen für Jugendliche und junge Erwachsene mit Behinderungen/Benachteiligungen der ITA gem. GmbH added.
# running instance 213..
# School VS Novaragasse 30 added.
# running instance 214..
# School I-FIT - Inklusive Fachspezifische Schule für Individualisierte Teilausbildungen für Jugendliche und junge Erwachsene mit Ausgrenzungsgefährdung und Behinderungen/Benachteiligungen des Evang.Schulwerks A.B. Wien" added.
# running instance 215..
# School VS Schönngasse 2 added.
# running instance 216..
# School PMS Obere Augartenstraße 34 added.
# running instance 217..
# School pORg 2 Rabbiner-Schneerson-Platz 1 added.
# running instance 218..
# School VS Vereinsgasse 29-31 added.
# running instance 219..
# School PMS Malzgasse 16 added.
# running instance 220..
# School VS Vorgartenstraße 191 added.
# running instance 221..
# School VS Wittelsbachstraße 6 added.
# running instance 222..
# School PMS Rabbiner Schneerson-Platz 1 added.
# running instance 223..
# School VS Wolfgang-Schmälzl-Gasse 13 added.
# running instance 224..
# School PMS Große Stadtgutgasse 24 added.
# running instance 225..
# School PVS Leopoldsgasse 1A added.
# running instance 226..
# School Mittelschule "Campus" Christine Nöstlinger added.
# running instance 227..
# School VS Vorgartenstraße 208 added.
# running instance 228..
# School VS Ernst-Melchior-Gasse 9 added.
# running instance 229..
# School PVS Malzgasse 16 added.
# running instance 230..
# School PVS Obere Augartenstraße 1 added.
# running instance 231..
# School PVS Simon-Wiesenthal-Gasse 3 added.
# running instance 232..
# School PVS Rabbiner Schneersonplatz 1 added.
# running instance 233..
# School PVS Nepomukgasse 2 added.
# running instance 234..
# School Danube International School Vienna added.
# running instance 235..
# School PVS Große Stadtgutgasse 24 added.
# running instance 236..
# School GTVS Wehlistraße 178 added.
# running instance 237..
# School „JESSODE-Hatora-Schule“ des Vereins „KHAL ISRAEL religiös-orthodoxer Verein Wien" added.
# running instance 238..
# School Volksschule "Campus" Christine Nöstlinger added.
# running instance 239..
# School Vienna Business School - Handelsakademie und Handelsschule Augarten der Wiener Kaufmannschaft added.
# running instance 240..
# School Handelsschule des Vereins jüdisches pädagogisches Zentrum added.
# running instance 241..
# School Handelsschule am Bundes-Blindeninstitut added.
# running instance 242..
# School Fachschule für jüdische Sozialberufe - Wiener Jeschiwah added.
# running instance 243..
# School Jüdische Mädchenfachschule für Kommunikation und Wirtschaft "Beth-Jakov-Schule" added.
# running instance 244..
# School Jehuda Halevi Musikschule des Vereins Jehuda Halevi Zentrum für Kunst und Kultur added.
# running instance 245..
# School VS Dietrichgasse 36 added.
# running instance 246..
# School MS Dietrichgasse 36 added.
# running instance 247..
# School PTS Maiselgasse 1 added.
# running instance 248..
# School ORg 3 Landstraßer Hauptstraße 70 added.
# running instance 249..
# School VS Erdbergstraße 76 added.
# running instance 250..
# School MS Hainburger Straße 40 added.
# running instance 251..
# School ASO Petrusgasse 10 added.
# running instance 252..
# School BRg 3 Boerhaavegasse 15 added.
# running instance 253..
# School VS Eslarngasse 23 added.
# running instance 254..
# School SSB Paulusgasse 9-11 added.
# running instance 255..
# School MS Hörnesgasse 12 added.
# running instance 256..
# School pG 3 Rennweg 31 added.
# running instance 257..
# School VS Prandaugasse 5 added.
# running instance 258..
# School MS Mira-Lobe-Weg 4 added.
# running instance 259..
# School VS Schrebergasse 39 added.
# running instance 260..
# School VS Schüttaustraße 42 added.
# running instance 261..
# School PVS Hardeggasse 65 added.
# running instance 262..
# School PVS Schödlbergergasse 20 added.
# running instance 263..
# School PMS Jüptnergasse 4 added.
# running instance 264..
# School MS 22, Sonnenallee 116 added.
# running instance 265..
# School VS Mira-Lobe-Weg 4 added.
# running instance 266..
# School MS Langobardenstraße 139 added.
# running instance 267..
# School GTVS Pirquetgasse 6B added.
# running instance 268..
# School VS Bertha-von-Suttner-Gasse 7 added.
# running instance 269..
# School MS Leopold-Kohr-Straße 6 added.
# running instance 270..
# School VS Brioschiweg 1und 3 added.
# running instance 271..
# School PVS Straße der Menschenrechte 1 added.
# running instance 272..
# School Japanische Internationale Schule in Wien added.
# running instance 273..
# School VS Oberdorfstraße 2 added.
# running instance 274..
# School VS Oberdorfstraße 2 added.
# running instance 275..
# School VS Viktor-Wittner-Gasse 50 added.
# running instance 276..
# School GTVS Pastinakweg 10 added.
# running instance 277..
# School VS Hammerfestweg 1 added.
# running instance 278..
# School VS Wagramer Straße 27 added.
# running instance 279..
# School VS Leonard-Bernstein-Straße 2 added.
# running instance 280..
# School PVS Jüptnergasse 4 added.
# running instance 281..
# School International Christian School of Vienna, Wagramer Straße 175 added.
# running instance 282..
# School VS Hannah-Arendt-Platz 8 added.
# running instance 283..
# School GTVS Attemsgasse added.
# running instance 284..
# School PVS des Vereins "Life-Family-Work" added.
# running instance 285..
# School VS Wagramer Straße 224 added.
# running instance 286..
# School Volksschule "Campus" Berresgasse added.
# running instance 287..
# School VS 22, Sonnenallee 116 added.
# running instance 288..
# School Bundeshandelsakademie und Bundeshandelsschule Wien 22 - business.academy.donaustadt added.
# running instance 289..
# School Hertha Firnberg Schulen für Wirtschaft und Tourismus added.
# running instance 290..
# School VS Langobardenstraße 139 added.
# running instance 291..
# School Höhere Technische Bundeslehranstalt Donaustadt added.
# running instance 292..
# School VS Leopold-Kohr-Straße 6 added.
# running instance 293..
# School VS Kirchenplatz 2-3 added.
# running instance 294..
# School VS Am Kaisermühlendamm 2 added.
# running instance 295..
# School VS Kirchenplatz 2-3 added.
# running instance 296..
# School MS Steinergasse 25 added.
# running instance 297..
# School ASO Canavesegasse 22a added.
# running instance 298..
# School Berufsschule für Reinigungstechnik der Gebäudereinigungsakademie der Wiener Gebäudereiniger SchulungsGmbH added.
# running instance 299..
# School HS Anton-Baumgartner-Straße 119 added.
# running instance 300..
# School SKÖ Kanitzgasse 8 added.
# running instance 301..
# School PTS Anton Baumgartner-Straße 44 added.
# running instance 302..
# School pGRg 23 Promenadeweg 3 added.
# running instance 303..
# School VS Prückelmayrgasse 6 added.
# running instance 304..
# School Karl Schubert Schule Wien added.
# running instance 305..
# School pGORg 23 Franz Asenbauer Gasse 49 added.
# running instance 306..
# School VS Anton-Baumgartner-Straße 44/I added.
# running instance 307..
# School VS Erlaaer Schleife 2 added.
# running instance 308..
# School MS Bendagasse 1-2 added.
# running instance 309..
# School VS Erlaaer Straße 74 added.
# running instance 310..
# School PWMS Sta. Christiana added.
# running instance 311..
# School GRg 23 Anton-Baumgartner-Straße 123 added.
# running instance 312..
# School VS Draschestraße 96 added.
# running instance 313..
# School PMS Franz-Asenbauer-Gasse 49 added.
# running instance 314..
# School VS Korbgasse 1 added.
# running instance 315..
# School VS Korbgasse 1 added.
# running instance 316..
# School VS Fürst Liechtenstein-Straße 17 added.
# running instance 317..
# School PVS Altmannsdorfer Straße 154-156 added.
# running instance 318..
# School PVS Endresstraße 59 C added.
# running instance 319..
# School Volksschule Carlbergergasse 72 added.
# running instance 320..
# School Volksschule "Bildungscampus Atzgersdorf" added.
# running instance 321..
# School PNMS Altmannsdorfer Straße 154-156 added.
# running instance 322..
# School Mittelschule "Bildungscampus Atzgersdorf" added.
# running instance 323..
# School PVS Willergasse 55 added.
# running instance 324..
# School PVS Franz-Asenbauer-Gasse 49 added.
# running instance 325..
# School Rudolf Steiner Schule Wien-Mauer added.
# running instance 326..
# School VS Bendagasse 1-2 added.
# running instance 327..
# School VS Akaziengasse 52-54 added.
# running instance 328..
# School VS Akaziengasse 52-54 added.
# running instance 329..
# School PVS Maurer-Lange-Gasse 115 added.
# running instance 330..
# School VS Anton-Baumgartner-Straße 44/II added.
# running instance 331..
# School PVS Promenadeweg 3 added.
# running instance 332..
# School VS Alma-Seidler-Weg 2 added.
# running instance 333..
# School Kreativschule Lernwerkstatt Regenbogen added.
# running instance 334..
# School Astrid Lindgren Schule für ganzheitliches Lernen added.
# running instance 335..
# School Höhere Lehranstalt für wirtschaftliche Berufe - Institut Santa Christiana added.
# running instance 336..
# School Musikschule Harmony des Vereins der Freunde der Musikschule Harmony added.
# running instance 337..
# School Waldorfkindergarten Seminar - Privatschule der Wiener Vereinigung für Waldorfpädagogik und Waldorfschulen-Erwachsenenbildung added.
# running instance 338..
# School Mayflower Christian Academy des Vereins "MCA - Mayflower Christian Academy - International School of Vienna added.
# running instance 339..
# School Rg 6 Marchettigasse 3 added.
# running instance 340..
# School WMS Neustiftgasse 98-102 added.
# running instance 341..
# School WMS Gödelgasse 5 added.
# running instance 342..
# School WMS Kleine Sperlgasse 2A added.
# running instance 343..
# School MS Steinbauergasse 27 added.
# running instance 344..
# School VS Währinger Straße 43 added.
# running instance 345..
# School MS Absberggasse 50 added.
# running instance 346..
# School MS Spallartgasse 18 added.
# running instance 347..
# School MS In der Krim 6 added.
# running instance 348..
# School WMS Wendstattgasse 5/II added.
# running instance 349..
# School VS Halirschgasse 25 added.
# running instance 350..
# School RgORg 23 Anton-Krieger-Gasse 25 added.
# running instance 351..
# School MS Koppstraße 110/I added.
# running instance 352..
# School MS Max-Winter-Platz 2 added.
# running instance 353..
# School GRgORg 20 Karajangasse 14 added.
# running instance 354..
# School G 8 Jodok-Fink-Platz 2 added.
# running instance 355..
# School MS Hermann-Broch-Gasse 2 added.
# running instance 356..
# School pG 4 Favoritenstraße 15 added.
# running instance 357..
# School VS Wichtelgasse 67 added.
# running instance 358..
# School WMS Leipziger Platz 1 added.
# running instance 359..
# School MS Pachmayergasse 6 added.
# running instance 360..
# School MS Am Schöpfwerk 27 added.
# running instance 361..
# School WMS Loquaiplatz 4 added.
# running instance 362..
# School pGRgORg 21 Anton-Böck-Gasse 37 added.
# running instance 363..
# School MS Campus Berresgasse added.
# running instance 364..
# School MS Am Kaisermühlendamm 2 added.
# running instance 365..
# School MS Wendstattgasse 3 added.
# running instance 366..
# School WMS Anton-Baumgartner-Straße 119 added.
# running instance 367..
# School MS Aderklaaer Straße 2 added.
# running instance 368..
# School MS Rudolf-Schön-Weg 1 added.
# running instance 369..
# School MS Hadersdorf Hauptstraße 80 added.
# running instance 370..
# School MS Enkplatz 4/I added.
# running instance 371..
# School MS Veitingergasse 9 added.
# running instance 372..
# School GRg 23 Draschestraße 90-92 added.
# running instance 373..
# School MS Josef-Enslein-Platz 1-3 added.
# running instance 374..
# School GRg 19 Billrothstraße 26-30 added.
# running instance 375..
# School GRg 15 Diefenbachgasse 19 added.
# running instance 376..
# School MS Kölblgasse 23 added.
# running instance 377..
# School MS Wittelsbachstraße 6 added.
# running instance 378..
# School MS Wendstattgasse 5/I added.
# running instance 379..
# School MS Carlbergergasse 72 added.
# running instance 380..
# School VS Florian-Hedorfer-Straße 20 added.
# running instance 381..
# School VS Svetelskystraße 4-6 added.
# running instance 382..
# School GRg 3 Radetzkystraße 2A added.
# running instance 383..
# School VS Kleistgasse 12 added.
# running instance 384..
# School GRg 17 Geblergasse 56-58 added.
# running instance 385..
# School MS Eibengasse 58 added.
# running instance 386..
# School ASO Steinbrechergasse 6 added.
# running instance 387..
# School MS Pfeilgasse 42b added.
# running instance 388..
# School Phönix Realgymnasium Knöllgasse 20 - 24 added.
# running instance 389..
# School MS Roda-Roda-Gasse 3 added.
# running instance 390..
# School MS Hanreitergasse 2 added.
# running instance 391..
# School MS Dirmhirngasse 138 added.
# running instance 392..
# School VS Am Hundsturm 18 added.
# running instance 393..
# School MS Svetelskystraße 4-6 added.
# running instance 394..
# School MS Deublergasse 21 added.
# running instance 395..
# School GTVS Pirquetgasse 6b added.
# running instance 396..
# School pRgORg 2 Obere Augartenstraße 1c added.
# running instance 397..
# School MS Selzergasse 25 added.
# running instance 398..
# School MS Kauergasse 3-5 added.
# running instance 399..
# School BIG Maygasse 25 added.
# running instance 400..
# School MS Glasergasse 8 added.
# running instance 401..
# School VS Rzehakgasse 9 added.
# running instance 402..
# School MS Florian-Hedorferstraße 22 added.
# running instance 403..
# School MS Pöchlarnstraße 14 added.
# running instance 404..
# School SES Jägerstraße 11-13 added.
# running instance 405..
# School SES Jägerstraße 11-13 added.
# running instance 406..
# School VS Greiseneckergasse 29 added.
# running instance 407..
# School MS Staudingergasse 6 added.
# running instance 408..
# School VS Leystraße 34 added.
# running instance 409..
# School MS Stromstraße 40 added.
# running instance 410..
# School VS Vorgartenstraße 95-97 added.
# running instance 411..
# School VS Dietmayrgasse 3 added.
# running instance 412..
# School VS Spielmanngasse 1 added.
# running instance 413..
# School VS Robert-Blum-Gasse 2 added.
# running instance 414..
# School VS Vorgartenstraße 50/Allerheiligenplatz 7 added.
# running instance 415..
# School VS Durchlaufstraße 23 added.
# running instance 416..
# School VS Engerthstraße 134 added.
# running instance 417..
# School TGM Höhere Technische Bundes Lehr- und Versuchsanstalt Wien 20 added.
# running instance 418..
# School LG Engerthstraße 117 added.
# running instance 419..
# School ASO 21, Franklinstraße 27-33/I added.
# running instance 420..
# School ASO 21, Franklinstraße 27-33/II added.
# running instance 421..
# School Berufsschule für Fahrzeugtechnik added.
# running instance 422..
# School Berufsschule für Spengler, Karosseriebau- und Metalltechnik added.
# running instance 423..
# School GRg 21 Franklinstraße 21 added.
# running instance 424..
# School VS Berzeliusgasse 2 added.
# running instance 425..
# School VS Brünnerstraße 139 added.
# running instance 426..
# School MS Regnerweg 6 added.
# running instance 427..
# School GRg 21 Franklinstraße 26 added.
# running instance 428..
# School VS Christian-Bucher-Gasse 14 added.
# running instance 429..
# School MS Kinzerplatz 9 added.
# running instance 430..
# School SSB Herchenhahngasse 6 added.
# running instance 431..
# School SSB Herchenhahngasse 6 added.
# running instance 432..
# School SSB Herchenhahngasse 6 added.
# running instance 433..
# School GRg 21 Ödenburger Straße 74 added.
# running instance 434..
# School SES Theodor-Körner-Gasse 25 added.
# running instance 435..
# School SES Theodor-Körner-Gasse 25 added.
# running instance 436..
# School SES Theodor-Körner-Gasse 25 added.
# running instance 437..
# School SES Theodor-Körner-Gasse 25 added.
# running instance 438..
# School SES Theodor-Körner-Gasse 25 added.
# running instance 439..
# School SES Theodor-Körner-Gasse 25 added.
# running instance 440..
# School VS Tomaschekstraße 44 added.
# running instance 441..
# School SES Theodor-Körner-Gasse 25 added.
# running instance 442..
# School GRg 21 Donauinselplatz 1 added.
# running instance 443..
# School VS Dr.-Skala-Straße 43-45 added.
# running instance 444..
# School MS Pastorstraße 29 added.
# running instance 445..
# School GRgORg 21 Gerasdorfer Straße 103 added.
# running instance 446..
# School VS Dunantgasse 2 added.
# running instance 447..
# School MS Reisgasse 1 added.
# running instance 448..
# School Sekundarschule Al Azhar International Schools added.
# running instance 449..
# School VS Herzmanovsky-Orlando-Gasse 11 added.
# running instance 450..
# School VS Irenäusgasse 2 added.
# running instance 451..
# School PMS Anton-Böck-Gasse 20 added.
# running instance 452..
# School pORg 21 Nordbahnanlage 4 added.
# running instance 453..
# School VS Jochbergengasse 1 added.
# running instance 454..
# School PMS Mayerweckstraße 1 added.
# running instance 455..
# School Bundesgymnasium für Berufstätige added.
# running instance 456..
# School VS Lavantgasse 35 added.
# running instance 457..
# School Privates Realgymnasium Avicenna (Ibn Sina) added.
# running instance 458..
# School VS Mengergasse 33 added.
# running instance 459..
# School MS Jochbergengasse 1 added.
# running instance 460..
# School VS Pastorstraße 29 added.
# running instance 461..
# School MS Adolf-Loos-Gasse 2 added.
# running instance 462..
# School VS Prießnitzgasse 1/I added.
# running instance 463..
# School VS Schillgasse 31 added.
# running instance 464..
# School VS Prießnitzgasse 1-3/II added.
# running instance 465..
# School PMS Weisselgasse 28 added.
# running instance 466..
# School PVS Mayerweckstraße 1 added.
# running instance 467..
# School PVS Anton-Böck-Gasse 20 added.
# running instance 468..
# School VS Dopschstraße 25 added.
# running instance 469..
# School VS Marco-Polo-Platz 9 added.
# running instance 470..
# School VS Rittingergasse 29a added.
# running instance 471..
# School VS Schumpeterweg 3 added.
# running instance 472..
# School VS Hanreitergasse 2 added.
# running instance 473..
# School VS Zehdengasse 9 added.
# running instance 474..
# School VS Adolf-Loos-Gasse 2 added.
# running instance 475..
# School PVS Weisselgasse 28 added.
# running instance 476..
# School VS  Donaufelderstraße 77 added.
# running instance 477..
# School Montessori-Schule Wien 21 - Neue Welt added.
# running instance 478..
# School Privatschule für instinktives Lernen added.
# running instance 479..
# School PVS Pragerstraße 124 added.
# running instance 480..
# School VS Marischkapromenade 16 added.
# running instance 481..
# School Höhere Bundeslehranstalt für Tourismus und wirtschaftliche Berufe added.
# running instance 482..
# School Private Pädagogische Hochschule - Erzdiözese Wien added.
# running instance 483..
# School Tierpflegerschule des Fonds zur Förderung der Tierpflegerausbildung added.
# running instance 484..
# School BAFEP 21 Bildungsanstalt für Elementarpädagogik des Vereins "Schulverein De La Salle" added.
# running instance 485..
# School Islamische Akademie Wien des Vereins Al Azhar International Schools added.
# running instance 486..
# School BAFEP 21 Patrizigasse 2 added.
# running instance 487..
# School Kolleg für Sozialpädagogik für Berufstätige added.
# running instance 488..
# School VS Asperner Heldenplatz 3 added.
# running instance 489..
# School MS Anton-Sattler-Gasse 93 added.
# running instance 490..
# School PTS Wintzingerodestraße 1-3 added.
# running instance 491..
# School Berufsschule für Baugewerbe added.
# running instance 492..
# School GRg 22 Bernoullistraße 3 added.
# running instance 493..
# School VS Schukowitzgasse 89 added.
# running instance 494..
# School ASO Lorenz-Kellner-Gasse 15 added.
# running instance 495..
# School Berufsschule für Gartenbau und Floristik added.
# running instance 496..
# School GRgORg 22 Polgarstraße 24 added.
# running instance 497..
# School VS Eßlinger Hauptstraße 97 added.
# running instance 498..
# School MS Konstanziagasse 50 added.
# running instance 499..
# School Berufsschule für Einzelhandel und EDV-Kaufleute added.
# running instance 500..
# School Vienna International School added.
# running instance 501..
# School SSH Hammerfestweg 1 added.
# running instance 502..
# School SSH Hammerfestweg 1 added.
# running instance 503..
# School GRg 22 Theodor Kramer-Straße 3 added.
# running instance 504..
# School VS Georg-Bilgeri-Straße 13 added.
# running instance 505..
# School WMS Plankenmaisstraße 30 added.
# running instance 506..
# School HS Plankenmaisstraße 30 added.
# running instance 507..
# School HS Plankenmaisstraße 30 added.
# running instance 508..
# School ZIS Stadlauerstraße 51 added.
# running instance 509..
# School SES Brioschiweg 1 added.
# running instance 510..
# School SES Brioschiweg 1 added.
# running instance 511..
# School SES Brioschiweg 1 added.
# running instance 512..
# School SES Brioschiweg 1 added.
# running instance 513..
# School GRg 22 Heustadelgasse 4 added.
# running instance 514..
# School VS Klenaugasse 12 added.
# running instance 515..
# School GRg 22 Contiweg 1 added.
# running instance 516..
# School VS Konstanziagasse 24-26 added.
# running instance 517..
# School pRgORg 22 Maculangasse 2 added.
# running instance 518..
# School VS Wulzendorfstraße 1 added.
# running instance 519..
# School BgBRg Maria-Trapp-Platz 5 added.
# running instance 520..
# School VS Meißnergasse 1 added.
# running instance 521..
# School VS Natorpgasse 1 added.
# running instance 522..
# School MS Afritschgasse 56 added.
# running instance 523..
# School Waldorf Campus Wien (11.-13. Schulstufe) added.
# running instance 524..
# School VS Hochsatzengasse 22-24 added.
# running instance 525..
# School MS Torricelligasse 50/II added.
# running instance 526..
# School BgBRgORg 14 added.
# running instance 527..
# School VS Linzer Straße 419 added.
# running instance 528..
# School VS Lortzinggasse 2 added.
# running instance 529..
# School Montessori Schule Statutschule 4. bis 9. Schulstufe added.
# running instance 530..
# School VS Zennerstraße 1 added.
# running instance 531..
# School VS Mondweg 73-83 added.
# running instance 532..
# School PVS Breitenseer Straße 31 added.
# running instance 533..
# School VS Karl-Toldt-Weg 12 added.
# running instance 534..
# School VS Märzstraße 178-180 added.
# running instance 535..
# School Montessori Schule - Statutschule 1. - 3. Schulstufe added.
# running instance 536..
# School Volksschule "Bildungscampus Wien West" added.
# running instance 537..
# School Montessori Schule - Statutschule (10. - 12. Schulstufe) added.
# running instance 538..
# School VS Dreyhausenstraße 19-25 added.
# running instance 539..
# School Höhere Graphische Bundes-Lehr- und Versuchsanstalt added.
# running instance 540..
# School Werkmeisterschule für Berufstätige des BMLV an der Vega-Payer-Weyprecht-Kaserne added.
# running instance 541..
# School Musikinstitut Polyhymnia der Polyhymnia GmbH added.
# running instance 542..
# School VS Benedikt-Schellinger-Gasse 1-3 added.
# running instance 543..
# School ASO Kröllgasse 20 added.
# running instance 544..
# School PTS Benedikt-Schellinger-Gasse 1-3 added.
# running instance 545..
# School PTS Benedikt-Schellinger-Gasse 1-3 added.
# running instance 546..
# School Berufsschule für Chemie, Grafik und gestaltende Berufe added.
# running instance 547..
# School RgORg 15 Henriettenplatz 6 added.
# running instance 548..
# School VS Friedrichsplatz 5 added.
# running instance 549..
# School MS Schweglerstraße 2-4 added.
# running instance 550..
# School SEH Zinckgasse 12-16 added.
# running instance 551..
# School VS Friesgasse 10 added.
# running instance 552..
# School MS Sechshauser Straße 71 added.
# running instance 553..
# School VS Goldschlagstraße 14-16 added.
# running instance 554..
# School VS Goldschlagstraße 14-16 added.
# running instance 555..
# School SES Huglgasse 3 added.
# running instance 556..
# School Berufsschule für Holz, Klang, Farbe und Lack added.
# running instance 557..
# School pGRg 15 Friesgasse 4 added.
# running instance 558..
# School VS Johnstraße 40 added.
# running instance 559..
# School PMS Friesgasse 4 added.
# running instance 560..
# School SHE Heilstättenschule Huglgasse 3 added.
# running instance 561..
# School VS Selzergasse 19 added.
# running instance 562..
# School PMS Gebrüder-Lang-Gasse 4 added.
# running instance 563..
# School GRg 15 Auf der Schmelz 4 added.
# running instance 564..
# School VS Ortnergasse 4 added.
# running instance 565..
# School Berufsschule für Handel und Reisen added.
# running instance 566..
# School pRg 15 Rauchfangkehrergasse 34/6 added.
# running instance 567..
# School PVS Friesgasse 4 added.
# running instance 568..
# School PVS Gebrüder-Lang-Gasse 4 added.
# running instance 569..
# School VS Reichsapfelgasse 30 added.
# running instance 570..
# School Berufsschule für Bürokaufleute added.
# running instance 571..
# School PVS Ullmannstraße 63 added.
# running instance 572..
# School Handelsakademie-Aufbaulehrgang / Handelsschule d. Schulverbund SSND Österreich added.
# running instance 573..
# School Fachschule für Mode der Stadt Wien added.
# running instance 574..
# School Vienna Konservatorium der Frau Mag. Eva Maria Schmid added.
# running instance 575..
# School VMI - VIENNA MUSIC INSTITUT - PRIVATKONSERVATORIUM DES HERRN MAG. ERNST RITSCH added.
# running instance 576..
# School BSPA Bundessportakademie -  Auf der Schmelz 6 added.
# running instance 577..
# School VS Gaullachergasse 49 added.
# running instance 578..
# School MS Grundsteingasse 48 added.
# running instance 579..
# School ASO Schinnaglgasse 3-5 added.
# running instance 580..
# School Rg 16 Schuhmeierplatz 7 added.
# running instance 581..
# School VS Grubergasse 4 added.
# running instance 582..
# School MS Koppstraße 110/II added.
# running instance 583..
# School GRg 16 Maroltingergasse 69-71 added.
# running instance 584..
# School VS Herbststraße 86 added.
# running instance 585..
# School AHS Julius-Meinl-Gasse 2a added.
# running instance 586..
# School VS Julius-Meinl-Gasse 1 added.
# running instance 587..
# School MS Brüßlgasse 18 added.
# running instance 588..
# School HS Brüßlgasse 18 added.
# running instance 589..
# School VS Brüßlgasse 18 added.
# running instance 590..
# School MS Roterdstraße 1 added.
# running instance 591..
# School MS Wiesberggasse 7 added.
# running instance 592..
# School VS Liebhartsgasse 19-21 added.
# running instance 593..
# School VS Lorenz Mandl-Gasse 56-58 added.
# running instance 594..
# School VS Odoakergasse 48 added.
# running instance 595..
# School VS Grundsteingasse 56 added.
# running instance 596..
# School Höhere Bundeslehranstalt für Mode und künstlerische Gestaltung added.
# running instance 597..
# School Höhere Technische Bundeslehranstalt Wien West added.
# running instance 598..
# School VS Halirschgasse 25 added.
# running instance 599..
# School ASO Leopold-Ernst-Gasse 37 added.
# running instance 600..
# School VS Kindermanngasse 1 added.
# running instance 601..
# School MS Geblergasse 29-31 added.
# running instance 602..
# School GRg 17 Parhamerplatz 18 added.
# running instance 603..
# School VS Knollgasse 4-6 added.
# running instance 604..
# School VS Knollgasse 4-6 added.
# running instance 605..
# School MS Redtenbachergasse 79 added.
# running instance 606..
# School SHE Pezzlgasse 29 added.
# running instance 607..
# School SHE Pezzlgasse 29 added.
# running instance 608..
# School SHE Pezzlgasse 29 added.
# running instance 609..
# School SHE Pezzlgasse 29 added.
# running instance 610..
# School SHE Pezzlgasse 29 added.
# running instance 611..
# School SHE Pezzlgasse 29 added.
# running instance 612..
# School SHE Pezzlgasse 29 added.
# running instance 613..
# School SHE Pezzlgasse 29 added.
# running instance 614..
# School SHE Pezzlgasse 29 added.
# running instance 615..
# School SHE Pezzlgasse 29 added.
# running instance 616..
# School SHE Pezzlgasse 29 added.
# running instance 617..
# School SHE Pezzlgasse 29 added.
# running instance 618..
# School SHE Pezzlgasse 29 added.
# running instance 619..
# School SHE Pezzlgasse 29 added.
# running instance 620..
# School SHE Pezzlgasse 29 added.
# running instance 621..
# School SHE Pezzlgasse 29 added.
# running instance 622..
# School SHE Pezzlgasse 29 added.
# running instance 623..
# School Höhere Schule im Spital (HIS) des Vereins für Individualpsychologie, Pezzlgasse 29 added.
# running instance 624..
# School VS Rötzergasse 2-4 added.
# running instance 625..
# School VS Rötzergasse 2-4 added.
# running instance 626..
# School KOMIT-Schule Bergsteiggasse 36-38 added.
# running instance 627..
# School Sonderschule für sprachgestörte Kinder added.
# running instance 628..
# School Höhere Bundes-Lehr- und Versuchsanstalt für chemische Industrie added.
# running instance 629..
# School Bundesschulen Kalvarienberg - Fachschulen und Aufbaulehrgang - Wirtschaft und Soziales added.
# running instance 630..
# School Franz Schubert Konservatorium für Musik des Herrn Prof. Karl Svec added.
# running instance 631..
# School VS Bischof-Faber-Platz 1 added.
# running instance 632..
# School ASO Anastasius-Grün-Gasse 10 added.
# running instance 633..
# School ASO/SPZ Anastasius-Grün-Gasse 10 added.
# running instance 634..
# School PTS Schopenhauerstraße 81 added.
# running instance 635..
# School PTS Schopenhauerstraße 81 added.
# running instance 636..
# School PTS Schopenhauerstraße 81 added.
# running instance 637..
# School pGRg 18  Semperstraße 45 added.
# running instance 638..
# School VS Cottagegasse 17 added.
# running instance 639..
# School MS Schopenhauerstraße 79 added.
# running instance 640..
# School ZIS Währinger Straße 173-181/I added.
# running instance 641..
# School pRgORg 18 Scheidlstraße 2 added.
# running instance 642..
# School VS Klettenhofergasse 3 added.
# running instance 643..
# School PWMS Antonigasse 72 - Schulstiftung der Erzdiözese Wien added.
# running instance 644..
# School SKÖ Währinger Straße 173-181/II added.
# running instance 645..
# School G 18 Klostergasse 25 added.
# running instance 646..
# School VS Köhlergasse 9 added.
# running instance 647..
# School PNMS  Lacknergasse 89 added.
# running instance 648..
# School GRg 19 Billrothstraße 73 added.
# running instance 649..
# School VS Pantzergasse 25 added.
# running instance 650..
# School American International School  Salmanndorferstraße 47 added.
# running instance 651..
# School VS Windhabergasse 2d added.
# running instance 652..
# School PVS Alfred-Wegener-Gasse 10-12 added.
# running instance 653..
# School PVS Döblinger Hauptstraße 83 added.
# running instance 654..
# School PVS Salmannsdorfer Straße 47 added.
# running instance 655..
# School Schwedische Schule Scheibelreitergasse 15 added.
# running instance 656..
# School Höhere Bundeslehranstalt für wirtschaftliche Berufe Wien 19 added.
# running instance 657..
# School Tourismusschulen Modul der Wirtschaftskammer Wien added.
# running instance 658..
# School BAFEP 19 Hofzeile 17 added.
# running instance 659..
# School BSH Bundesschülerinnenheim Straßergasse added.
# running instance 660..
# School VS Vorgartenstraße 42 added.
# running instance 661..
# School MS Greiseneckergasse 31 added.
# running instance 662..
# School ASO Treustraße 9 added.
# running instance 663..
# School ASO/SPZ Treustraße 9 added.
# running instance 664..
# School PTS Stromstraße 44 added.
# running instance 665..
# School BOL Adalbert-Stifter-Straße 18 added.
# running instance 666..
# School VS Oskar-Spiel-Gasse 3 added.
# running instance 667..
# School VS Treustraße 55 added.
# running instance 668..
# School VS Greiseneckergasse 29/II added.
# running instance 669..
# School KOMIT-Schule Eduardgasse 3 added.
# running instance 670..
# School Rg 18 Schopenhauerstraße 49 added.
# running instance 671..
# School VS Scheibenbergstraße 63 added.
# running instance 672..
# School PMS Schopenhauerstraße 44-46 added.
# running instance 673..
# School GRg 18 Haizingergasse 37 added.
# running instance 674..
# School VS Schulgasse 57 added.
# running instance 675..
# School PMS Semperstraße 45 added.
# running instance 676..
# School PVS Antonigasse 72 added.
# running instance 677..
# School Rudolf Steiner Schule Pötzleinsdorf added.
# running instance 678..
# School PVS Lacknergasse 89 added.
# running instance 679..
# School Private MS der Frau Dr. Sigrid Schauberger added.
# running instance 680..
# School AMADEUS International School VIENNA added.
# running instance 681..
# School pORg 18, VES - Vienna European School added.
# running instance 682..
# School PVS Schumanngasse 17 added.
# running instance 683..
# School PVS Semperstraße 45 added.
# running instance 684..
# School Rudolf Steiner Schule Pötzleinsdorf added.
# running instance 685..
# School PVS Schopenhauerstraße 44-46 added.
# running instance 686..
# School Private VS des Herrn Dr. Christian Schauberger added.
# running instance 687..
# School PVS Scheidlstraße 2 added.
# running instance 688..
# School Werbeakademie - Fachlehrgang für Marktkommunikation des WIFI der Wirtschaftskammer Wien added.
# running instance 689..
# School Werkmeisterschule für Berufstätige des Wirtschaftsförderungsinstitutes der Wirtschaftskammer Wien added.
# running instance 690..
# School PPTS Alfred Wegener-Gasse 10-12 added.
# running instance 691..
# School Berufsschule für Brau- und Getränketechnik und für Destillateure added.
# running instance 692..
# School G 19 Gymnasiumstraße 83 added.
# running instance 693..
# School VS Flotowgasse 25 added.
# running instance 694..
# School MS Oskar-Spiel-Gasse 3 added.
# running instance 695..
# School VS Grinzinger Straße 88 added.
# running instance 696..
# School MS Pyrkergasse 14-16 added.
# running instance 697..
# School PSO Stefan-Esders-Platz 1 added.
# running instance 698..
# School VS Kreindlgasse 24 added.
# running instance 699..
# School PMS Alfred-Wegener-Gasse 10-12 added.
# running instance 700..
# School PSO Am Himmel-Gspöttgraben 5 added.
# running instance 701..
# School Rg 19 Krottenbachstraße 11-13 added.
# running instance 702..
# School VS Krottenbachstraße 108 added.
# running instance 703..
# School VS Krottenbachstraße 108 added.
# running instance 704..
# School „Gymnasium“ und „Wirtschaftskundliches Realgymnasium“ des Vereins „Vereinigung von Ordensschulen“ added.
# running instance 705..
# School VS Mannagettagasse 1 added.
# running instance 706..
# School pGRg 19 Alfred Wegener-Gasse 10-12 added.
# running instance 707..
# School SES Hoefftgasse 7 added.
# running instance 708..
# School GRg 11 Geringergasse 2 added.
# running instance 709..
# School VS Brehmstraße 9 added.
# running instance 710..
# School MS Rzehakgasse 7 added.
# running instance 711..
# School pGRg 11 Erdbergstraße 222 A added.
# running instance 712..
# School VS Herderplatz 1 added.
# running instance 713..
# School MS Hasenleitengasse 7 added.
# running instance 714..
# School VS Molitorgasse 11 added.
# running instance 715..
# School VS Münnichplatz 6 added.
# running instance 716..
# School VS Simoningplatz 2 added.
# running instance 717..
# School VS Wilhelm-Kreß-Platz 32 added.
# running instance 718..
# School GTMS 11, Medwedweg 18 added.
# running instance 719..
# School VS Hoefftgasse 7 added.
# running instance 720..
# School VS Pantucekgasse 13 added.
# running instance 721..
# School VS Fuchsröhrenstraße 25 added.
# running instance 722..
# School VS Svetelskystraße 5 added.
# running instance 723..
# School Expos. der VS 1110, Svetelskystraße 5 added.
# running instance 724..
# School Expos. der VS 1110, Svetelskystraße 5 added.
# running instance 725..
# School VS 11, Medwedweg 18 added.
# running instance 726..
# School VS Rappachgasse 44 - Bildungscampus Gasometerumfeld added.
# running instance 727..
# School Bundeshandelsakademie und Bundeshandelsschule Wien 11 added.
# running instance 728..
# School Friedrich Gulda School of Music Wien JAM MUSIC LAB Conservatory for Jazz and Popular - Music Vienna der Jam Music GmbH added.
# running instance 729..
# School Johann Sebastian Bach Musikschule des Evangelischen Schulwerk A.B. Wien added.
# running instance 730..
# School VS Bischoffgasse 10 added.
# running instance 731..
# School VS Bischoffgasse 10 added.
# running instance 732..
# School MS Herthergasse 28 added.
# running instance 733..
# School ASO Singrienergasse 19 added.
# running instance 734..
# School Berufsschule für Lebensmittel, Touristik und Zahntechnik added.
# running instance 735..
# School GRg 12 Rosasgasse 1-3 added.
# running instance 736..
# School VS Haebergasse 1a added.
# running instance 737..
# School MS Johann-Hoffmann-Platz 19 added.
# running instance 738..
# School SES Singrienergasse 19 added.
# running instance 739..
# School SES Singrienergasse 19 added.
# running instance 740..
# School SES Singrienergasse 19 added.
# running instance 741..
# School SES Singrienergasse 19 added.
# running instance 742..
# School GRg 12 Erlgasse 32-34 added.
# running instance 743..
# School VS Johann-Hoffmann-Platz 20 added.
# running instance 744..
# School Berufsschule für Gastgewerbe added.
# running instance 745..
# School Privatschule INFINUM added.
# running instance 746..
# School VS Karl-Löwe-Gasse 20 added.
# running instance 747..
# School MS Singrienergasse 23 added.
# running instance 748..
# School VS Deckergasse 1 added.
# running instance 749..
# School Berufsschule für Industrie, Finanzen und Transport added.
# running instance 750..
# School VS Rothenburgstraße 1 added.
# running instance 751..
# School VS Ruckergasse 42 added.
# running instance 752..
# School VS Am Schöpfwerk 27 added.
# running instance 753..
# School VS Rohrwassergasse 2 added.
# running instance 754..
# School Isma Private Gesamtschule Muhammad Asad Reschgasse 20-22 added.
# running instance 755..
# School Privatschule Infinum Hetzendorferstraße 77 added.
# running instance 756..
# School Fachschule der Stadt Wien für wirtschaftliche Berufe added.
# running instance 757..
# School Bundeshandelsakademie und Bundeshandelsschule Wien 12 - International Business College Hetzendorf added.
# running instance 758..
# School Modeschule der Stadt Wien im Schloss Hetzendorf added.
# running instance 759..
# School Richard Wagner Konservatorium des Herrn Mirza Kapetanovic added.
# running instance 760..
# School BAFEP 12 Private Bundesbildungsanstalt für Elementarpädagogik added.
# running instance 761..
# School VS Am Platz 2 added.
# running instance 762..
# School Berufsschule der SPAR österreichische Warenhandels-AG - Private Spar Akademie Wien added.
# running instance 763..
# School G 13 Fichtnergasse 15 added.
# running instance 764..
# School VS Auhofstraße 49 added.
# running instance 765..
# School HS Veitingergasse 9 added.
# running instance 766..
# School SES Hackinger Kai 15 added.
# running instance 767..
# School SES Hackinger Kai 15 added.
# running instance 768..
# School Berufsschule für Einzelhandel added.
# running instance 769..
# School GRg 13 Wenzgasse 7 added.
# running instance 770..
# School PMS  Schloßberggasse 17 added.
# running instance 771..
# School pGRg 13 Schloßberggasse 17 added.
# running instance 772..
# School VS Dr.-Schober-Straße 1 added.
# running instance 773..
# School pORg 13 Auhofstraße 78 e-f added.
# running instance 774..
# School VS Speisinger Straße 44 added.
# running instance 775..
# School VS Speisinger Straße 44 added.
# running instance 776..
# School VS Steinlechnergasse 5-7 added.
# running instance 777..
# School PVS Schloßberggasse 17 added.
# running instance 778..
# School VS Hietzinger Hauptstraße 166 added.
# running instance 779..
# School Friedrich Eymann Waldorfschule added.
# running instance 780..
# School Freie Waldorfschule Wien-West added.
# running instance 781..
# School Lehranstalt für systemische Familientherapie der Erzdiözese Wien für Berufstätige added.
# running instance 782..
# School Fachschule und Aufbaulehrgang für wirtschaftliche Berufe des Schulvereins der Dominikanerinnen added.
# running instance 783..
# School Lehranstalt für pastorale Berufe des Seminars für kirchliche Berufe added.
# running instance 784..
# School Expositur der Höheren gewerblichen Bundeslehranstalt für Mode und Bekleidungstechnik u. für wirtschaftliche Berufe added.
# running instance 785..
# School Bundeshandelsakademie und Bundeshandelsschule Wien 13 - Schumpeter Handelsakademie added.
# running instance 786..
# School Höhere Bundeslehranstalt für Tourismus und für wirtschaftliche Berufe Wien 13 added.
# running instance 787..
# School Speziallehrgang für Leitungsfunktionen in der Sozialarbeit der Caritas der Erzdiözese Wien added.
# running instance 788..
# School HBLFA Grünbergstraße 24 added.
# running instance 789..
# School Goetheanistisches Konservatorium und waldorfpädagogische Akademie des Kuratoriums für künstlerische und heilende Pädagogik added.
# running instance 790..
# School BSH 13 Himmelhofgasse 17-19 added.
# running instance 791..
# School BSH Bundesschülerheim 13 added.
# running instance 792..
# School VS Diesterweggasse 30 added.
# running instance 793..
# School SSB Kienmayergasse 41 added.
# running instance 794..
# School SSB Kienmayergasse 41 added.
# running instance 795..
# School SSB Kienmayergasse 41 added.
# running instance 796..
# School SSB Kienmayergasse 41 added.
# running instance 797..
# School SSB Kienmayergasse 41 added.
# running instance 798..
# School Verein W@lz.Wiener Lernzentrum, Heinrich-Collin-Straße 9 added.
# running instance 799..
# School Berufsschule für Schönheitsberufe added.
# running instance 800..
# School GRg 14 Astgasse 3 added.
# running instance 801..
# School VS Felbigergasse 97 added.
# running instance 802..
# School MS Torricelligasse 50 I added.
# running instance 803..
# School ASO Linzer Straße 232 added.
# running instance 804..
# School GRg 14 Linzer Straße 146 added.
# running instance 805..
# School VS Hadersdorf Hauptstraße 70 added.
# running instance 806..
# School MS Lortzinggasse 2 added.

# %%
def populate_stops(stops_data):
    count = 1
    for feature in stops_data['features']:
        print(f"running instance {count}..")
        count = count+1
        properties = feature['properties']
        geometry = feature['geometry']['coordinates']
        
        stop_node = Stop.nodes.get_or_none(stop_id=feature['id'])
        if not stop_node:
            stop_node = Stop(
                stop_id=feature['id'],
                name=properties['BEZEICHNUNG'],
                wl_number=properties['WL_NUMMER'],
                stop_latitude=geometry[1],
                stop_longitude=geometry[0]
            ).save()
            print(f"Stop {properties['BEZEICHNUNG']} ADDED.")
        else:
            print(f"Stop {properties['BEZEICHNUNG']} ALREADY EXISTED.")
            
populate_stops(stops_data)
# Out:
# running instance 1..
# Stop Absberggasse already in graph, not added.
# running instance 2..
# Stop Achengasse already in graph, not added.
# running instance 3..
# Stop Ada-Christen-Gasse already in graph, not added.
# running instance 4..
# Stop Adam-Betz-Gasse already in graph, not added.
# running instance 5..
# Stop Adamovichgasse already in graph, not added.
# running instance 6..
# Stop Adolf-Loos-Gasse already in graph, not added.
# running instance 7..
# Stop Adolf-Unger-Gasse already in graph, not added.
# running instance 8..
# Stop Afritschgasse already in graph, not added.
# running instance 9..
# Stop Agavenweg already in graph, not added.
# running instance 10..
# Stop Agnesgasse already in graph, not added.
# running instance 11..
# Stop Aignerstraße already in graph, not added.
# running instance 12..
# Stop Auf der Schmelz already in graph, not added.
# running instance 13..
# Stop Morzinplatz already in graph, not added.
# running instance 14..
# Stop Alaudagasse already in graph, not added.
# running instance 15..
# Stop Albern Sendnergasse already in graph, not added.
# running instance 16..
# Stop Alberner Hafen already in graph, not added.
# running instance 17..
# Stop Alberner Hafenzufahrtsstraße already in graph, not added.
# running instance 18..
# Stop Alberner Straße already in graph, not added.
# running instance 19..
# Stop Albertgasse already in graph, not added.
# running instance 20..
# Stop Albertinaplatz already in graph, not added.
# running instance 21..
# Stop Carminweg already in graph, not added.
# running instance 22..
# Stop Algenweg already in graph, not added.
# running instance 23..
# Stop Allerheiligengasse already in graph, not added.
# running instance 24..
# Stop Gerasdorfer Str./Ruthnergasse already in graph, not added.
# running instance 25..
# Stop Alois-Behr-Straße already in graph, not added.
# running instance 26..
# Stop Alsegger Straße already in graph, not added.
# running instance 27..
# Stop Alser Straße already in graph, not added.
# running instance 28..
# Stop Aichholzgasse already in graph, not added.
# running instance 29..
# Stop Nußdorfer Str/Alserbachstraße already in graph, not added.
# running instance 30..
# Stop Triester Str/Altdorferstraße already in graph, not added.
# running instance 31..
# Stop Alte Donau already in graph, not added.
# running instance 32..
# Stop Aichholzgasse/Ratschkygasse already in graph, not added.
# running instance 33..
# Stop Altes Landgut already in graph, not added.
# running instance 34..
# Stop Althanstraße already in graph, not added.
# running instance 35..
# Stop Breitenfurter St/Altmannsd Str already in graph, not added.
# running instance 36..
# Stop Auhofstraße already in graph, not added.
# running instance 37..
# Stop Am Fasangarten already in graph, not added.
# running instance 38..
# Stop Am Heidjöchl already in graph, not added.
# running instance 39..
# Stop Am Heidjöchl/Hausfeldstraße already in graph, not added.
# running instance 40..
# Stop Am Himmelreich already in graph, not added.
# running instance 41..
# Stop Am Hundsturm already in graph, not added.
# running instance 42..
# Stop Am Kanal already in graph, not added.
# running instance 43..
# Stop Am Kanal/Hasenleitengasse already in graph, not added.
# running instance 44..
# Stop Am Modenapark already in graph, not added.
# running instance 45..
# Stop Am Platz already in graph, not added.
# running instance 46..
# Stop Am Rosenhügel already in graph, not added.
# running instance 47..
# Stop Reichsbrücke already in graph, not added.
# running instance 48..
# Stop Am Schöpfwerk already in graph, not added.
# running instance 49..
# Stop Am Spiegeln already in graph, not added.
# running instance 50..
# Stop Am Spitz already in graph, not added.
# running instance 51..
# Stop Am Tabor already in graph, not added.
# running instance 52..
# Stop Fünfhausgasse already in graph, not added.
# running instance 53..
# Stop Gesundheitszentrum Süd already in graph, not added.
# running instance 54..
# Stop Ameisbachzeile already in graph, not added.
# running instance 55..
# Stop Ameisgasse already in graph, not added.
# running instance 56..
# Stop Neubaugasse already in graph, not added.
# running instance 57..
# Stop Ammerweg already in graph, not added.
# running instance 58..
# Stop Amongasse already in graph, not added.
# running instance 59..
# Stop An den Steinfeldern already in graph, not added.
# running instance 60..
# Stop An den alten Schanzen already in graph, not added.
# running instance 61..
# Stop An den langen Lüssen already in graph, not added.
# running instance 62..
# Stop An der Bien already in graph, not added.
# running instance 63..
# Stop An der Niederhaid already in graph, not added.
# running instance 64..
# Stop An der Scheibenwiese already in graph, not added.
# running instance 65..
# Stop Angermayergasse already in graph, not added.
# running instance 66..
# Stop Anschützgasse already in graph, not added.
# running instance 67..
# Stop Anton-Bosch-Gasse already in graph, not added.
# running instance 68..
# Stop Anton-Böck-Gasse already in graph, not added.
# running instance 69..
# Stop Anton-Krieger-Gasse already in graph, not added.
# running instance 70..
# Stop Anton-Sattler-Gasse already in graph, not added.
# running instance 71..
# Stop Anton-Störck-Gasse already in graph, not added.
# running instance 72..
# Stop Antonigasse already in graph, not added.
# running instance 73..
# Stop Anzengruberstraße already in graph, not added.
# running instance 74..
# Stop Apostelgasse already in graph, not added.
# running instance 75..
# Stop Liesing Aquädukt already in graph, not added.
# running instance 76..
# Stop Margaretengürtel/Arbeitergasse already in graph, not added.
# running instance 77..
# Stop Arbeiterstrandbad already in graph, not added.
# running instance 78..
# Stop Argentinierstraße already in graph, not added.
# running instance 79..
# Stop Armbrustergasse already in graph, not added.
# running instance 80..
# Stop Arminenstraße already in graph, not added.
# running instance 81..
# Stop Arndtstraße already in graph, not added.
# running instance 82..
# Stop Arnikaweg already in graph, not added.
# running instance 83..
# Stop Arsenal already in graph, not added.
# running instance 84..
# Stop Artariastraße already in graph, not added.
# running instance 85..
# Stop Arthaberplatz already in graph, not added.
# running instance 86..
# Stop Artillerieplatz already in graph, not added.
# running instance 87..
# Stop Aspernallee already in graph, not added.
# running instance 88..
# Stop Asperner Heldenplatz already in graph, not added.
# running instance 89..
# Stop Frederick-Loewe-Weg already in graph, not added.
# running instance 90..
# Stop Matzleinsdf.Platz Autoreisezug already in graph, not added.
# running instance 91..
# Stop Atzgersdorf Friedhof already in graph, not added.
# running instance 92..
# Stop Atzgersdorf Kirchenplatz already in graph, not added.
# running instance 93..
# Stop Atzgersdorf already in graph, not added.
# running instance 94..
# Stop An der Liesing already in graph, not added.
# running instance 95..
# Stop Atzgersdorfer Straße already in graph, not added.
# running instance 96..
# Stop Auernheimergasse already in graph, not added.
# running instance 97..
# Stop Augasse already in graph, not added.
# running instance 98..
# Stop Broßmannplatz already in graph, not added.
# running instance 99..
# Stop Aumannplatz already in graph, not added.
# running instance 100..
# Stop Autokaderstraße already in graph, not added.
# running instance 101..
# Stop Aßmayergasse already in graph, not added.
# running instance 102..
# Stop Bacherplatz already in graph, not added.
# running instance 103..
# Stop Badeteich Süßenbrunn already in graph, not added.
# running instance 104..
# Stop Badgasse already in graph, not added.
# running instance 105..
# Stop Bahnhofstraße already in graph, not added.
# running instance 106..
# Stop Wiethestraße/Kirschenallee already in graph, not added.
# running instance 107..
# Stop Barawitzkagasse already in graph, not added.
# running instance 108..
# Stop Barichgasse already in graph, not added.
# running instance 109..
# Stop Morelligasse already in graph, not added.
# running instance 110..
# Stop Bauernfeldplatz already in graph, not added.
# running instance 111..
# Stop Linzer Straße/Hochsatzengasse already in graph, not added.
# running instance 112..
# Stop Baumgartner Friedhof already in graph, not added.
# running instance 113..
# Stop Baumgasse already in graph, not added.
# running instance 114..
# Stop Nußdorf, Beethovengang already in graph, not added.
# running instance 115..
# Stop Belgradplatz already in graph, not added.
# running instance 116..
# Stop Bellevuestraße already in graph, not added.
# running instance 117..
# Stop Bellgasse already in graph, not added.
# running instance 118..
# Stop Belvederegasse already in graph, not added.
# running instance 119..
# Stop Benatzkygasse already in graph, not added.
# running instance 120..
# Stop Berggasse already in graph, not added.
# running instance 121..
# Stop Bergmillergasse already in graph, not added.
# running instance 122..
# Stop Bergsteiggasse already in graph, not added.
# running instance 123..
# Stop Theodor-Körner-Gasse already in graph, not added.
# running instance 124..
# Stop Berlepschgasse already in graph, not added.
# running instance 125..
# Stop Fernkorngasse already in graph, not added.
# running instance 126..
# Stop Bernreiterplatz already in graph, not added.
# running instance 127..
# Stop Mühlschüttel already in graph, not added.
# running instance 128..
# Stop Berzeliusgasse already in graph, not added.
# running instance 129..
# Stop Beschußamt already in graph, not added.
# running instance 130..
# Stop Anton-Schall-Gasse already in graph, not added.
# running instance 131..
# Stop Bettelheimstraße already in graph, not added.
# running instance 132..
# Stop Bezirksamt Donaustadt already in graph, not added.
# running instance 133..
# Stop Döblinger Hauptstr/Gatterburgg already in graph, not added.
# running instance 134..
# Stop Laxenburger Str/Gudrunstraße already in graph, not added.
# running instance 135..
# Stop Bezirksamt Margareten already in graph, not added.
# running instance 136..
# Stop Bibernellweg already in graph, not added.
# running instance 137..
# Stop Bieglerhütte already in graph, not added.
# running instance 138..
# Stop Binsenweg already in graph, not added.
# running instance 139..
# Stop Biomull-Werk already in graph, not added.
# running instance 140..
# Stop Bischoffgasse already in graph, not added.
# running instance 141..
# Stop Bischofgasse already in graph, not added.
# running instance 142..
# Stop Blaasstraße already in graph, not added.
# running instance 143..
# Stop Blechturmgasse already in graph, not added.
# running instance 144..
# Stop Bleibtreustraße already in graph, not added.
# running instance 145..
# Stop Bleriotgasse already in graph, not added.
# running instance 146..
# Stop Blindengasse already in graph, not added.
# running instance 147..
# Stop Blumengasse already in graph, not added.
# running instance 148..
# Stop Hetmanekgasse already in graph, not added.
# running instance 149..
# Stop Bognergasse already in graph, not added.
# running instance 150..
# Stop Bohattaweg already in graph, not added.
# running instance 151..
# Stop Borkowskigasse already in graph, not added.
# running instance 152..
# Stop Bossigasse already in graph, not added.
# running instance 153..
# Stop Maculangasse/Wagramer Straße already in graph, not added.
# running instance 154..
# Stop Braillegasse already in graph, not added.
# running instance 155..
# Stop Brandstätte already in graph, not added.
# running instance 156..
# Stop Braungasse already in graph, not added.
# running instance 157..
# Stop Grimmgasse already in graph, not added.
# running instance 158..
# Stop Braunhubergasse already in graph, not added.
# running instance 159..
# Stop Braunschweiggasse already in graph, not added.
# running instance 160..
# Stop Scheffelstraße already in graph, not added.
# running instance 161..
# Stop Breiteneckergasse already in graph, not added.
# running instance 162..
# Stop Breitenlee Friedhof already in graph, not added.
# running instance 163..
# Stop Breitenlee Ort already in graph, not added.
# running instance 164..
# Stop Breitensee already in graph, not added.
# running instance 165..
# Stop Roschegasse already in graph, not added.
# running instance 166..
# Stop Bretschneidergasse already in graph, not added.
# running instance 167..
# Stop Brigittagasse already in graph, not added.
# running instance 168..
# Stop Brigittaplatz already in graph, not added.
# running instance 169..
# Stop Brockhausengasse already in graph, not added.
# running instance 170..
# Stop Thaliastraße/Brunnengasse already in graph, not added.
# running instance 171..
# Stop Neulerchenfelder Str/Brunneng already in graph, not added.
# running instance 172..
# Stop Brunner Straße/Erlaaer Straße already in graph, not added.
# running instance 173..
# Stop Brückengasse already in graph, not added.
# running instance 174..
# Stop Brünner Straße already in graph, not added.
# running instance 175..
# Stop Bergtaidingweg already in graph, not added.
# running instance 176..
# Stop Brünnlbadgasse already in graph, not added.
# running instance 177..
# Stop Brüßlgasse already in graph, not added.
# running instance 178..
# Stop Bubergasse already in graph, not added.
# running instance 179..
# Stop Buchbindergasse already in graph, not added.
# running instance 180..
# Stop Lindmayer/Friedenspagode already in graph, not added.
# running instance 181..
# Stop Computerstr/Gutheil-Schoder-G already in graph, not added.
# running instance 182..
# Stop Hütteldorf, Bujattigasse already in graph, not added.
# running instance 183..
# Stop Bundessportbad already in graph, not added.
# running instance 184..
# Stop Bunsengasse already in graph, not added.
# running instance 185..
# Stop Burgersteingasse already in graph, not added.
# running instance 186..
# Stop Burggasse-Stadthalle already in graph, not added.
# running instance 187..
# Stop Campingplatz Wien-West 2 already in graph, not added.
# running instance 188..
# Stop Burgring already in graph, not added.
# running instance 189..
# Stop Burgstall already in graph, not added.
# running instance 190..
# Stop Rathausplatz/Burgtheater already in graph, not added.
# running instance 191..
# Stop Bärenmühldurchgang already in graph, not added.
# running instance 192..
# Stop Börnergasse already in graph, not added.
# running instance 193..
# Stop Börsegasse/Wipplingerstraße already in graph, not added.
# running instance 194..
# Stop Bösendorferstraße already in graph, not added.
# running instance 195..
# Stop Camillo-Sitte-Gasse already in graph, not added.
# running instance 196..
# Stop Breitenfurter Str/Willergasse already in graph, not added.
# running instance 197..
# Stop Campingplatz Wien-Süd already in graph, not added.
# running instance 198..
# Stop Campingplatz Wien-West 1 already in graph, not added.
# running instance 199..
# Stop Campingplatzweg already in graph, not added.
# running instance 200..
# Stop Canisiusgasse already in graph, not added.
# running instance 201..
# Stop Carabelligasse already in graph, not added.
# running instance 202..
# Stop Carlbergergasse already in graph, not added.
# running instance 203..
# Stop Castelligasse already in graph, not added.
# running instance 204..
# Stop Celtesgasse already in graph, not added.
# running instance 205..
# Stop Chimanistraße already in graph, not added.
# running instance 206..
# Stop Cobenzl Parkplatz already in graph, not added.
# running instance 207..
# Stop Cobenzlgasse already in graph, not added.
# running instance 208..
# Stop Columbusplatz already in graph, not added.
# running instance 209..
# Stop Triester Straße/Computerstraße already in graph, not added.
# running instance 210..
# Stop Concordiaplatz already in graph, not added.
# running instance 211..
# Stop Corvinusgasse already in graph, not added.
# running instance 212..
# Stop Cottagegasse already in graph, not added.
# running instance 213..
# Stop Cottagestraße already in graph, not added.
# running instance 214..
# Stop Czartoryskigasse already in graph, not added.
# running instance 215..
# Stop Dahliengasse already in graph, not added.
# running instance 216..
# Stop Dammstraße already in graph, not added.
# running instance 217..
# Stop Dampfkraftwerk Donaustadt already in graph, not added.
# running instance 218..
# Stop Dampfschiffhaufen already in graph, not added.
# running instance 219..
# Stop Danzergasse already in graph, not added.
# running instance 220..
# Stop Daphneweg already in graph, not added.
# running instance 221..
# Stop Daringergasse already in graph, not added.
# running instance 222..
# Stop Knöllgasse/Davidgasse already in graph, not added.
# running instance 223..
# Stop Deindorfstraße already in graph, not added.
# running instance 224..
# Stop Deißenhofergasse already in graph, not added.
# running instance 225..
# Stop Laxenburger Str/Heizwerkstr already in graph, not added.
# running instance 226..
# Stop Dietmayrgasse already in graph, not added.
# running instance 227..
# Stop Dirnelwiese already in graph, not added.
# running instance 228..
# Stop Dobrowskygasse already in graph, not added.
# running instance 229..
# Stop Doeltergasse already in graph, not added.
# running instance 230..
# Stop Dommayergasse already in graph, not added.
# running instance 231..
# Stop Donauinsel already in graph, not added.
# running instance 232..
# Stop Floridsdorfer Brücke already in graph, not added.
# running instance 233..
# Stop Donaustadtstraße already in graph, not added.
# running instance 234..
# Stop Donauwarte already in graph, not added.
# running instance 235..
# Stop Donauzentrum already in graph, not added.
# running instance 236..
# Stop Dopschstraße already in graph, not added.
# running instance 237..
# Stop Dorfmeistergasse already in graph, not added.
# running instance 238..
# Stop Dornbacher Straße already in graph, not added.
# running instance 239..
# Stop Dostalgasse already in graph, not added.
# running instance 240..
# Stop Dostgasse already in graph, not added.
# running instance 241..
# Stop Dr.-Adolf-Schärf-Heim already in graph, not added.
# running instance 242..
# Stop Stubentor already in graph, not added.
# running instance 243..
# Stop Dr.-Karl-Renner-Ring already in graph, not added.
# running instance 244..
# Stop Dr.-Neumann-Gasse already in graph, not added.
# running instance 245..
# Stop Dr.-Schober-Straße already in graph, not added.
# running instance 246..
# Stop Draugasse already in graph, not added.
# running instance 247..
# Stop Dunantgasse already in graph, not added.
# running instance 248..
# Stop Dänenstraße already in graph, not added.
# running instance 249..
# Stop Döblinger Bad already in graph, not added.
# running instance 250..
# Stop Döblinger Friedhof already in graph, not added.
# running instance 251..
# Stop Döblinger Steg already in graph, not added.
# running instance 252..
# Stop Dörmanngasse already in graph, not added.
# running instance 253..
# Stop E-Werk already in graph, not added.
# running instance 254..
# Stop Eberstorferweg already in graph, not added.
# running instance 255..
# Stop Edelsteingasse already in graph, not added.
# running instance 256..
# Stop Edenstraße already in graph, not added.
# running instance 257..
# Stop Edmund-Hawranek-Platz already in graph, not added.
# running instance 258..
# Stop Eduard-Kittenberger-Gasse already in graph, not added.
# running instance 259..
# Stop Albrechtskreithgasse already in graph, not added.
# running instance 260..
# Stop Egon-Friedell-Gasse already in graph, not added.
# running instance 261..
# Stop Eibesbrunnergasse already in graph, not added.
# running instance 262..
# Stop Eibischweg already in graph, not added.
# running instance 263..
# Stop Eichbachgasse already in graph, not added.
# running instance 264..
# Stop Eichenstraße already in graph, not added.
# running instance 265..
# Stop Einsiedeleigasse already in graph, not added.
# running instance 266..
# Stop Einsiedlerplatz already in graph, not added.
# running instance 267..
# Stop Luzegasse already in graph, not added.
# running instance 268..
# Stop Eipeldauerstraße already in graph, not added.
# running instance 269..
# Stop Eisenstadtplatz already in graph, not added.
# running instance 270..
# Stop Eisstoßgasse already in graph, not added.
# running instance 271..
# Stop Elderschplatz already in graph, not added.
# running instance 272..
# Stop Elsbeergasse already in graph, not added.
# running instance 273..
# Stop Elterleinplatz already in graph, not added.
# running instance 274..
# Stop Embelgasse already in graph, not added.
# running instance 275..
# Stop Endemanngasse already in graph, not added.
# running instance 276..
# Stop Engerthstraße/Innstraße already in graph, not added.
# running instance 277..
# Stop Engerthstraße/Traisengasse already in graph, not added.
# running instance 278..
# Stop Englisch-Feld-Gasse already in graph, not added.
# running instance 279..
# Stop Donaumarina already in graph, not added.
# running instance 280..
# Stop Erdbergstr/Schlachthausgasse already in graph, not added.
# running instance 281..
# Stop Ottakringer Str/Erdbrustgasse already in graph, not added.
# running instance 282..
# Stop Erlaaer Straße already in graph, not added.
# running instance 283..
# Stop Erlachplatz already in graph, not added.
# running instance 284..
# Stop Erndtgasse already in graph, not added.
# running instance 285..
# Stop Erzherzog-Karl-Straße already in graph, not added.
# running instance 286..
# Stop Erdberg already in graph, not added.
# running instance 287..
# Stop Donaustadtbrücke already in graph, not added.
# running instance 288..
# Stop Eselstiege already in graph, not added.
# running instance 289..
# Stop Eslarngasse already in graph, not added.
# running instance 290..
# Stop Esterhazygasse already in graph, not added.
# running instance 291..
# Stop Etrichstraße already in graph, not added.
# running instance 292..
# Stop Daumegasse already in graph, not added.
# running instance 293..
# Stop Evangelischer Friedhof already in graph, not added.
# running instance 294..
# Stop Eßling Schule already in graph, not added.
# running instance 295..
# Stop Eßling Friedhof already in graph, not added.
# running instance 296..
# Stop Aspernstraße already in graph, not added.
# running instance 297..
# Stop Fasangasse already in graph, not added.
# running instance 298..
# Stop Heiligenstadt, 12.-Februar-Pl already in graph, not added.
# running instance 299..
# Stop Diesterweggasse already in graph, not added.
# running instance 300..
# Stop Wattmanngasse/Elisabethallee already in graph, not added.
# running instance 301..
# Stop Felix-Dahn-Straße already in graph, not added.
# running instance 302..
# Stop Felmayergasse already in graph, not added.
# running instance 303..
# Stop Fendigasse already in graph, not added.
# running instance 304..
# Stop Sonnleithnergasse already in graph, not added.
# running instance 305..
# Stop Gspöttgraben already in graph, not added.
# running instance 306..
# Stop Fernsprechamt Heiligenstadt already in graph, not added.
# running instance 307..
# Stop Ferry-Dusika-Stadion already in graph, not added.
# running instance 308..
# Stop Feuerwache Am Steinhof already in graph, not added.
# running instance 309..
# Stop Feuerwache Grinzing already in graph, not added.
# running instance 310..
# Stop Dampfkraftwerk already in graph, not added.
# running instance 311..
# Stop Fickeysstraße already in graph, not added.
# running instance 312..
# Stop Filmteichstraße already in graph, not added.
# running instance 313..
# Stop Finsterbuschstraße/Spielplatz already in graph, not added.
# running instance 314..
# Stop Billgasse already in graph, not added.
# running instance 315..
# Stop Löschniggasse already in graph, not added.
# running instance 316..
# Stop Firma Dietzel already in graph, not added.
# running instance 317..
# Stop Dammhaufengasse already in graph, not added.
# running instance 318..
# Stop Pfarrgasse/Traviatagasse already in graph, not added.
# running instance 319..
# Stop Zimbagasse already in graph, not added.
# running instance 320..
# Stop Auhof already in graph, not added.
# running instance 321..
# Stop Firma Schiff & Stern already in graph, not added.
# running instance 322..
# Stop Giefinggasse already in graph, not added.
# running instance 323..
# Stop Rodaun Wohnheim already in graph, not added.
# running instance 324..
# Stop Heinrich-von-Buol-Gasse already in graph, not added.
# running instance 325..
# Stop Fischergrund already in graph, not added.
# running instance 326..
# Stop Fichtnergasse already in graph, not added.
# running instance 327..
# Stop Florian-Geyer-Gasse already in graph, not added.
# running instance 328..
# Stop Florian-Hedorfer-Straße already in graph, not added.
# running instance 329..
# Stop Florianigasse already in graph, not added.
# running instance 330..
# Stop Floridsdorf already in graph, not added.
# running instance 331..
# Stop Joseph-Lister-Gasse already in graph, not added.
# running instance 332..
# Stop Flotowgasse already in graph, not added.
# running instance 333..
# Stop Flugfeldstraße already in graph, not added.
# running instance 334..
# Stop Flötzersteig already in graph, not added.
# running instance 335..
# Stop Flötzersteigbrücke already in graph, not added.
# running instance 336..
# Stop Hadersdorf Forstgarten already in graph, not added.
# running instance 337..
# Stop Forsthausgasse already in graph, not added.
# running instance 338..
# Stop Frachtenbahnhof Lobau Hafen already in graph, not added.
# running instance 339..
# Stop Franz-Asenbauer-Gasse already in graph, not added.
# running instance 340..
# Stop Franz-Josef-Spital already in graph, not added.
# running instance 341..
# Stop Franz-Josefs-Bahnhof already in graph, not added.
# running instance 342..
# Stop Krankenanstalt Rudolfstiftung already in graph, not added.
# running instance 343..
# Stop Franz-Pletersky-Weg already in graph, not added.
# running instance 344..
# Stop Franzensbrücke already in graph, not added.
# running instance 345..
# Stop Franzosenweg already in graph, not added.
# running instance 346..
# Stop Forchheimergasse already in graph, not added.
# running instance 347..
# Stop Freesienweg already in graph, not added.
# running instance 348..
# Stop Freiheitsplatz already in graph, not added.
# running instance 349..
# Stop Freihofsiedlung already in graph, not added.
# running instance 350..
# Stop Kraftwerk Freudenau already in graph, not added.
# running instance 351..
# Stop Freyenthurmgasse already in graph, not added.
# running instance 352..
# Stop Freytaggasse already in graph, not added.
# running instance 353..
# Stop Friedensbrücke already in graph, not added.
# running instance 354..
# Stop Baumgarten already in graph, not added.
# running instance 355..
# Stop Friedensgasse already in graph, not added.
# running instance 356..
# Stop Mariabrunn Kirche already in graph, not added.
# running instance 357..
# Stop Friedjunggasse already in graph, not added.
# running instance 358..
# Stop Friedlgasse already in graph, not added.
# running instance 359..
# Stop Friedrich-Engels-Platz already in graph, not added.
# running instance 360..
# Stop Friedstraße already in graph, not added.
# running instance 361..
# Stop Frödenplatz already in graph, not added.
# running instance 362..
# Stop Frömmlgasse already in graph, not added.
# running instance 363..
# Stop Fröschelgasse already in graph, not added.
# running instance 364..
# Stop Längenfeldgasse/Flurschützstr already in graph, not added.
# running instance 365..
# Stop Fultonstraße already in graph, not added.
# running instance 366..
# Stop Funkengerngasse already in graph, not added.
# running instance 367..
# Stop Seegasse already in graph, not added.
# running instance 368..
# Stop Gallitzinstraße already in graph, not added.
# running instance 369..
# Stop Kaltenleutgebner Straße 10/63 already in graph, not added.
# running instance 370..
# Stop Rodaun Gasthaus Maut already in graph, not added.
# running instance 371..
# Stop Gasthaus Zum Friedhof already in graph, not added.
# running instance 372..
# Stop Gatterburggasse already in graph, not added.
# running instance 373..
# Stop Gattergasse already in graph, not added.
# running instance 374..
# Stop Gatterhölzl already in graph, not added.
# running instance 375..
# Stop Gaudenzdorfer Gürtel already in graph, not added.
# running instance 376..
# Stop Gaußplatz already in graph, not added.
# running instance 377..
# Stop Gaßmannstraße already in graph, not added.
# running instance 378..
# Stop Geiereckstraße already in graph, not added.
# running instance 379..
# Stop Geistingergasse already in graph, not added.
# running instance 380..
# Stop Gellertplatz already in graph, not added.
# running instance 381..
# Stop Gemeindeberggasse already in graph, not added.
# running instance 382..
# Stop General-Motors-Werk already in graph, not added.
# running instance 383..
# Stop Genochplatz already in graph, not added.
# running instance 384..
# Stop Brünner Straße/Hanreitergasse already in graph, not added.
# running instance 385..
# Stop Gerhardusgasse already in graph, not added.
# running instance 386..
# Stop Geringergasse already in graph, not added.
# running instance 387..
# Stop Gernotgasse already in graph, not added.
# running instance 388..
# Stop Geroldgasse already in graph, not added.
# running instance 389..
# Stop Gersthof already in graph, not added.
# running instance 390..
# Stop Ehrenpreisgasse already in graph, not added.
# running instance 391..
# Stop Gersthofer Friedhof already in graph, not added.
# running instance 392..
# Stop Getreidemarkt already in graph, not added.
# running instance 393..
# Stop Geusaugasse already in graph, not added.
# running instance 394..
# Stop Zippererstraße already in graph, not added.
# running instance 395..
# Stop Heinrich-Drimmel-Platz already in graph, not added.
# running instance 396..
# Stop Ghelengasse already in graph, not added.
# running instance 397..
# Stop Gladiolenweg already in graph, not added.
# running instance 398..
# Stop Glanzing already in graph, not added.
# running instance 399..
# Stop Glatzgasse already in graph, not added.
# running instance 400..
# Stop Glawatschweg already in graph, not added.
# running instance 401..
# Stop Glockengasse already in graph, not added.
# running instance 402..
# Stop Gloriettegasse already in graph, not added.
# running instance 403..
# Stop Glossystraße already in graph, not added.
# running instance 404..
# Stop Gobergasse already in graph, not added.
# running instance 405..
# Stop Goethehof already in graph, not added.
# running instance 406..
# Stop Gogolgasse already in graph, not added.
# running instance 407..
# Stop Goldhammergasse already in graph, not added.
# running instance 408..
# Stop Gotthelfgasse already in graph, not added.
# running instance 409..
# Stop Graben/Petersplatz already in graph, not added.
# running instance 410..
# Stop Graf-Seilern-Gasse already in graph, not added.
# running instance 411..
# Stop Grasbergergasse already in graph, not added.
# running instance 412..
# Stop Grasgasse already in graph, not added.
# running instance 413..
# Stop Gredlerstraße already in graph, not added.
# running instance 414..
# Stop Gregor-Mendel-Straße already in graph, not added.
# running instance 415..
# Stop Gregorygasse already in graph, not added.
# running instance 416..
# Stop Greinzgasse already in graph, not added.
# running instance 417..
# Stop Greutberggasse already in graph, not added.
# running instance 418..
# Stop Griegstraße already in graph, not added.
# running instance 419..
# Stop Enkplatz already in graph, not added.
# running instance 420..
# Stop Grinzing already in graph, not added.
# running instance 421..
# Stop Am Bahnhof already in graph, not added.
# running instance 422..
# Stop Grinzinger Straße already in graph, not added.
# running instance 423..
# Stop Donaustadtstraße/Lange Allee already in graph, not added.
# running instance 424..
# Stop Großer Biberhaufen already in graph, not added.
# running instance 425..
# Stop Großjedlersdorf already in graph, not added.
# running instance 426..
# Stop Großmarktstraße already in graph, not added.
# running instance 427..
# Stop Gruschaplatz already in graph, not added.
# running instance 428..
# Stop Gräßlplatz already in graph, not added.
# running instance 429..
# Stop Gumpendorfer Straße already in graph, not added.
# running instance 430..
# Stop Grenzgasse already in graph, not added.
# running instance 431..
# Stop Guneschgasse already in graph, not added.
# running instance 432..
# Stop Gunoldstraße already in graph, not added.
# running instance 433..
# Stop Guntherstraße already in graph, not added.
# running instance 434..
# Stop Guntherstraße/Stadtgrenze already in graph, not added.
# running instance 435..
# Stop Gusenleithnergasse already in graph, not added.
# running instance 436..
# Stop Gustav-Pick-Gasse already in graph, not added.
# running instance 437..
# Stop Gutheil-Schoder-Gasse WLB already in graph, not added.
# running instance 438..
# Stop Gutraterplatz already in graph, not added.
# running instance 439..
# Stop Gußhausstraße already in graph, not added.
# running instance 440..
# Stop Gußriegelstraße already in graph, not added.
# running instance 441..
# Stop Gymnasiumstraße already in graph, not added.
# running instance 442..
# Stop Günselgasse already in graph, not added.
# running instance 443..
# Stop Dornbach, Güpferlingstraße already in graph, not added.
# running instance 444..
# Stop Gütenbachstraße already in graph, not added.
# running instance 445..
# Stop Gärtnerstraße already in graph, not added.
# running instance 446..
# Stop Haberditzlgasse already in graph, not added.
# running instance 447..
# Stop Haberlandtgasse already in graph, not added.
# running instance 448..
# Stop Neulerchenfelder Str/Haberlg already in graph, not added.
# running instance 449..
# Stop Habsburgergasse already in graph, not added.
# running instance 450..
# Stop Beingasse already in graph, not added.
# running instance 451..
# Stop Hadersdorfer Hauptstraße already in graph, not added.
# running instance 452..
# Stop Hadersdorf Bahnhof already in graph, not added.
# running instance 453..
# Stop Oberzellergasse already in graph, not added.
# running instance 454..
# Stop Stammersdorfer Kellergasse already in graph, not added.
# running instance 455..
# Stop 11. Haidequerstraße already in graph, not added.
# running instance 456..
# Stop 7. Haidequerstraße already in graph, not added.
# running instance 457..
# Stop Haidestraße already in graph, not added.
# running instance 458..
# Stop Dreherstraße already in graph, not added.
# running instance 459..
# Stop Eckpergasse already in graph, not added.
# running instance 460..
# Stop Halteraugasse already in graph, not added.
# running instance 461..
# Stop Halterlacken already in graph, not added.
# running instance 462..
# Stop Hans-Mandl-Berufsschule already in graph, not added.
# running instance 463..
# Stop Empergergasse already in graph, not added.
# running instance 464..
# Stop Hütteldorfer Str/Lützowgasse already in graph, not added.
# running instance 465..
# Stop Hardeggasse already in graph, not added.
# running instance 466..
# Stop Hardtgasse already in graph, not added.
# running instance 467..
# Stop Harrachgasse already in graph, not added.
# running instance 468..
# Stop Hartlebengasse already in graph, not added.
# running instance 469..
# Stop Haschafeld already in graph, not added.
# running instance 470..
# Stop Haselbrunnerstraße already in graph, not added.
# running instance 471..
# Stop Hasenleitengasse already in graph, not added.
# running instance 472..
# Stop Hasibederstraße already in graph, not added.
# running instance 473..
# Stop Hasnerstraße already in graph, not added.
# running instance 474..
# Stop Haspelmeistergasse already in graph, not added.
# running instance 475..
# Stop Haspingerplatz already in graph, not added.
# running instance 476..
# Stop Geiselbergstraße already in graph, not added.
# running instance 477..
# Stop Donaustadtstraße/Deinleingasse already in graph, not added.
# running instance 478..
# Stop Prater, Hauptallee already in graph, not added.
# running instance 479..
# Stop Hausfeldstraße already in graph, not added.
# running instance 480..
# Stop Dreimarkstein already in graph, not added.
# running instance 481..
# Stop Hawlicekgasse already in graph, not added.
# running instance 482..
# Stop Heiligenstadt already in graph, not added.
# running instance 483..
# Stop Eugen-Bormann-Gasse already in graph, not added.
# running instance 484..
# Stop Heiligenstädter Brücke already in graph, not added.
# running instance 485..
# Stop Taborstraße/Heinestraße already in graph, not added.
# running instance 486..
# Stop Siemensstr./H.-von-Buol-Gasse already in graph, not added.
# running instance 487..
# Stop Heizwerkstraße already in graph, not added.
# running instance 488..
# Stop Heldenplatz already in graph, not added.
# running instance 489..
# Stop Helferstorferstraße already in graph, not added.
# running instance 490..
# Stop Hellingstraße already in graph, not added.
# running instance 491..
# Stop Dresdner Straße already in graph, not added.
# running instance 492..
# Stop Henriettenplatz already in graph, not added.
# running instance 493..
# Stop Herbeckstraße already in graph, not added.
# running instance 494..
# Stop Heringgasse already in graph, not added.
# running instance 495..
# Stop Hermesstraße already in graph, not added.
# running instance 496..
# Stop Hernals already in graph, not added.
# running instance 497..
# Stop Herrengasse already in graph, not added.
# running instance 498..
# Stop Hernalser Gürtel already in graph, not added.
# running instance 499..
# Stop Hernalser Hauptstr/Wattgasse already in graph, not added.
# running instance 500..
# Stop Hertlgasse already in graph, not added.
# running instance 501..
# Stop Herzgasse already in graph, not added.
# running instance 502..
# Stop Hetzendorf already in graph, not added.
# running instance 503..
# Stop Hetzgasse already in graph, not added.
# running instance 504..
# Stop Heuberg Schutzhaus already in graph, not added.
# running instance 505..
# Stop Heuberggasse already in graph, not added.
# running instance 506..
# Stop Heudörfelgasse already in graph, not added.
# running instance 507..
# Stop Schönbr Str/Kettenbrückengasse already in graph, not added.
# running instance 508..
# Stop Hietzing already in graph, not added.
# running instance 509..
# Stop Obere Waldandacht already in graph, not added.
# running instance 510..
# Stop Hildebrandgasse already in graph, not added.
# running instance 511..
# Stop Hillerstraße already in graph, not added.
# running instance 512..
# Stop Himberger Straße already in graph, not added.
# running instance 513..
# Stop Himmelmutterweg already in graph, not added.
# running instance 514..
# Stop Himmelstraße already in graph, not added.
# running instance 515..
# Stop Hintere Zollamtsstraße already in graph, not added.
# running instance 516..
# Stop Am Krautgarten already in graph, not added.
# running instance 517..
# Stop Hirschengasse already in graph, not added.
# running instance 518..
# Stop Hirschstetten Ort already in graph, not added.
# running instance 519..
# Stop Blumengärten Hirschstetten already in graph, not added.
# running instance 520..
# Stop Hirschstetten already in graph, not added.
# running instance 521..
# Stop Fuchsienweg already in graph, not added.
# running instance 522..
# Stop Hütteldorfer Str/Hochsatzeng already in graph, not added.
# running instance 523..
# Stop Hoefftgasse already in graph, not added.
# running instance 524..
# Stop Hoferstiege already in graph, not added.
# running instance 525..
# Stop Hofherr-Schrantz-Gasse already in graph, not added.
# running instance 526..
# Stop Hofmannsthalgasse already in graph, not added.
# running instance 527..
# Stop Hofwiesengasse already in graph, not added.
# running instance 528..
# Stop Hohe Warte already in graph, not added.
# running instance 529..
# Stop Hohe-Wand-Wiese already in graph, not added.
# running instance 530..
# Stop Hohenbergstraße already in graph, not added.
# running instance 531..
# Stop Hohenfelsplatz already in graph, not added.
# running instance 532..
# Stop Hoher Markt already in graph, not added.
# running instance 533..
# Stop Hollergasse already in graph, not added.
# running instance 534..
# Stop Kollarzgasse already in graph, not added.
# running instance 535..
# Stop Holubstraße already in graph, not added.
# running instance 536..
# Stop Hopfengasse already in graph, not added.
# running instance 537..
# Stop Horeischygasse already in graph, not added.
# running instance 538..
# Stop Hosnedlgasse already in graph, not added.
# running instance 539..
# Stop Hoßplatz already in graph, not added.
# running instance 540..
# Stop Hubermanngasse already in graph, not added.
# running instance 541..
# Stop Hubert-Gsur-Gasse already in graph, not added.
# running instance 542..
# Stop Hubertusdamm already in graph, not added.
# running instance 543..
# Stop Huflattichweg already in graph, not added.
# running instance 544..
# Stop Huglgasse already in graph, not added.
# running instance 545..
# Stop Hugo-Wolf-Park already in graph, not added.
# running instance 546..
# Stop Unter St. Veit, Hummelgasse already in graph, not added.
# running instance 547..
# Stop Husarenweg already in graph, not added.
# running instance 548..
# Stop Hütteldorf already in graph, not added.
# running instance 549..
# Stop Pelargonienweg already in graph, not added.
# running instance 550..
# Stop Hütteldorfer Friedhof already in graph, not added.
# running instance 551..
# Stop Hüttenbrennergasse already in graph, not added.
# running instance 552..
# Stop Hüttergasse already in graph, not added.
# running instance 553..
# Stop Hämmerlegasse already in graph, not added.
# running instance 554..
# Stop Hänflingweg already in graph, not added.
# running instance 555..
# Stop Hänischgasse already in graph, not added.
# running instance 556..
# Stop Häußlergasse already in graph, not added.
# running instance 557..
# Stop Höchstädtplatz already in graph, not added.
# running instance 558..
# Stop Hödlgasse already in graph, not added.
# running instance 559..
# Stop Hörtengasse already in graph, not added.
# running instance 560..
# Stop Iberisweg already in graph, not added.
# running instance 561..
# Stop Illgasse already in graph, not added.
# running instance 562..
# Stop Liesing Industriegelände Süd already in graph, not added.
# running instance 563..
# Stop Industriegelände Liesing West already in graph, not added.
# running instance 564..
# Stop Innocentiagasse already in graph, not added.
# running instance 565..
# Stop Innstraße already in graph, not added.
# running instance 566..
# Stop Invalidensiedlung already in graph, not added.
# running instance 567..
# Stop Inzersdorf Friedhof already in graph, not added.
# running instance 568..
# Stop Inzersdorf Großmarkt already in graph, not added.
# running instance 569..
# Stop Blumental already in graph, not added.
# running instance 570..
# Stop Hosnedlgasse/Lieblgasse already in graph, not added.
# running instance 571..
# Stop Inzersdorf Personenbahnhof already in graph, not added.
# running instance 572..
# Stop Inzersdorf, Zetschegasse already in graph, not added.
# running instance 573..
# Stop Iselgasse already in graph, not added.
# running instance 574..
# Stop Oleandergasse already in graph, not added.
# running instance 575..
# Stop Jagdschloßgasse already in graph, not added.
# running instance 576..
# Stop Jahngasse already in graph, not added.
# running instance 577..
# Stop Jedlersdorf already in graph, not added.
# running instance 578..
# Stop Hosnedlgasse/Obachgasse already in graph, not added.
# running instance 579..
# Stop Jedlersdorfer Straße already in graph, not added.
# running instance 580..
# Stop Jedlesee already in graph, not added.
# running instance 581..
# Stop Jenbachgasse already in graph, not added.
# running instance 582..
# Stop Berresgasse already in graph, not added.
# running instance 583..
# Stop Joachimsthalerplatz already in graph, not added.
# running instance 584..
# Stop Jochbergengasse already in graph, not added.
# running instance 585..
# Stop Jochen-Rindt-Straße already in graph, not added.
# running instance 586..
# Stop Johann-Friedl-Gasse already in graph, not added.
# running instance 587..
# Stop Johannes-Krawarik-Gasse already in graph, not added.
# running instance 588..
# Stop Johann-Nepomuk-Berger-Platz already in graph, not added.
# running instance 589..
# Stop Johann-Pölzer-Gasse already in graph, not added.
# running instance 590..
# Stop Johann-Strauß-Gasse already in graph, not added.
# running instance 591..
# Stop Johanneskapelle already in graph, not added.
# running instance 592..
# Stop Johnstraße already in graph, not added.
# running instance 593..
# Stop Josef-Baumann-Gasse already in graph, not added.
# running instance 594..
# Stop Josef-Enslein-Platz already in graph, not added.
# running instance 595..
# Stop Josef-Gall-Gasse already in graph, not added.
# running instance 596..
# Stop Josef-Meder-Gasse already in graph, not added.
# running instance 597..
# Stop Josef-Melichar-Gasse already in graph, not added.
# running instance 598..
# Stop Josef-Ressel-Straße already in graph, not added.
# running instance 599..
# Stop Josef-Österreicher-Gasse already in graph, not added.
# running instance 600..
# Stop Elisabethwiese already in graph, not added.
# running instance 601..
# Stop Josefstädter Straße already in graph, not added.
# running instance 602..
# Stop Inzersdorfer Str/Ettenreichg already in graph, not added.
# running instance 603..
# Stop Julius-Payer-Gasse already in graph, not added.
# running instance 604..
# Stop Julius-Raab-Platz already in graph, not added.
# running instance 605..
# Stop Jungstraße already in graph, not added.
# running instance 606..
# Stop Jura-Soyfer-Gasse already in graph, not added.
# running instance 607..
# Stop Justgasse already in graph, not added.
# running instance 608..
# Stop Jüptnergasse already in graph, not added.
# running instance 609..
# Stop In der Au already in graph, not added.
# running instance 610..
# Stop Jägerwaldsiedlung already in graph, not added.
# running instance 611..
# Stop Kagran already in graph, not added.
# running instance 612..
# Stop Hagedornweg already in graph, not added.
# running instance 613..
# Stop Breitenleer Straße already in graph, not added.
# running instance 614..
# Stop Kagraner Anger already in graph, not added.
# running instance 615..
# Stop Kagraner Brücke already in graph, not added.
# running instance 616..
# Stop Kagraner Friedhof already in graph, not added.
# running instance 617..
# Stop Kagraner Platz already in graph, not added.
# running instance 618..
# Stop Kahlenberg already in graph, not added.
# running instance 619..
# Stop Kahlenbergerdorf already in graph, not added.
# running instance 620..
# Stop Korbweidenweg already in graph, not added.
# running instance 621..
# Stop Kaiser-Franz-Josef-Straße already in graph, not added.
# running instance 622..
# Stop Kaiserebersdorfer Friedhof already in graph, not added.
# running instance 623..
# Stop Kaiserebersdorf, Zinnergasse already in graph, not added.
# running instance 624..
# Stop Angelibad already in graph, not added.
# running instance 625..
# Stop Kaisermühlen-VIC already in graph, not added.
# running instance 626..
# Stop Kaisermühlenstraße already in graph, not added.
# running instance 627..
# Stop Kaiserstraße already in graph, not added.
# running instance 628..
# Stop Kaiserstraße/Burggasse already in graph, not added.
# running instance 629..
# Stop Kaiserstraße/Neustiftgasse already in graph, not added.
# running instance 630..
# Stop Kaiserstraße/Westbahnstraße already in graph, not added.
# running instance 631..
# Stop Kalksburg Kirchenplatz already in graph, not added.
# running instance 632..
# Stop Kammerergasse already in graph, not added.
# running instance 633..
# Stop Kanalstraße already in graph, not added.
# running instance 634..
# Stop Wulzendorfstraße/Kapellenweg already in graph, not added.
# running instance 635..
# Stop Kapellergasse already in graph, not added.
# running instance 636..
# Stop Kappgasse already in graph, not added.
# running instance 637..
# Stop Kardinal-Nagl-Platz already in graph, not added.
# running instance 638..
# Stop Karl-Meißl-Straße already in graph, not added.
# running instance 639..
# Stop Karl-Schwed-Gasse already in graph, not added.
# running instance 640..
# Stop Triester Straße/Karl-Tornay-G already in graph, not added.
# running instance 641..
# Stop Karlsplatz already in graph, not added.
# running instance 642..
# Stop Arsenal Objekt 5 already in graph, not added.
# running instance 643..
# Stop Karmeliterplatz already in graph, not added.
# running instance 644..
# Stop Karthäuserstraße already in graph, not added.
# running instance 645..
# Stop Kaserngasse already in graph, not added.
# running instance 646..
# Stop Haus des Meeres already in graph, not added.
# running instance 647..
# Stop Kellerberggasse already in graph, not added.
# running instance 648..
# Stop Kellermanngasse already in graph, not added.
# running instance 649..
# Stop Kempfengerngasse already in graph, not added.
# running instance 650..
# Stop Keplerplatz already in graph, not added.
# running instance 651..
# Stop Dreherstraße/Hoefftgasse already in graph, not added.
# running instance 652..
# Stop Kerbelgasse already in graph, not added.
# running instance 653..
# Stop Ottakringer Straße/Wattgasse already in graph, not added.
# running instance 654..
# Stop Kettenbrückengasse already in graph, not added.
# running instance 655..
# ...
# Stop Wahlberggasse added.
# running instance 1515..
# Stop Hüttelberg added.
# running instance 1516..
# Stop Steinböckeng/Freyenthurmgasse added.
# running instance 1517..
# Stop Marinekaserne added.
# running instance 1518..
# Stop Kalmusweg added.
# running instance 1519..
# Stop Sevcikgasse added.
# running instance 1520..
# Stop Jedlersdorfer Str/Hanreiterg added.
# running instance 1521..
# Stop Marchfeldkanal added.
# running instance 1522..
# Stop Kummergasse added.
# running instance 1523..
# Stop Josef-Flandorfer-Straße added.
# running instance 1524..
# Stop Birostraße/Jochen-Rindt-Straße added.
# running instance 1525..
# Stop Birostraße added.
# running instance 1526..
# Stop Jedlersdorfer Platz added.
# running instance 1527..
# Stop Dattlergasse added.
# running instance 1528..
# Stop Steinergasse added.
# running instance 1529..
# Stop Trondheimgasse added.
# running instance 1530..
# Stop Aspern, Oberdorfstraße added.
# running instance 1531..
# Stop Magdalenenstraße added.
# running instance 1532..
# Stop Stavangergasse added.
# running instance 1533..
# Stop Seidelbastgasse added.
# running instance 1534..
# Stop Heustadelgasse/Schule added.
# running instance 1535..
# Stop Hoechlegasse added.
# running instance 1536..
# Stop Jägermaiszufahrt added.
# running instance 1537..
# Stop Heustadelgasse added.
# running instance 1538..
# Stop Auspitzgasse added.
# running instance 1539..
# Stop Mühlau added.
# running instance 1540..
# Stop Leidlweg added.
# running instance 1541..
# Stop Dumreichergasse added.
# running instance 1542..
# Stop Arztgasse added.
# running instance 1543..
# Stop Haengasse added.
# running instance 1544..
# Stop Ultzmanngasse/Kirschenallee added.
# running instance 1545..
# Stop Goldregengasse added.
# running instance 1546..
# Stop Pilotengasse added.
# running instance 1547..
# Stop Reglergasse added.
# running instance 1548..
# Stop Kornblumenweg added.
# running instance 1549..
# Stop Aurikelweg added.
# running instance 1550..
# Stop Benjowskigasse added.
# running instance 1551..
# Stop Wachthausgasse added.
# running instance 1552..
# Stop Hauptstraße 150 added.
# running instance 1553..
# Stop Liechtensteinstr/Schottentor added.
# running instance 1554..
# Stop Emil-Behring-Weg added.
# running instance 1555..
# Stop Willergasse/Liesingbrücke added.
# running instance 1556..
# Stop Martin-Gaunersdorfer-Gasse added.
# running instance 1557..
# Stop Lichtentaler Gasse added.
# running instance 1558..
# Stop Linke Wienzeile/Brückengasse added.
# running instance 1559..
# Stop Mitterhofergasse added.
# running instance 1560..
# Stop Atzgersdorfer Str/Wundtgasse added.
# running instance 1561..
# Stop Seefeldergasse added.
# running instance 1562..
# Stop Otto-Weber-Gasse added.
# running instance 1563..
# Stop Possingergasse/Gablenzgasse added.
# running instance 1564..
# Stop Hütteldorfer Straße/Johnstraße added.
# running instance 1565..
# Stop Lorenz-Müller-Gasse added.
# running instance 1566..
# Stop Jägerstraße added.
# running instance 1567..
# Stop Neue Donau added.
# running instance 1568..
# Stop Pantucekgasse/Widholzgasse added.
# running instance 1569..
# Stop Leberberg added.
# running instance 1570..
# Stop Svetelskystraße added.
# running instance 1571..
# Stop Franz-Eduard-Matras-Gasse added.
# running instance 1572..
# Stop Theodor-Kramer-Straße added.
# running instance 1573..
# Stop Hochmuthgasse added.
# running instance 1574..
# Stop Rautenweg/Hermann-Gebauer-Str added.
# running instance 1575..
# Stop Hermann-Gebauer-Straße added.
# running instance 1576..
# Stop Edmund-Reim-Gasse added.
# running instance 1577..
# Stop Rothenburgstraße added.
# running instance 1578..
# Stop Hetzendorfer Straße added.
# running instance 1579..
# Stop Badeteich Hirschstetten added.
# running instance 1580..
# Stop Kolletschkagasse added.
# running instance 1581..
# Stop Hernalser Friedhof added.
# running instance 1582..
# Stop Kastanienallee added.
# running instance 1583..
# Stop Panethgasse/Sebaldgasse added.
# running instance 1584..
# Stop Weingartenallee added.
# running instance 1585..
# Stop Sportpark Süßenbrunn added.
# running instance 1586..
# Stop Kefedergrundgasse added.
# running instance 1587..
# Stop Flötzersteig/Wilhelminenspital added.
# running instance 1588..
# Stop Neu-Albern added.
# running instance 1589..
# Stop Allerheiligenplatz added.
# running instance 1590..
# Stop Klimschgasse added.
# running instance 1591..
# Stop Breitenfurter Str/Liesingbr added.
# running instance 1592..
# Stop Hackinger Straße added.
# running instance 1593..
# Stop Carabelligasse/Ruthnergasse added.
# running instance 1594..
# Stop Petrusgasse added.
# running instance 1595..
# Stop Leberweg added.
# running instance 1596..
# Stop Gewerbepark Stadlau Nord added.
# running instance 1597..
# Stop Gewerbepark Stadlau Süd added.
# running instance 1598..
# Stop Boschstraße/Halteraugasse added.
# running instance 1599..
# Stop Amtshaus Muthgasse added.
# running instance 1600..
# Stop Pasettistraße added.
# running instance 1601..
# Stop Handelskai added.
# running instance 1602..
# Stop Kalksburg Lodererweg added.
# running instance 1603..
# Stop Rossinigasse added.
# running instance 1604..
# Stop Mühlhäufelgasse added.
# running instance 1605..
# Stop Viktor-Wittner-Gasse added.
# running instance 1606..
# Stop Kaposigasse added.
# running instance 1607..
# Stop Kahlergasse added.
# running instance 1608..
# Stop Schanzstraße/Akkonplatz added.
# running instance 1609..
# Stop Holbeingasse added.
# running instance 1610..
# Stop Starhemberg-Kaserne added.
# running instance 1611..
# Stop Niedermoserstraße added.
# running instance 1612..
# Stop Spittelbreitengasse added.
# running instance 1613..
# Stop Siebeneichengasse added.
# running instance 1614..
# Stop Grundäckergasse added.
# running instance 1615..
# Stop Ernanigasse added.
# running instance 1616..
# Stop Seligmanngasse added.
# running instance 1617..
# Stop Simonsgasse added.
# running instance 1618..
# Stop Sechshauser Gürtel added.
# running instance 1619..
# Stop Edelsinnstraße/Schwenkgasse added.
# running instance 1620..
# Stop Basler Gasse added.
# running instance 1621..
# Stop Hainburger Straße added.
# running instance 1622..
# Stop Mantlergasse added.
# running instance 1623..
# Stop Zouvalgasse added.
# running instance 1624..
# Stop Donau-City Nord added.
# running instance 1625..
# Stop Verbindungsweg added.
# running instance 1626..
# Stop Donauturm added.
# running instance 1627..
# Stop Satzberggasse added.
# running instance 1628..
# Stop Tokiostraße added.
# running instance 1629..
# Stop Arakawastraße added.
# running instance 1630..
# Stop Veterinärmed. Universität added.
# running instance 1631..
# Stop Satzingerweg added.
# running instance 1632..
# Stop Zwerchäckerweg added.
# running instance 1633..
# Stop Martin-Luther-King-Park added.
# running instance 1634..
# Stop Südrandstraße/Heizwerkstraße added.
# running instance 1635..
# Stop Halban-Kurz-Straße added.
# running instance 1636..
# Stop Ferdinand-Frey-Weg added.
# running instance 1637..
# Stop Rendezvousberg added.
# running instance 1638..
# Stop Johannes-von-Gott-Platz added.
# running instance 1639..
# Stop Soldanellenweg added.
# running instance 1640..
# Stop Gasometer added.
# running instance 1641..
# Stop Hirschstettner Str/Gewerbepark added.
# running instance 1642..
# Stop Breitenlee Schule added.
# running instance 1643..
# Stop Franz-Schreker-Gasse added.
# running instance 1644..
# Stop Rudolf-Hausner-Gasse added.
# running instance 1645..
# Stop Antonsplatz added.
# running instance 1646..
# Stop Simmering/Kaiserebersd Str added.
# running instance 1647..
# Stop Gottschalkgasse/Enkplatz added.
# running instance 1648..
# Stop Savoyenstraße/Koenig-Promenade added.
# running instance 1649..
# Stop Stillfriedplatz added.
# running instance 1650..
# Stop Hertha-Firnberg-Straße added.
# running instance 1651..
# Stop Maria-Kuhn-Gasse added.
# running instance 1652..
# Stop Albert-Schultz-Halle added.
# running instance 1653..
# Stop Steinmüllergasse added.
# running instance 1654..
# Stop Umlauftgasse added.
# running instance 1655..
# Stop Rosenackerstraße added.
# running instance 1656..
# Stop Jenschikweg added.
# running instance 1657..
# Stop Spinozagasse added.
# running instance 1658..
# Stop Karl-Metschl-Gasse added.
# running instance 1659..
# Stop Nottendorfer Gasse added.
# running instance 1660..
# Stop Franzosengraben added.
# running instance 1661..
# Stop Skraupstraße/Justgasse added.
# running instance 1662..
# Stop Lackenjöchelgasse added.
# running instance 1663..
# Stop Ginsterweg added.
# running instance 1664..
# Stop Richard-Tauber-Gasse added.
# running instance 1665..
# Stop Breitenlee Schule/Schukowitzg added.
# running instance 1666..
# Stop Mühlweg added.
# running instance 1667..
# Stop Radnitzkygasse added.
# running instance 1668..
# Stop Kaiserebersdorf added.
# running instance 1669..
# Stop Undsetgasse added.
# running instance 1670..
# Stop Haus Föhrenhof added.
# running instance 1671..
# Stop Modecenterstraße added.
# running instance 1672..
# Stop Gewerbepark Stadlau Mitte added.
# running instance 1673..
# Stop Absbergbrücke added.
# running instance 1674..
# Stop Aspern Sportplatz added.
# running instance 1675..
# Stop Linzer Straße/Flötzersteig added.
# running instance 1676..
# Stop Linzer Straße/Bahnhofstraße added.
# running instance 1677..
# Stop Friedhofstraße added.
# running instance 1678..
# Stop Untere Kaistraße added.
# running instance 1679..
# Stop Franz-Koci-Straße added.
# running instance 1680..
# Stop Schmerlingplatz added.
# running instance 1681..
# Stop Am Heumarkt added.
# running instance 1682..
# Stop Jubiläumswarte added.
# running instance 1683..
# Stop Hotel NH Danube City added.
# running instance 1684..
# Stop Primavesigasse added.
# running instance 1685..
# Stop Stachegasse added.
# running instance 1686..
# Stop Höhenstraße/Rohrerwiese added.
# running instance 1687..
# Stop Stranitzkygasse added.
# running instance 1688..
# Stop Gloria-Theater added.
# running instance 1689..
# Stop Kurpark Nordosteingang added.
# running instance 1690..
# Stop Hederichgasse added.
# running instance 1691..
# Stop Burgenlandgasse added.
# running instance 1692..
# Stop Neuwaldegger Straße added.
# running instance 1693..
# Stop Kieslerweg added.
# running instance 1694..
# Stop Fuchsenzeile added.
# running instance 1695..
# Stop Süßenbr Str/Breitenleer Str added.
# running instance 1696..
# Stop Laimgrubengasse added.
# running instance 1697..
# Stop Akademietheater added.
# running instance 1698..
# Stop Im Gestockert added.
# running instance 1699..
# Stop Ährengrubenweg added.
# running instance 1700..
# Stop Carl-Appel-Straße added.
# running instance 1701..
# Stop Brantinggasse added.
# running instance 1702..
# Stop Pichelmayergasse added.
# running instance 1703..
# Stop Saligergasse/Kindergarten added.
# running instance 1704..
# Stop Saligergasse added.
# running instance 1705..
# Stop Schottenhof added.
# running instance 1706..
# Stop Hanslteich added.
# running instance 1707..
# Stop Zentralfriedh Kindergräber added.
# running instance 1708..
# Stop Haidersberggasse added.
# running instance 1709..
# Stop Korngoldgasse added.
# running instance 1710..
# Stop Zentralfriedhof Tor 11 added.
# running instance 1711..
# Stop Zentralfriedh Mahnmal 1938/45 added.
# running instance 1712..
# Stop Zentralfriedh Friedh-Gärtnerei added.
# running instance 1713..
# Stop Zentralfriedh Halle3/Gr 40 added.
# running instance 1714..
# Stop Zentralfriedh Gruppe 121 added.
# running instance 1715..
# Stop Zentralfriedh Gruppe 152 added.
# running instance 1716..
# Stop Zentralfriedh Gruppe 147 added.
# running instance 1717..
# Stop Zentralfriedh Gruppe 142 added.
# running instance 1718..
# Stop Zentralfriedh Gruppe 66 added.
# running instance 1719..
# Stop Zentralfriedh Gruppe 84 added.
# running instance 1720..
# Stop Zentralfriedh Tor 9/Gruppe 82 added.
# running instance 1721..
# Stop Zentralfriedh Kriegsgräber added.
# running instance 1722..
# Stop Zentralfriedh Kriegsgr 1.WK added.
# running instance 1723..
# Stop Zentralfriedh Gruppe 78 added.
# running instance 1724..
# Stop Zentralfriedh Gruppe 74 added.
# running instance 1725..
# Stop Zentralfriedh Gruppe 47 added.
# running instance 1726..
# Stop Zentralfriedh Gruppe 11 added.
# running instance 1727..
# Stop Phillipsgasse added.
# running instance 1728..
# Stop Weinzierlgasse added.
# running instance 1729..
# Stop Praterstern/Lassallestraße added.
# running instance 1730..
# Stop Döblinger Gürtel/Nußdorfer Str added.
# running instance 1731..
# Stop Breitenft Str/Hetzendorfer Str added.
# running instance 1732..
# Stop Franz-Sebek-Straße added.
# running instance 1733..
# Stop Hetzendorf S/Altmannsd Str added.
# running instance 1734..
# Stop Hanusch-Krankenhaus added.
# running instance 1735..
# Stop Zinnergasse/Kaserne added.
# running instance 1736..
# Stop Wienflußaufsicht added.
# running instance 1737..
# Stop Iselgasse/Illgasse added.
# running instance 1738..
# Stop Am Schöpfwerk/Eibesbrunnerg added.
# running instance 1739..
# Stop Aderklaaer Straße added.
# running instance 1740..
# Stop Großfeldsiedlung added.
# running instance 1741..
# Stop Rennbahnweg added.
# running instance 1742..
# Stop Kürschnergasse added.
# running instance 1743..
# Stop Eipeldauer Str/A-Sattler-Gasse added.
# running instance 1744..
# Stop Hirschstettner Straße added.
# running instance 1745..
# Stop Leopoldau/Möllplatz added.
# running instance 1746..
# Stop Weinheimergasse added.
# running instance 1747..
# Stop Stammersdf/Stammersdorfer Str added.
# running instance 1748..
# Stop Aspernallee/Schule added.
# running instance 1749..
# Stop Steinhagegasse added.
# running instance 1750..
# Stop Laxenburger Str/R-Tauber-Gasse added.
# running instance 1751..
# Stop Pierre-de-Coubertin-Platz added.
# running instance 1752..
# Stop Inzersd Str/Bernhardtstalgasse added.
# running instance 1753..
# Stop Kainachgasse added.
# running instance 1754..
# Stop Stadlauer Brücke added.
# running instance 1755..
# Stop Kleine Stadtgutgasse added.
# running instance 1756..
# Stop Volkertplatz added.
# running instance 1757..
# Stop Stella-Klein-Löw-Weg added.
# running instance 1758..
# Stop Pichlgasse added.
# running instance 1759..
# Stop Graben/Tuchlauben added.
# running instance 1760..
# Stop Margaretenstraße added.
# running instance 1761..
# Stop Taborstraße added.
# running instance 1762..
# Stop Messe-Prater added.
# running instance 1763..
# Stop Krieau added.
# running instance 1764..
# Stop Stadion added.
# running instance 1765..
# Stop Marathonweg added.
# running instance 1766..
# Stop Schipanygasse added.
# running instance 1767..
# Stop Leopold-Moses-Gasse added.
# running instance 1768..
# Stop Harkortstraße added.
# running instance 1769..
# Stop Radetzkystraße/Matthäusgasse added.
# running instance 1770..
# Stop Erlafstraße added.
# running instance 1771..
# Stop Wohlmutstraße added.
# running instance 1772..
# Stop Langenzersdorfer Straße added.
# running instance 1773..
# Stop Kafkastraße added.
# running instance 1774..
# Stop Molkereistraße added.
# running instance 1775..
# Stop Max-Winter-Platz added.
# running instance 1776..
# Stop Hotel Hilton Danube added.
# running instance 1777..
# Stop Wolfgang-Pauli-Gasse added.
# running instance 1778..
# Stop Herzmanskystraße added.
# running instance 1779..
# Stop Schloss Neugebäude added.
# running instance 1780..
# Stop Deinleingasse/Schule added.
# running instance 1781..
# Stop Tarifpunkt Simmering added.
# running instance 1782..
# Stop Leebgasse/Siccardsburggasse added.
# running instance 1783..
# Stop Anastasius-Grün-Gasse added.
# running instance 1784..
# Stop Tarifpunkt Kliebergasse added.
# running instance 1785..
# Stop Tarifpunkt Leopoldau added.
# running instance 1786..
# Stop Tarifpunkt Matzleinsdorfer Pl added.
# running instance 1787..
# Stop Betriebshof Favoriten added.
# running instance 1788..
# Stop Betriebshof Simmering added.
# running instance 1789..
# Stop Zimmermannplatz added.
# running instance 1790..
# Stop Betriebshof Speising added.
# running instance 1791..
# Stop Betriebshof Rudolfsheim added.
# running instance 1792..
# Stop Betriebshof Ottakring added.
# running instance 1793..
# Stop Betriebshof Hernals added.
# running instance 1794..
# Stop Betriebshof Gürtel added.
# running instance 1795..
# Stop Betriebshof Brigittenau added.
# running instance 1796..
# Stop Betriebshof Floridsdorf added.
# running instance 1797..
# Stop Betriebshof Kagran added.
# running instance 1798..
# Stop Betriebshof Spetterbrücke added.
# running instance 1799..
# Stop Betriebshof Raxstraße added.
# running instance 1800..
# Stop Betriebshof Leopoldau added.
# running instance 1801..
# Stop   added.
# running instance 1802..
# Stop   added.
# running instance 1803..
# Stop   added.
# running instance 1804..
# Stop   added.
# running instance 1805..
# Stop   added.
# running instance 1806..
# Stop   added.
# running instance 1807..
# Stop   added.

# %% [markdown]
# ## Add connections from Stops to the corresponding lines (U6, 13A, 62, ..)

# %%
def classify_line(line_name):
    # Check if line starts with "U" followed by a digit 1-6 for metro
    if line_name.startswith("U") and len(line_name) > 1 and line_name[1].isdigit() and 1 <= int(line_name[1]) <= 6:
        return "metro"
    
    # Check if line is a single character from the German alphabet or a digit below 75 for tram
    if (line_name.isalpha() and len(line_name) == 1) or (line_name.isdigit() and int(line_name) < 75):
        return "tram"
    
    # Check if line starts with a digit below 100 followed by "A" or "B" for bus
    if (len(line_name) > 1 and line_name[:-1].isdigit() and int(line_name[:-1]) < 100 and line_name[-1] in ['A', 'B']) or (line_name.isdigit() and int(line_name) >= 100):
        return "bus"
    
    # Check if line starts with "N" for night bus
    if line_name.startswith("N"):
        return "nightbus"
    
    # Default case
    return "NA"

# %%
def process_stop_lines(csv_file):
    count = 1
    with open(csv_file, 'r') as file:
        reader = csv.DictReader(file)
        for row in reader:
            print(f"run {count}")
            count=count+1

            stop_name = row['HTXT'].strip()
            lines = row['HLINIEN'].split(", ")
            
            # Find the Stop node by name
            stop_node = Stop.nodes.get_or_none(name=stop_name)
            if not stop_node:
                print(f"Stop {stop_name} NOT FOUND in the database.")
                continue
            
            # Process each line in HLINIEN
            for line_name in lines:
                # Create or get the Line node
                line_node = Line.nodes.get_or_none(name=line_name)  # Assign default type, update as needed

                if not line_node:
                    line_type = classify_line(line_name)

                    line_node = Line(
                        name = line_name, 
                        type = line_type
                    ).save()
                    print(f"Line {line_name} ADDED.")

                    if line_type == "NA":
                        print(f'line_type of {line_name} NOT KNOWN!')

                else:
                    print(f"Line {line_name} ALREADY EXISTED.")
                
                # Create the relationship from Stop to Line
                if not stop_node.has_line.is_connected(line_node):
                    stop_node.has_line.connect(line_node)
                    print(f"Line {line_name} at stop {stop_name} ADDED.")
                else:
                    print(f"Line {line_name} at stop {stop_name} ALREADY EXISTED.")

process_stop_lines(lines_paths)
# Out:
# run 1
# Line N71 ALREADY EXISTED.
# Line N71 at stop Molitorgasse ALREADY EXISTED.
# run 2
# Line 71 ALREADY EXISTED.
# Line 71 at stop Molitorgasse ALREADY EXISTED.
# run 3
# Line N71 ALREADY EXISTED.
# Line N71 at stop Molitorgasse ALREADY EXISTED.
# run 4
# Line N71 ALREADY EXISTED.
# Line N71 at stop Molitorgasse ALREADY EXISTED.
# run 5
# Line 71 ALREADY EXISTED.
# Line 71 at stop Molitorgasse ALREADY EXISTED.
# run 6
# Line 13A ALREADY EXISTED.
# Line 13A at stop Mommsengasse ALREADY EXISTED.
# run 7
# Line 450 ALREADY EXISTED.
# Line 450 at stop Mondweg ALREADY EXISTED.
# Line 50B ALREADY EXISTED.
# Line 50B at stop Mondweg ALREADY EXISTED.
# Line 49A ALREADY EXISTED.
# Line 49A at stop Mondweg ALREADY EXISTED.
# run 8
# Line 450 ALREADY EXISTED.
# Line 450 at stop Mondweg ALREADY EXISTED.
# Line 50B ALREADY EXISTED.
# Line 50B at stop Mondweg ALREADY EXISTED.
# Line 49A ALREADY EXISTED.
# Line 49A at stop Mondweg ALREADY EXISTED.
# run 9
# Line 450 ALREADY EXISTED.
# Line 450 at stop Mondweg ALREADY EXISTED.
# Line 49A ALREADY EXISTED.
# Line 49A at stop Mondweg ALREADY EXISTED.
# run 10
# Line 450 ALREADY EXISTED.
# Line 450 at stop Mondweg ALREADY EXISTED.
# Line 49A ALREADY EXISTED.
# Line 49A at stop Mondweg ALREADY EXISTED.
# run 11
# Line 58A ALREADY EXISTED.
# Line 58A at stop Montecuccoliplatz ALREADY EXISTED.
# Line 56A ALREADY EXISTED.
# Line 56A at stop Montecuccoliplatz ALREADY EXISTED.
# Line 56B ALREADY EXISTED.
# Line 56B at stop Montecuccoliplatz ALREADY EXISTED.
# Line 58B ALREADY EXISTED.
# Line 58B at stop Montecuccoliplatz ALREADY EXISTED.
# run 12
# Line 8A ALREADY EXISTED.
# Line 8A at stop Montecuccoliplatz ALREADY EXISTED.
# run 13
# Line 58A ALREADY EXISTED.
# Line 58A at stop Montecuccoliplatz ALREADY EXISTED.
# Line 56A ALREADY EXISTED.
# Line 56A at stop Montecuccoliplatz ALREADY EXISTED.
# Line 56B ALREADY EXISTED.
# Line 56B at stop Montecuccoliplatz ALREADY EXISTED.
# Line 58B ALREADY EXISTED.
# Line 58B at stop Montecuccoliplatz ALREADY EXISTED.
# run 14
# Line 8A ALREADY EXISTED.
# Line 8A at stop Montecuccoliplatz ALREADY EXISTED.
# run 15
# Line 51A ALREADY EXISTED.
# Line 51A at stop Montleartstraße ALREADY EXISTED.
# run 16
# Line 51A ALREADY EXISTED.
# Line 51A at stop Montleartstraße ALREADY EXISTED.
# run 17
# Line 44A ALREADY EXISTED.
# Line 44A at stop Moosgasse ALREADY EXISTED.
# run 18
# Line 5B ALREADY EXISTED.
# Line 5B at stop Mooslackengasse ALREADY EXISTED.
# Line 11A ALREADY EXISTED.
# Line 11A at stop Mooslackengasse ALREADY EXISTED.
# run 19
# Line 453 ALREADY EXISTED.
# Line 453 at stop Mooswiesengasse ALREADY EXISTED.
# Line 451 ALREADY EXISTED.
# Line 451 at stop Mooswiesengasse ALREADY EXISTED.
# run 20
# Line 451 ALREADY EXISTED.
# Line 451 at stop Mooswiesengasse ALREADY EXISTED.
# run 21
# Line N25 ALREADY EXISTED.
# Line N25 at stop Moritz-Dreger-Gasse ALREADY EXISTED.
# Line 29A ALREADY EXISTED.
# Line 29A at stop Moritz-Dreger-Gasse ALREADY EXISTED.
# run 22
# Line N25 ALREADY EXISTED.
# Line N25 at stop Moritz-Dreger-Gasse ALREADY EXISTED.
# run 23
# Line N25 ALREADY EXISTED.
# Line N25 at stop Moritz-Dreger-Gasse ALREADY EXISTED.
# run 24
# Line 29A ALREADY EXISTED.
# Line 29A at stop Moritz-Dreger-Gasse ALREADY EXISTED.
# run 25
# Line 29B ALREADY EXISTED.
# Line 29B at stop Moritz-Dreger-Gasse ALREADY EXISTED.
# Line N25 ALREADY EXISTED.
# Line N25 at stop Moritz-Dreger-Gasse ALREADY EXISTED.
# run 26
# Line N25 ALREADY EXISTED.
# Line N25 at stop Moritz-Dreger-Gasse ALREADY EXISTED.
# run 27
# Line N25 ALREADY EXISTED.
# Line N25 at stop Moritz-Dreger-Gasse ALREADY EXISTED.
# run 28
# Line 29B ALREADY EXISTED.
# Line 29B at stop Moritz-Dreger-Gasse ALREADY EXISTED.
# run 29
# Line 52A ALREADY EXISTED.
# Line 52A at stop Moschingergasse ALREADY EXISTED.
# run 30
# Line 62 ALREADY EXISTED.
# Line 62 at stop Murlingengasse ALREADY EXISTED.
# run 31
# Line 95A ALREADY EXISTED.
# Line 95A at stop Murraygasse ALREADY EXISTED.
# Line N24 ALREADY EXISTED.
# Line N24 at stop Murraygasse ALREADY EXISTED.
# Line N23 ALREADY EXISTED.
# Line N23 at stop Murraygasse ALREADY EXISTED.
# Line 95B ALREADY EXISTED.
# Line 95B at stop Murraygasse ALREADY EXISTED.
# run 32
# Line N24 ALREADY EXISTED.
# Line N24 at stop Murraygasse ALREADY EXISTED.
# Line N23 ALREADY EXISTED.
# Line N23 at stop Murraygasse ALREADY EXISTED.
# run 33
# Line N24 ALREADY EXISTED.
# Line N24 at stop Murraygasse ALREADY EXISTED.
# Line N23 ALREADY EXISTED.
# Line N23 at stop Murraygasse ALREADY EXISTED.
# run 34
# Line N24 ALREADY EXISTED.
# Line N24 at stop Murraygasse ALREADY EXISTED.
# Line N23 ALREADY EXISTED.
# Line N23 at stop Murraygasse ALREADY EXISTED.
# run 35
# Line N24 ALREADY EXISTED.
# Line N24 at stop Murraygasse ALREADY EXISTED.
# Line N23 ALREADY EXISTED.
# Line N23 at stop Murraygasse ALREADY EXISTED.
# run 36
# Line 95A ALREADY EXISTED.
# Line 95A at stop Murraygasse ALREADY EXISTED.
# Line N23 ALREADY EXISTED.
# Line N23 at stop Murraygasse ALREADY EXISTED.
# Line 95B ALREADY EXISTED.
# Line 95B at stop Murraygasse ALREADY EXISTED.
# run 37
# Line N23 ALREADY EXISTED.
# Line N23 at stop Murraygasse ALREADY EXISTED.
# run 38
# Line N23 ALREADY EXISTED.
# Line N23 at stop Murraygasse ALREADY EXISTED.
# run 39
# Line 5B ALREADY EXISTED.
# Line 5B at stop Muthgasse ALREADY EXISTED.
# Line 11A ALREADY EXISTED.
# Line 11A at stop Muthgasse ALREADY EXISTED.
# run 40
# Line 66A ALREADY EXISTED.
# Line 66A at stop Mühlbreiten ALREADY EXISTED.
# Line 60A ALREADY EXISTED.
# Line 60A at stop Mühlbreiten ALREADY EXISTED.
# Line N66 ALREADY EXISTED.
# Line N66 at stop Mühlbreiten ALREADY EXISTED.
# Line 64A ALREADY EXISTED.
# Line 64A at stop Mühlbreiten ALREADY EXISTED.
# run 41
# Line N66 ALREADY EXISTED.
# Line N66 at stop Mühlbreiten ALREADY EXISTED.
# run 42
# Line N66 ALREADY EXISTED.
# Line N66 at stop Mühlbreiten ALREADY EXISTED.
# run 43
# Line 66A ALREADY EXISTED.
# Line 66A at stop Mühlbreiten ALREADY EXISTED.
# Line 60A ALREADY EXISTED.
# Line 60A at stop Mühlbreiten ALREADY EXISTED.
# Line N66 ALREADY EXISTED.
# Line N66 at stop Mühlbreiten ALREADY EXISTED.
# Line 64A ALREADY EXISTED.
# Line 64A at stop Mühlbreiten ALREADY EXISTED.
# run 44
# Line N66 ALREADY EXISTED.
# Line N66 at stop Mühlbreiten ALREADY EXISTED.
# run 45
# Line N66 ALREADY EXISTED.
# Line N66 at stop Mühlbreiten ALREADY EXISTED.
# run 46
# Line O ALREADY EXISTED.
# Line O at stop Mühlfeldgasse ALREADY EXISTED.
# Line 71 ALREADY EXISTED.
# Line 71 at stop Mühlfeldgasse ALREADY EXISTED.
# Line 2 ALREADY EXISTED.
# Line 2 at stop Mühlfeldgasse ALREADY EXISTED.
# Line 5 ALREADY EXISTED.
# Line 5 at stop Mühlfeldgasse ALREADY EXISTED.
# run 47
# Line 88B ALREADY EXISTED.
# Line 88B at stop Mühlhäufel ALREADY EXISTED.
# run 48
# Line N91 ALREADY EXISTED.
# Line N91 at stop Mühlhäufelweg ALREADY EXISTED.
# run 49
# Line N91 ALREADY EXISTED.
# Line N91 at stop Mühlhäufelweg ALREADY EXISTED.
# run 50
# Line 71B ALREADY EXISTED.
# Line 71B at stop Mühlsangergasse ALREADY EXISTED.
# Line 73A ALREADY EXISTED.
# Line 73A at stop Mühlsangergasse ALREADY EXISTED.
# run 51
# Line 71B ALREADY EXISTED.
# Line 71B at stop Mühlsangergasse ALREADY EXISTED.
# Line N71 ALREADY EXISTED.
# Line N71 at stop Mühlsangergasse ALREADY EXISTED.
# Line 73A ALREADY EXISTED.
# Line 73A at stop Mühlsangergasse ALREADY EXISTED.
# run 52
# Line N71 ALREADY EXISTED.
# Line N71 at stop Mühlsangergasse ALREADY EXISTED.
# run 53
# Line N71 ALREADY EXISTED.
# Line N71 at stop Mühlsangergasse ALREADY EXISTED.
# run 54
# Line 95A ALREADY EXISTED.
# Line 95A at stop Mühlwasser ALREADY EXISTED.
# Line 93A ALREADY EXISTED.
# Line 93A at stop Mühlwasser ALREADY EXISTED.
# Line N91 ALREADY EXISTED.
# Line N91 at stop Mühlwasser ALREADY EXISTED.
# run 55
# Line N91 ALREADY EXISTED.
# Line N91 at stop Mühlwasser ALREADY EXISTED.
# run 56
# Line N91 ALREADY EXISTED.
# Line N91 at stop Mühlwasser ALREADY EXISTED.
# run 57
# Line N91 ALREADY EXISTED.
# Line N91 at stop Mühlwasser ALREADY EXISTED.
# run 58
# Line N91 ALREADY EXISTED.
# Line N91 at stop Mühlwasser ALREADY EXISTED.
# run 59
# Line 93A ALREADY EXISTED.
# Line 93A at stop Mühlwasser ALREADY EXISTED.
# Line N91 ALREADY EXISTED.
# Line N91 at stop Mühlwasser ALREADY EXISTED.
# run 60
# Line N91 ALREADY EXISTED.
# Line N91 at stop Mühlwasser ALREADY EXISTED.
# run 61
# Line N91 ALREADY EXISTED.
# Line N91 at stop Mühlwasser ALREADY EXISTED.
# run 62
# Line N91 ALREADY EXISTED.
# Line N91 at stop Mühlwasser ALREADY EXISTED.
# run 63
# Line N91 ALREADY EXISTED.
# Line N91 at stop Mühlwasser ALREADY EXISTED.
# run 64
# Line 93A ALREADY EXISTED.
# Line 93A at stop Mühlwasserstraße ALREADY EXISTED.
# Line 92A ALREADY EXISTED.
# Line 92A at stop Mühlwasserstraße ALREADY EXISTED.
# Line N91 ALREADY EXISTED.
# Line N91 at stop Mühlwasserstraße ALREADY EXISTED.
# run 65
# Line N91 ALREADY EXISTED.
# Line N91 at stop Mühlwasserstraße ALREADY EXISTED.
# run 66
# Line N91 ALREADY EXISTED.
# Line N91 at stop Mühlwasserstraße ALREADY EXISTED.
# run 67
# Line N91 ALREADY EXISTED.
# Line N91 at stop Mühlwasserstraße ALREADY EXISTED.
# run 68
# Line N91 ALREADY EXISTED.
# Line N91 at stop Mühlwasserstraße ALREADY EXISTED.
# run 69
# Line 93A ALREADY EXISTED.
# Line 93A at stop Mühlwasserstraße ALREADY EXISTED.
# Line 92A ALREADY EXISTED.
# Line 92A at stop Mühlwasserstraße ALREADY EXISTED.
# Line N91 ALREADY EXISTED.
# Line N91 at stop Mühlwasserstraße ALREADY EXISTED.
# run 70
# Line N91 ALREADY EXISTED.
# Line N91 at stop Mühlwasserstraße ALREADY EXISTED.
# run 71
# Line N91 ALREADY EXISTED.
# Line N91 at stop Mühlwasserstraße ALREADY EXISTED.
# run 72
# Line N91 ALREADY EXISTED.
# Line N91 at stop Mühlwasserstraße ALREADY EXISTED.
# run 73
# Line N91 ALREADY EXISTED.
# Line N91 at stop Mühlwasserstraße ALREADY EXISTED.
# run 74
# Stop Hauptbahnhof Ost NOT FOUND in the database.
# run 75
# Stop Hauptbahnhof Ost NOT FOUND in the database.
# run 76
# Stop Pensionistenwohnhaus Hetzendorf NOT FOUND in the database.
# run 77
# Stop Pensionistenwohnhaus Hetzendorf NOT FOUND in the database.
# run 78
# Stop Kaiserebersdorf, Münnichplatz NOT FOUND in the database.
# run 79
# Stop Kaiserebersdorf, Münnichplatz NOT FOUND in the database.
# run 80
# Line 15A ALREADY EXISTED.
# Line 15A at stop Männertreugasse ALREADY EXISTED.
# run 81
# Line 15A ALREADY EXISTED.
# Line 15A at stop Männertreugasse ALREADY EXISTED.
# run 82
# Line 10 ALREADY EXISTED.
# Line 10 at stop Reinlgasse/Märzstraße ALREADY EXISTED.
# run 83
# Line 10 ALREADY EXISTED.
# Line 10 at stop Reinlgasse/Märzstraße ALREADY EXISTED.
# run 84
# Stop Aspern Nord NOT FOUND in the database.
# run 85
# Stop Aspern Nord NOT FOUND in the database.
# run 86
# Stop Aspern Nord NOT FOUND in the database.
# run 87
# Stop Aspern Nord NOT FOUND in the database.
# run 88
# Stop Aspern Nord NOT FOUND in the database.
# run 89
# Stop Aspern Nord NOT FOUND in the database.
# run 90
# Stop Aspern Nord NOT FOUND in the database.
# run 91
# Stop Aspern Nord NOT FOUND in the database.
# run 92
# Line 10A ALREADY EXISTED.
# Line 10A at stop Johnstraße/Märzstraße ALREADY EXISTED.
# run 93
# Line 10A ALREADY EXISTED.
# Line 10A at stop Johnstraße/Märzstraße ALREADY EXISTED.
# run 94
# Line N91 ALREADY EXISTED.
# Line N91 at stop Naufahrtbrücke ALREADY EXISTED.
# run 95
# Line N29 ALREADY EXISTED.
# Line N29 at stop Leystraße ALREADY EXISTED.
# run 96
# Line N29 ALREADY EXISTED.
# Line N29 at stop Leystraße ALREADY EXISTED.
# run 97
# Line 16A ALREADY EXISTED.
# Line 16A at stop Lichtensterngasse ALREADY EXISTED.
# run 98
# Line 16A ALREADY EXISTED.
# Line 16A at stop Lichtensterngasse ALREADY EXISTED.
# run 99
# Line 46 ALREADY EXISTED.
# Line 46 at stop Thaliastraße/Haberlgasse ALREADY EXISTED.
# run 100
# Line N46 ALREADY EXISTED.
# Line N46 at stop Thaliastraße/Haberlgasse ALREADY EXISTED.
# run 101
# Line N46 ALREADY EXISTED.
# Line N46 at stop Thaliastraße/Haberlgasse ALREADY EXISTED.
# run 102
# Line 46 ALREADY EXISTED.
# Line 46 at stop Thaliastraße/Haberlgasse ALREADY EXISTED.
# run 103
# Line N46 ALREADY EXISTED.
# Line N46 at stop Thaliastraße/Haberlgasse ALREADY EXISTED.
# run 104
# Line N46 ALREADY EXISTED.
# Line N46 at stop Thaliastraße/Haberlgasse ALREADY EXISTED.
# run 105
# Line 10 ALREADY EXISTED.
# Line 10 at stop Liebknechtgasse ALREADY EXISTED.
# Line 2 ALREADY EXISTED.
# Line 2 at stop Liebknechtgasse ALREADY EXISTED.
# run 106
# Line 10 ALREADY EXISTED.
# Line 10 at stop Liebknechtgasse ALREADY EXISTED.
# Line 2 ALREADY EXISTED.
# Line 2 at stop Liebknechtgasse ALREADY EXISTED.
# run 107
# Line 25A ALREADY EXISTED.
# Line 25A at stop Tillmanngasse ALREADY EXISTED.
# run 108
# Line N25 ALREADY EXISTED.
# Line N25 at stop Tillmanngasse ALREADY EXISTED.
# run 109
# Line N25 ALREADY EXISTED.
# Line N25 at stop Tillmanngasse ALREADY EXISTED.
# run 110
# Line 25A ALREADY EXISTED.
# Line 25A at stop Tillmanngasse ALREADY EXISTED.
# run 111
# Line N25 ALREADY EXISTED.
# Line N25 at stop Tillmanngasse ALREADY EXISTED.
# Line 25A ALREADY EXISTED.
# Line 25A at stop Tillmanngasse ALREADY EXISTED.
# run 112
# Line N25 ALREADY EXISTED.
# Line N25 at stop Tillmanngasse ALREADY EXISTED.
# run 113
# Line N25 ALREADY EXISTED.
# Line N25 at stop Tillmanngasse ALREADY EXISTED.
# run 114
# Line D ALREADY EXISTED.
# Line D at stop Liechtenwerder Platz ALREADY EXISTED.
# run 115
# Line N8 ALREADY EXISTED.
# Line N8 at stop Liechtenwerder Platz ALREADY EXISTED.
# Line N35 ALREADY EXISTED.
# Line N35 at stop Liechtenwerder Platz ALREADY EXISTED.
# Line N38 ALREADY EXISTED.
# Line N38 at stop Liechtenwerder Platz ALREADY EXISTED.
# Line N36 ALREADY EXISTED.
# Line N36 at stop Liechtenwerder Platz ALREADY EXISTED.
# run 116
# Line N8 ALREADY EXISTED.
# Line N8 at stop Liechtenwerder Platz ALREADY EXISTED.
# Line N35 ALREADY EXISTED.
# Line N35 at stop Liechtenwerder Platz ALREADY EXISTED.
# Line N38 ALREADY EXISTED.
# Line N38 at stop Liechtenwerder Platz ALREADY EXISTED.
# Line N36 ALREADY EXISTED.
# Line N36 at stop Liechtenwerder Platz ALREADY EXISTED.
# run 117
# Line N8 ALREADY EXISTED.
# Line N8 at stop Liechtenwerder Platz ALREADY EXISTED.
# Line N35 ALREADY EXISTED.
# Line N35 at stop Liechtenwerder Platz ALREADY EXISTED.
# Line N38 ALREADY EXISTED.
# Line N38 at stop Liechtenwerder Platz ALREADY EXISTED.
# Line N36 ALREADY EXISTED.
# Line N36 at stop Liechtenwerder Platz ALREADY EXISTED.
# run 118
# Line N8 ALREADY EXISTED.
# Line N8 at stop Liechtenwerder Platz ALREADY EXISTED.
# Line N35 ALREADY EXISTED.
# Line N35 at stop Liechtenwerder Platz ALREADY EXISTED.
# Line N38 ALREADY EXISTED.
# Line N38 at stop Liechtenwerder Platz ALREADY EXISTED.
# Line N36 ALREADY EXISTED.
# Line N36 at stop Liechtenwerder Platz ALREADY EXISTED.
# run 119
# Line N8 ALREADY EXISTED.
# Line N8 at stop Liechtenwerder Platz ALREADY EXISTED.
# Line N35 ALREADY EXISTED.
# Line N35 at stop Liechtenwerder Platz ALREADY EXISTED.
# Line N38 ALREADY EXISTED.
# Line N38 at stop Liechtenwerder Platz ALREADY EXISTED.
# Line N36 ALREADY EXISTED.
# Line N36 at stop Liechtenwerder Platz ALREADY EXISTED.
# run 120
# Line D ALREADY EXISTED.
# Line D at stop Liechtenwerder Platz ALREADY EXISTED.
# run 121
# Line 98A ALREADY EXISTED.
# Line 98A at stop Lieglerstraße ALREADY EXISTED.
# run 122
# Line 66A ALREADY EXISTED.
# Line 66A at stop Liesing ALREADY EXISTED.
# Line N66 ALREADY EXISTED.
# Line N66 at stop Liesing ALREADY EXISTED.
# run 123
# Line N66 ALREADY EXISTED.
# Line N66 at stop Liesing ALREADY EXISTED.
# run 124
# Line N66 ALREADY EXISTED.
# Line N66 at stop Liesing ALREADY EXISTED.
# run 125
# Line 207 ALREADY EXISTED.
# Line 207 at stop Liesing ALREADY EXISTED.
# Line 61B ALREADY EXISTED.
# Line 61B at stop Liesing ALREADY EXISTED.
# run 126
# Line 207 ALREADY EXISTED.
# Line 207 at stop Liesing ALREADY EXISTED.
# Line 61B ALREADY EXISTED.
# Line 61B at stop Liesing ALREADY EXISTED.
# run 127
# Line 64A ALREADY EXISTED.
# Line 64A at stop Liesing ALREADY EXISTED.
# run 128
# Line 255 ALREADY EXISTED.
# Line 255 at stop Liesing ALREADY EXISTED.
# run 129
# Line 62A ALREADY EXISTED.
# Line 62A at stop Liesing ALREADY EXISTED.
# Line N65 ALREADY EXISTED.
# Line N65 at stop Liesing ALREADY EXISTED.
# run 130
# Line N65 ALREADY EXISTED.
# Line N65 at stop Liesing ALREADY EXISTED.
# run 131
# Line N65 ALREADY EXISTED.
# Line N65 at stop Liesing ALREADY EXISTED.
# run 132
# Line 259 ALREADY EXISTED.
# Line 259 at stop Liesing ALREADY EXISTED.
# Line 256 ALREADY EXISTED.
# Line 256 at stop Liesing ALREADY EXISTED.
# Line SV510 ALREADY EXISTED.
# Line SV510 at stop Liesing ALREADY EXISTED.
# Line 257 ALREADY EXISTED.
# Line 257 at stop Liesing ALREADY EXISTED.
# Line 258 ALREADY EXISTED.
# Line 258 at stop Liesing ALREADY EXISTED.
# run 133
# Line 253 ALREADY EXISTED.
# Line 253 at stop Liesing ALREADY EXISTED.
# Line 250 ALREADY EXISTED.
# Line 250 at stop Liesing ALREADY EXISTED.
# run 134
# Line 60A ALREADY EXISTED.
# Line 60A at stop Liesing ALREADY EXISTED.
# Line N61 ALREADY EXISTED.
# Line N61 at stop Liesing ALREADY EXISTED.
# run 135
# Line N61 ALREADY EXISTED.
# Line N61 at stop Liesing ALREADY EXISTED.
# run 136
# Line N61 ALREADY EXISTED.
# Line N61 at stop Liesing ALREADY EXISTED.
# run 137
# Line N61 ALREADY EXISTED.
# Line N61 at stop Liesing ALREADY EXISTED.
# run 138
# Line N29 ALREADY EXISTED.
# Line N29 at stop Leystraße ALREADY EXISTED.
# Line 5A ALREADY EXISTED.
# Line 5A at stop Leystraße ALREADY EXISTED.
# Line 11A ALREADY EXISTED.
# Line 11A at stop Leystraße ALREADY EXISTED.
# run 139
# Line N61 ALREADY EXISTED.
# Line N61 at stop Liesing ALREADY EXISTED.
# run 140
# Line 259 ALREADY EXISTED.
# Line 259 at stop Liesing ALREADY EXISTED.
# Line 253 ALREADY EXISTED.
# Line 253 at stop Liesing ALREADY EXISTED.
# Line 250 ALREADY EXISTED.
# Line 250 at stop Liesing ALREADY EXISTED.
# Line 257 ALREADY EXISTED.
# Line 257 at stop Liesing ALREADY EXISTED.
# Line 258 ALREADY EXISTED.
# Line 258 at stop Liesing ALREADY EXISTED.
# run 141
# Line 61A ALREADY EXISTED.
# Line 61A at stop Liesing ALREADY EXISTED.
# run 142
# Stop Liesing Bad (Manngasse) NOT FOUND in the database.
# run 143
# Stop Wiener Neudorf Eumigweg NOT FOUND in the database.
# run 144
# Stop Wolfsgraben Besenkopf NOT FOUND in the database.
# run 145
# Stop Wolfsgraben Besenkopf NOT FOUND in the database.
# run 146
# Stop Gaaden Buchengasse NOT FOUND in the database.
# run 147
# Stop Gaaden Buchengasse NOT FOUND in the database.
# run 148
# Stop Ulrichskirchen Hofgartenstraße NOT FOUND in the database.
# run 149
# Stop Ulrichskirchen Bahnstraße NOT FOUND in the database.
# run 150
# Stop Mauerbach Hirschengartenstraße NOT FOUND in the database.
# run 151
# Stop Mauerbach Hirschengartenstraße NOT FOUND in the database.
# run 152
# Stop Ebergassing Siedlergasse NOT FOUND in the database.
# run 153
# Stop Ebergassing Siedlergasse NOT FOUND in the database.
# run 154
# Stop Trautmannsdorf/Leitha Volksschule NOT FOUND in the database.
# run 155
# Stop Korneuburg Liebherrstraße NOT FOUND in the database.
# run 156
# Stop Hinterbrühl Mannlichergasse NOT FOUND in the database.
# run 157
# Stop Hinterbrühl Mannlichergasse NOT FOUND in the database.
# run 158
# Stop Perchtoldsdorf Wegbachgasse NOT FOUND in the database.
# run 159
# Stop Perchtoldsdorf Wegbachgasse NOT FOUND in the database.
# run 160
# Stop Moosbrunn Unterwaltersdorfer Straße NOT FOUND in the database.
# run 161
# Stop Moosbrunn Unterwaltersdorfer Straße NOT FOUND in the database.
# run 162
# Stop Mödling WIFI NOT FOUND in the database.
# run 163
# Stop Breitenfurt Wolfsgrabenstraße NOT FOUND in the database.
# run 164
# Stop Korneuburg Viktor-Kaplan-Str. NOT FOUND in the database.
# run 165
# Stop Korneuburg McDonalds-Straße NOT FOUND in the database.
# run 166
# Stop Korneuburg Bezirksbauernkammer NOT FOUND in the database.
# run 167
# Stop Kaltenleutgeben Wiesengasse NOT FOUND in the database.
# run 168
# Stop Langenzersdorf Schulstraße NOT FOUND in the database.
# run 169
# Stop Klosterneuburg Aufeldgasse/Inkustraße NOT FOUND in the database.
# run 170
# Stop Gramatneusiedl Schulen NOT FOUND in the database.
# run 171
# Stop Schwadorf Schulgasse NOT FOUND in the database.
# run 172
# Stop Schwadorf Schulgasse NOT FOUND in the database.
# run 173
# Stop Baden Hochschulpromenade NOT FOUND in the database.
# run 174
# Stop Baden Kollmannstraße NOT FOUND in the database.
# run 175
# Stop Baden Bezirkshauptmannschaft NOT FOUND in the database.
# run 176
# Stop Baden Kanalgasse NOT FOUND in the database.
# run 177
# Stop Baden Prinz-Solms-Straße NOT FOUND in the database.
# run 178
# Stop Baden Dörflergasse NOT FOUND in the database.
# run 179
# Stop Baden Dörflergasse NOT FOUND in the database.
# run 180
# Stop Baden Steinbruchgasse NOT FOUND in the database.
# run 181
# Stop Baden Steinbruchgasse NOT FOUND in the database.
# run 182
# Stop Baden Dumbagasse NOT FOUND in the database.
# run 183
# Stop Baden Dumbagasse NOT FOUND in the database.
# run 184
# Stop Maria Lanzendorf Sportplatz NOT FOUND in the database.
# run 185
# Stop Maria Lanzendorf Sportplatz NOT FOUND in the database.
# run 186
# Stop Zwölfaxing Josef-Weiß-Gasse NOT FOUND in the database.
# run 187
# Stop Zwölfaxing Josef-Weiß-Gasse NOT FOUND in the database.
# run 188
# Stop Wiener Neudorf Buchenweg NOT FOUND in the database.
# run 189
# Stop Wiener Neudorf Buchenweg NOT FOUND in the database.
# run 190
# Stop Purkersdorf Volksschule NOT FOUND in the database.
# run 191
# Stop Neu-Guntramsdorf Ozeanstraße NOT FOUND in the database.
# run 192
# Stop Neu-Guntramsdorf Ozeanstraße NOT FOUND in the database.
# run 193
# Stop Biedermannsdorf S.-Marcus-Str. NOT FOUND in the database.
# run 194
# Stop Biedermannsdorf S.-Marcus-Str. NOT FOUND in the database.
# run 195
# Stop Heimbautal Gartenstraße NOT FOUND in the database.
# run 196
# Stop Wolkersdorf Hofgartenstraße NOT FOUND in the database.
# run 197
# Stop Hennersdorf Stiftergasse NOT FOUND in the database.
# run 198
# Stop Hennersdorf Wildgansgasse NOT FOUND in the database.
# run 199
# Stop St. Andrä-Wördern Tullner Straße NOT FOUND in the database.
# run 200
# Stop St. Andrä-Wördern Tullner Straße NOT FOUND in the database.
# run 201
# Stop Kierling Maital NOT FOUND in the database.
# run 202
# Stop Purkersdorf Pestsäule NOT FOUND in the database.
# run 203
# Stop Brunn/Geb. Karl-Etti-Platz NOT FOUND in the database.
# run 204
# Stop Brunn/Geb. Europaring NOT FOUND in the database.
# run 205
# Stop Brunn/Geb. Liebermannstraße NOT FOUND in the database.
# run 206
# Stop Brunn/Geb. Liebermannstraße NOT FOUND in the database.
# run 207
# Stop Wiener Neudorf Reisenbauer-Ring Nord NOT FOUND in the database.
# run 208
# Stop Laxenburg Guntramsdorfer Str. NOT FOUND in the database.
# run 209
# Stop Laxenburg Guntramsdorfer Str. NOT FOUND in the database.
# run 210
# Stop Moosbrunn Wassergasse NOT FOUND in the database.
# run 211
# Stop Moosbrunn Wassergasse NOT FOUND in the database.
# run 212
# Stop Klosterneuburg Wigandgasse 8 NOT FOUND in the database.
# run 213
# Stop Klosterneuburg Wigandgasse 22 NOT FOUND in the database.
# run 214
# Stop Hennersdorf Gemeindeamt NOT FOUND in the database.
# run 215
# Stop Schönau an der Donau Friedhof NOT FOUND in the database.
# run 216
# Stop Schönau an der Donau Friedhof NOT FOUND in the database.
# run 217
# Stop Strasshof Anton-Fromm-Straße NOT FOUND in the database.
# run 218
# Stop Wolkersdorf Marie-Curie-Straße NOT FOUND in the database.
# run 219
# Stop Gablitz Schielegasse NOT FOUND in the database.
# run 220
# Stop Strasshof Franz-Planeta-Straße NOT FOUND in the database.
# run 221
# Stop IZ NÖ-Süd Str. 15/WALTER B-PARK 77 NOT FOUND in the database.
# run 222
# Stop IZ NÖ-Süd Str. 15/WALTER B-PARK 77 NOT FOUND in the database.
# run 223
# Stop Vösendorf SCS Park/Europaring NOT FOUND in the database.
# run 224
# Stop Wienerherberg Kleinfeldgasse NOT FOUND in the database.
# run 225
# Stop Wienerherberg Kleinfeldgasse NOT FOUND in the database.
# run 226
# Stop Ebergassing Schwadorfer Straße NOT FOUND in the database.
# run 227
# Stop Ebergassing Schwadorfer Straße NOT FOUND in the database.
# run 228
# Stop Leobendorf Industriezeile NOT FOUND in the database.
# run 229
# Stop Leobendorf Industriezeile NOT FOUND in the database.
# run 230
# Stop Wolkersdorf Mittelschule NOT FOUND in the database.
# run 231
# Stop Breitenfurt Rudolf-Steiner-Gasse NOT FOUND in the database.
# run 232
# Stop Breitenfurt Rudolf-Steiner-Gasse NOT FOUND in the database.
# run 233
# Stop Münchendorf Babenbergersee II NOT FOUND in the database.
# run 234
# Stop Münchendorf Babenbergersee II NOT FOUND in the database.
# run 235
# Stop Tulbing Volksschule NOT FOUND in the database.
# run 236
# Stop Himberg Ebergassinger Str. NOT FOUND in the database.
# run 237
# Stop Himberg Ebergassinger Str. NOT FOUND in the database.
# run 238
# Stop Wiener Neudorf Brown-Boveri-Str. NOT FOUND in the database.
# run 239
# Stop Wiener Neudorf Brown-Boveri-Str. NOT FOUND in the database.
# run 240
# Stop Sittendorf An der Teichwiese NOT FOUND in the database.
# run 241
# Stop Wiener Neudorf Franz-Fürst-Str. NOT FOUND in the database.
# run 242
# Stop Klosterneuburg Untere Öden NOT FOUND in the database.
# run 243
# Stop Klosterneuburg Normannengasse NOT FOUND in the database.
# run 244
# Stop Klosterneuburg Donaustr./Büropark NOT FOUND in the database.
# run 245
# Stop Breitenfurt Friedhof NOT FOUND in the database.
# run 246
# Stop Breitenfurt Raphael-Donner-Gasse NOT FOUND in the database.
# run 247
# Stop Guntramsdorf Schulcampus NOT FOUND in the database.
# run 248
# Stop Guntramsdorf Schulcampus NOT FOUND in the database.
# run 249
# Stop IZ NÖ-Süd Str. 15/Wendestelle NOT FOUND in the database.
# run 250
# Stop Brunn/Geb. Rennweg NOT FOUND in the database.
# run 251
# Stop St. Andrä-Wördern Dr.-Ignaz-Stich-Platz NOT FOUND in the database.
# run 252
# Stop St. Andrä-Wördern Franz-Lehar-Gasse NOT FOUND in the database.
# run 253
# Stop Wiener Neudorf Gemeindeamt NOT FOUND in the database.
# run 254
# Stop Wiener Neudorf Gemeindeamt NOT FOUND in the database.
# run 255
# Stop Götzendorf Volksschule NOT FOUND in the database.
# run 256
# Stop Ebergassing Götzendorfer Str. NOT FOUND in the database.
# run 257
# Stop Ebergassing Götzendorfer Str. NOT FOUND in the database.
# run 258
# Stop Mödling Im Felberbrunn NOT FOUND in the database.
# run 259
# Stop Weidling Reitstall NOT FOUND in the database.
# run 260
# Stop Maria Gugging Am Campus NOT FOUND in the database.
# run 261
# Stop Stockerau Gymnasiumweg NOT FOUND in the database.
# run 262
# Stop Stockerau Gymnasiumweg NOT FOUND in the database.
# run 263
# Stop Schwechat Klederinger Straße NOT FOUND in the database.
# run 264
# Stop Schwechat Klederinger Straße NOT FOUND in the database.
# run 265
# Stop Mödling Landesklinikum NOT FOUND in the database.
# run 266
# Stop Velm bei Himberg Schlosspark NOT FOUND in the database.
# run 267
# Stop Velm bei Himberg Kalter Gang NOT FOUND in the database.
# run 268
# Stop Velm bei Himberg Kalter Gang NOT FOUND in the database.
# run 269
# Stop Traiskirchen Margarethenstraße NOT FOUND in the database.
# run 270
# Stop Siegenfeld Hochweg NOT FOUND in the database.
# run 271
# Stop Siegenfeld Hochweg NOT FOUND in the database.
# run 272
# Stop Mitterndorf/Fischa Landesmann-Straße NOT FOUND in the database.
# run 273
# Stop Mitterndorf/Fischa Landesmann-Straße NOT FOUND in the database.
# run 274
# Stop Wolkersdorf Alter Markt NOT FOUND in the database.
# run 275
# Stop Wolkersdorf Alter Markt NOT FOUND in the database.
# run 276
# Stop Wolkersdorf Alter Markt NOT FOUND in the database.
# run 277
# Stop Helmahof Eduard-Bauernfeld-Gasse NOT FOUND in the database.
# run 278
# Stop Helmahof Eduard-Bauernfeld-Gasse NOT FOUND in the database.
# run 279
# Stop Neu-Guntramsdorf Franz-Novy-Gasse NOT FOUND in the database.
# run 280
# Stop Neu-Guntramsdorf Franz-Novy-Gasse NOT FOUND in the database.
# run 281
# Stop Deutsch-Wagram Rohrergasse NOT FOUND in the database.
# run 282
# Stop Deutsch-Wagram Rohrergasse NOT FOUND in the database.
# run 283
# Stop Brunn/Geb. Wolfholzgasse NOT FOUND in the database.
# run 284
# Stop Brunn/Geb. Wolfholzgasse NOT FOUND in the database.
# run 285
# Stop Enzersdorf/Fischa Julius-Raab-Gasse NOT FOUND in the database.
# run 286
# Stop Pischelsdorf Schulgasse NOT FOUND in the database.
# run 287
# Stop Kleinneusiedl Schwadorfer Straße 18 NOT FOUND in the database.
# run 288
# Stop Deutsch-Wagram Grenzweg NOT FOUND in the database.
# run 289
# Stop Seyring G3 Shopping Resort/Eingang C NOT FOUND in the database.
# run 290
# Stop Seyring G3 Shopping Resort/Eingang B NOT FOUND in the database.
# run 291
# Stop Laxenburg Süd NOT FOUND in the database.
# run 292
# Stop Laxenburg Süd NOT FOUND in the database.
# run 293
# Stop Schmida Ortsmitte NOT FOUND in the database.
# run 294
# Stop Schmida Eichenweg NOT FOUND in the database.
# run 295
# Stop Liesing Bad (Manngasse) NOT FOUND in the database.
# run 296
# Stop Liesing Bad (Perchtoldsdorfer Str.) NOT FOUND in the database.
# run 297
# Stop Liesing Bad (Perchtoldsdorfer Str.) NOT FOUND in the database.
# run 298
# Line 256 ALREADY EXISTED.
# Line 256 at stop Liesing Bad ALREADY EXISTED.
# Line 255 ALREADY EXISTED.
# Line 255 at stop Liesing Bad ALREADY EXISTED.
# Line 257 ALREADY EXISTED.
# Line 257 at stop Liesing Bad ALREADY EXISTED.
# Line 258 ALREADY EXISTED.
# Line 258 at stop Liesing Bad ALREADY EXISTED.
# run 299
# Line 61A ALREADY EXISTED.
# Line 61A at stop Liesing Feuerwache ALREADY EXISTED.
# run 300
# Line 61A ALREADY EXISTED.
# Line 61A at stop Liesing Feuerwache ALREADY EXISTED.
# run 301
# Line 61A ALREADY EXISTED.
# Line 61A at stop Liesing Friedhof ALREADY EXISTED.
# run 302
# Line 61A ALREADY EXISTED.
# Line 61A at stop Liesing Friedhof ALREADY EXISTED.
# run 303
# Line 48A ALREADY EXISTED.
# Line 48A at stop Moeringgasse ALREADY EXISTED.
# run 304
# Line 66A ALREADY EXISTED.
# Line 66A at stop Liesing Schulzentrum ALREADY EXISTED.
# Line N66 ALREADY EXISTED.
# Line N66 at stop Liesing Schulzentrum ALREADY EXISTED.
# run 305
# Line N66 ALREADY EXISTED.
# Line N66 at stop Liesing Schulzentrum ALREADY EXISTED.
# run 306
# Line N66 ALREADY EXISTED.
# Line N66 at stop Liesing Schulzentrum ALREADY EXISTED.
# run 307
# Line 66A ALREADY EXISTED.
# Line 66A at stop Liesing Schulzentrum ALREADY EXISTED.
# Line N66 ALREADY EXISTED.
# Line N66 at stop Liesing Schulzentrum ALREADY EXISTED.
# run 308
# Line N66 ALREADY EXISTED.
# Line N66 at stop Liesing Schulzentrum ALREADY EXISTED.
# run 309
# Line N66 ALREADY EXISTED.
# Line N66 at stop Liesing Schulzentrum ALREADY EXISTED.
# run 310
# Stop Sebastianbrücke NOT FOUND in the database.
# run 311
# Stop Sebastianbrücke NOT FOUND in the database.
# run 312
# Stop Sebastianbrücke NOT FOUND in the database.
# run 313
# Stop Sebastianbrücke NOT FOUND in the database.
# run 314
# Stop Sebastianbrücke NOT FOUND in the database.
# run 315
# Stop Sebastianbrücke NOT FOUND in the database.
# run 316
# Stop Sebastianbrücke NOT FOUND in the database.
# run 317
# Stop Sebastianbrücke NOT FOUND in the database.
# run 318
# Stop Sebastianbrücke NOT FOUND in the database.
# run 319
# Stop Sebastianbrücke NOT FOUND in the database.
# run 320
# Stop Sebastianbrücke NOT FOUND in the database.
# run 321
# Stop Sebastianbrücke NOT FOUND in the database.
# run 322
# Line 64A ALREADY EXISTED.
# Line 64A at stop Liesinger-Flur-Gasse ALREADY EXISTED.
# run 323
# Line 64A ALREADY EXISTED.
# Line 64A at stop Liesinger-Flur-Gasse ALREADY EXISTED.
# run 324
# Stop Jedleseer Friedhof NOT FOUND in the database.
# run 325
# Stop Jedleseer Friedhof NOT FOUND in the database.
# run 326
# Line 69A ALREADY EXISTED.
# Line 69A at stop Lilienthalgasse ALREADY EXISTED.
# run 327
# Line 69A ALREADY EXISTED.
# Line 69A at stop Lilienthalgasse ALREADY EXISTED.
# run 328
# Line 60A ALREADY EXISTED.
# Line 60A at stop Lindauergasse ALREADY EXISTED.
# Line N61 ALREADY EXISTED.
# Line N61 at stop Lindauergasse ALREADY EXISTED.
# run 329
# Line N61 ALREADY EXISTED.
# Line N61 at stop Lindauergasse ALREADY EXISTED.
# run 330
# Line N61 ALREADY EXISTED.
# Line N61 at stop Lindauergasse ALREADY EXISTED.
# run 331
# Line N61 ALREADY EXISTED.
# Line N61 at stop Lindauergasse ALREADY EXISTED.
# run 332
# Line N61 ALREADY EXISTED.
# Line N61 at stop Lindauergasse ALREADY EXISTED.
# run 333
# Line 60A ALREADY EXISTED.
# Line 60A at stop Lindauergasse ALREADY EXISTED.
# Line N61 ALREADY EXISTED.
# Line N61 at stop Lindauergasse ALREADY EXISTED.
# run 334
# Line N61 ALREADY EXISTED.
# Line N61 at stop Lindauergasse ALREADY EXISTED.
# run 335
# Line N61 ALREADY EXISTED.
# Line N61 at stop Lindauergasse ALREADY EXISTED.
# run 336
# Line N61 ALREADY EXISTED.
# Line N61 at stop Lindauergasse ALREADY EXISTED.
# run 337
# Line N61 ALREADY EXISTED.
# Line N61 at stop Lindauergasse ALREADY EXISTED.
# run 338
# Line 69A ALREADY EXISTED.
# Line 69A at stop Lindenbauergasse ALREADY EXISTED.
# run 339
# Line 69A ALREADY EXISTED.
# Line 69A at stop Lindenbauergasse ALREADY EXISTED.
# run 340
# Stop Jungnickelweg NOT FOUND in the database.
# run 341
# Stop Jungnickelweg NOT FOUND in the database.
# run 342
# Stop Jungnickelweg NOT FOUND in the database.
# run 343
# Stop Jungnickelweg NOT FOUND in the database.
# run 344
# Stop Jungnickelweg NOT FOUND in the database.
# run 345
# Stop Jungnickelweg NOT FOUND in the database.
# run 346
# Stop Linnéplatz NOT FOUND in the database.
# run 347
# Stop Linnéplatz NOT FOUND in the database.
# run 348
# Line 4A ALREADY EXISTED.
# Line 4A at stop Lisztstraße ALREADY EXISTED.
# run 349
# Line 4A ALREADY EXISTED.
# Line 4A at stop Lisztstraße ALREADY EXISTED.
# run 350
# Line N71 ALREADY EXISTED.
# Line N71 at stop Litfaßstraße ALREADY EXISTED.
# run 351
# Line N71 ALREADY EXISTED.
# Line N71 at stop Litfaßstraße ALREADY EXISTED.
# run 352
# Line D ALREADY EXISTED.
# Line D at stop Litfaßstraße ALREADY EXISTED.
# Line 71 ALREADY EXISTED.
# Line 71 at stop Litfaßstraße ALREADY EXISTED.
# run 353
# Line N71 ALREADY EXISTED.
# Line N71 at stop Litfaßstraße ALREADY EXISTED.
# run 354
# Line N71 ALREADY EXISTED.
# Line N71 at stop Litfaßstraße ALREADY EXISTED.
# run 355
# Line 71 ALREADY EXISTED.
# Line 71 at stop Litfaßstraße ALREADY EXISTED.
# run 356
# Stop Raffineriestr./Ostbahnbrücke NOT FOUND in the database.
# run 357
# Stop Raffineriestr./Ostbahnbrücke NOT FOUND in the database.
# run 358
# Line 60A ALREADY EXISTED.
# Line 60A at stop Löwenthalgasse ALREADY EXISTED.
# Line N61 ALREADY EXISTED.
# Line N61 at stop Löwenthalgasse ALREADY EXISTED.
# run 359
# Line N61 ALREADY EXISTED.
# Line N61 at stop Löwenthalgasse ALREADY EXISTED.
# run 360
# Line N61 ALREADY EXISTED.
# Line N61 at stop Löwenthalgasse ALREADY EXISTED.
# run 361
# Line N61 ALREADY EXISTED.
# Line N61 at stop Löwenthalgasse ALREADY EXISTED.
# run 362
# Line N61 ALREADY EXISTED.
# Line N61 at stop Löwenthalgasse ALREADY EXISTED.
# run 363
# Line 93A ALREADY EXISTED.
# Line 93A at stop Lobaugasse ALREADY EXISTED.
# run 364
# Line 93A ALREADY EXISTED.
# Line 93A at stop Lobaugasse ALREADY EXISTED.
# run 365
# Line 92B ALREADY EXISTED.
# Line 92B at stop Lobgrundstraße ALREADY EXISTED.
# run 366
# Line 92B ALREADY EXISTED.
# Line 92B at stop Lobgrundstraße ALREADY EXISTED.
# run 367
# Line 34A ALREADY EXISTED.
# Line 34A at stop Lohnergasse ALREADY EXISTED.
# run 368
# Line 34A ALREADY EXISTED.
# Line 34A at stop Lohnergasse ALREADY EXISTED.
# run 369
# Line 26A ALREADY EXISTED.
# Line 26A at stop Lohwaggasse ALREADY EXISTED.
# Line N26 ALREADY EXISTED.
# Line N26 at stop Lohwaggasse ALREADY EXISTED.
# run 370
# Line N26 ALREADY EXISTED.
# Line N26 at stop Lohwaggasse ALREADY EXISTED.
# run 371
# Line N26 ALREADY EXISTED.
# Line N26 at stop Lohwaggasse ALREADY EXISTED.
# run 372
# Line 97A ALREADY EXISTED.
# Line 97A at stop Lohwaggasse ALREADY EXISTED.
# Line 26A ALREADY EXISTED.
# Line 26A at stop Lohwaggasse ALREADY EXISTED.
# Line N26 ALREADY EXISTED.
# Line N26 at stop Lohwaggasse ALREADY EXISTED.
# run 373
# Line N26 ALREADY EXISTED.
# Line N26 at stop Lohwaggasse ALREADY EXISTED.
# run 374
# Line N26 ALREADY EXISTED.
# Line N26 at stop Lohwaggasse ALREADY EXISTED.
# run 375
# Line 36A ALREADY EXISTED.
# Line 36A at stop Lokomotivgasse ALREADY EXISTED.
# run 376
# Line 36A ALREADY EXISTED.
# Line 36A at stop Lokomotivgasse ALREADY EXISTED.
# run 377
# Stop Lorenz-Böhler-Unfallkrankenhaus NOT FOUND in the database.
# run 378
# Stop Lorenz-Böhler-Unfallkrankenhaus NOT FOUND in the database.
# run 379
# Stop Lorenz-Böhler-Unfallkrankenhaus NOT FOUND in the database.
# run 380
# Stop Lorenz-Böhler-Unfallkrankenhaus NOT FOUND in the database.
# run 381
# Stop Lorystraße (Grillgasse) NOT FOUND in the database.
# run 382
# Stop Lorystraße (Dommesgasse) NOT FOUND in the database.
# run 383
# Line 72A ALREADY EXISTED.
# Line 72A at stop Anton-Stilling-Platz ALREADY EXISTED.
# run 384
# Line 72A ALREADY EXISTED.
# Line 72A at stop Anton-Stilling-Platz ALREADY EXISTED.
# run 385
# Line 97A ALREADY EXISTED.
# Line 97A at stop Margeritenweg ALREADY EXISTED.
# run 386
# Stop Lukschgasse (Schüttelstr.) NOT FOUND in the database.
# run 387
# Stop Lukschgasse (Böcklinstr.) NOT FOUND in the database.
# run 388
# Stop Lusthaus/Aspernallee NOT FOUND in the database.
# run 389
# Stop Lusthaus/Aspernallee NOT FOUND in the database.
# run 390
# Stop Linzer Str./Lützowgasse NOT FOUND in the database.
# run 391
# Stop Linzer Str./Lützowgasse NOT FOUND in the database.
# run 392
# Line N60 ALREADY EXISTED.
# Line N60 at stop Längenfeldgasse ALREADY EXISTED.
# run 393
# Line N60 ALREADY EXISTED.
# Line N60 at stop Längenfeldgasse ALREADY EXISTED.
# run 394
# Line N8 ALREADY EXISTED.
# Line N8 at stop Längenfeldgasse ALREADY EXISTED.
# Line 12A ALREADY EXISTED.
# Line 12A at stop Längenfeldgasse ALREADY EXISTED.
# run 395
# Line N8 ALREADY EXISTED.
# Line N8 at stop Längenfeldgasse ALREADY EXISTED.
# run 396
# Line N8 ALREADY EXISTED.
# Line N8 at stop Längenfeldgasse ALREADY EXISTED.
# run 397
# Line N60 ALREADY EXISTED.
# Line N60 at stop Längenfeldgasse ALREADY EXISTED.
# run 398
# Line N60 ALREADY EXISTED.
# Line N60 at stop Längenfeldgasse ALREADY EXISTED.
# run 399
# Line N8 ALREADY EXISTED.
# Line N8 at stop Längenfeldgasse ALREADY EXISTED.
# Line 12A ALREADY EXISTED.
# Line 12A at stop Längenfeldgasse ALREADY EXISTED.
# run 400
# Line N8 ALREADY EXISTED.
# Line N8 at stop Längenfeldgasse ALREADY EXISTED.
# run 401
# Line N8 ALREADY EXISTED.
# Line N8 at stop Längenfeldgasse ALREADY EXISTED.
# run 402
# Stop Wiener Neudorf Martonygasse NOT FOUND in the database.
# run 403
# Stop Wiener Neudorf Martonygasse NOT FOUND in the database.
# run 404
# Stop Mitterndorf/Fischa Grenzgasse NOT FOUND in the database.
# run 405
# Stop Gerasdorf Westliche Scheunenstraße NOT FOUND in the database.
# run 406
# Stop Gerasdorf Westliche Scheunenstraße NOT FOUND in the database.
# run 407
# Stop Gerasdorf Grenzweg NOT FOUND in the database.
# run 408
# Stop Gerasdorf Grenzweg NOT FOUND in the database.
# run 409
# Stop Fischamend Zeppelinstraße NOT FOUND in the database.
# run 410
# Stop Fischamend Zeppelinstraße NOT FOUND in the database.
# run 411
# Stop Auersthal Europa-Siedlung NOT FOUND in the database.
# run 412
# Stop Langenzersdorf Rebschulgasse NOT FOUND in the database.
# run 413
# Stop Langenzersdorf Im Kühhagel NOT FOUND in the database.
# run 414
# Stop Langenzersdorf Friedhofstraße NOT FOUND in the database.
# run 415
# Stop Deutsch-Wagram Franz-Schuhmeier-Str. NOT FOUND in the database.
# run 416
# Stop Deutsch-Wagram Karl-Wiesinger-Straße NOT FOUND in the database.
# run 417
# Stop Deutsch-Wagram Albert-Schweitzer-G. NOT FOUND in the database.
# run 418
# Stop Mauerbach Volksschule NOT FOUND in the database.
# run 419
# Stop Vösendorf Anton-Benya-Straße 7 NOT FOUND in the database.
# run 420
# Stop Wiener Neudorf Am Anningerpark NOT FOUND in the database.
# run 421
# Stop Wiener Neudorf Am Anningerpark NOT FOUND in the database.
# run 422
# Stop Wiener Neudorf Anningerstraße NOT FOUND in the database.
# run 423
# Stop Wiener Neudorf Anningerstraße NOT FOUND in the database.
# run 424
# Stop Brunn/Geb. Auf der Stierwiese NOT FOUND in the database.
# run 425
# Stop Wipfing/Donau Hauptstraße NOT FOUND in the database.
# run 426
# Line N91 ALREADY EXISTED.
# Line N91 at stop Naufahrtbrücke ALREADY EXISTED.
# run 427
# Line N91 ALREADY EXISTED.
# Line N91 at stop Naufahrtbrücke ALREADY EXISTED.
# run 428
# Line N91 ALREADY EXISTED.
# Line N91 at stop Naufahrtbrücke ALREADY EXISTED.
# run 429
# Line N91 ALREADY EXISTED.
# Line N91 at stop Naufahrtbrücke ALREADY EXISTED.
# run 430
# Line N91 ALREADY EXISTED.
# Line N91 at stop Naufahrtbrücke ALREADY EXISTED.
# run 431
# Line N91 ALREADY EXISTED.
# Line N91 at stop Naufahrtbrücke ALREADY EXISTED.
# run 432
# Line N91 ALREADY EXISTED.
# Line N91 at stop Naufahrtbrücke ALREADY EXISTED.
# run 433
# Line 16A ALREADY EXISTED.
# Line 16A at stop Nauheimergasse ALREADY EXISTED.
# run 434
# Line 16A ALREADY EXISTED.
# Line 16A at stop Nauheimergasse ALREADY EXISTED.
# run 435
# Line 6 ALREADY EXISTED.
# Line 6 at stop Neilreichgasse ALREADY EXISTED.
# Line N6 ALREADY EXISTED.
# Line N6 at stop Neilreichgasse ALREADY EXISTED.
# Line 18 ALREADY EXISTED.
# Line 18 at stop Neilreichgasse ALREADY EXISTED.
# run 436
# Line 6 ALREADY EXISTED.
# Line 6 at stop Neilreichgasse ALREADY EXISTED.
# Line N6 ALREADY EXISTED.
# Line N6 at stop Neilreichgasse ALREADY EXISTED.
# Line 18 ALREADY EXISTED.
# Line 18 at stop Neilreichgasse ALREADY EXISTED.
# run 437
# Line N6 ALREADY EXISTED.
# Line N6 at stop Neilreichgasse ALREADY EXISTED.
# run 438
# Line N6 ALREADY EXISTED.
# Line N6 at stop Neilreichgasse ALREADY EXISTED.
# run 439
# Line 6 ALREADY EXISTED.
# Line 6 at stop Neilreichgasse ALREADY EXISTED.
# Line N6 ALREADY EXISTED.
# Line N6 at stop Neilreichgasse ALREADY EXISTED.
# Line 18 ALREADY EXISTED.
# Line 18 at stop Neilreichgasse ALREADY EXISTED.
# run 440
# Line 6 ALREADY EXISTED.
# Line 6 at stop Neilreichgasse ALREADY EXISTED.
# Line N6 ALREADY EXISTED.
# Line N6 at stop Neilreichgasse ALREADY EXISTED.
# Line 18 ALREADY EXISTED.
# Line 18 at stop Neilreichgasse ALREADY EXISTED.
# run 441
# Line N6 ALREADY EXISTED.
# Line N6 at stop Neilreichgasse ALREADY EXISTED.
# run 442
# Line N6 ALREADY EXISTED.
# Line N6 at stop Neilreichgasse ALREADY EXISTED.
# run 443
# Line N25 ALREADY EXISTED.
# Line N25 at stop Nestroyplatz ALREADY EXISTED.
# run 444
# Line N25 ALREADY EXISTED.
# Line N25 at stop Nestroyplatz ALREADY EXISTED.
# run 445
# Line 5A ALREADY EXISTED.
# Line 5A at stop Nestroyplatz ALREADY EXISTED.
# run 446
# Line N25 ALREADY EXISTED.
# Line N25 at stop Nestroyplatz ALREADY EXISTED.
# run 447
# Line N25 ALREADY EXISTED.
# Line N25 at stop Nestroyplatz ALREADY EXISTED.
# run 448
# Line N90 ALREADY EXISTED.
# Line N90 at stop Neue Donau Mitte ALREADY EXISTED.
# Line 92A ALREADY EXISTED.
# Line 92A at stop Neue Donau Mitte ALREADY EXISTED.
# Line 92B ALREADY EXISTED.
# Line 92B at stop Neue Donau Mitte ALREADY EXISTED.
# run 449
# Line N90 ALREADY EXISTED.
# Line N90 at stop Neue Donau Mitte ALREADY EXISTED.
# run 450
# Line N90 ALREADY EXISTED.
# Line N90 at stop Neue Donau Mitte ALREADY EXISTED.
# run 451
# Line N90 ALREADY EXISTED.
# Line N90 at stop Neue Donau Mitte ALREADY EXISTED.
# run 452
# Line N90 ALREADY EXISTED.
# Line N90 at stop Neue Donau Mitte ALREADY EXISTED.
# run 453
# Line N90 ALREADY EXISTED.
# Line N90 at stop Neue Donau Mitte ALREADY EXISTED.
# Line 92A ALREADY EXISTED.
# Line 92A at stop Neue Donau Mitte ALREADY EXISTED.
# Line 92B ALREADY EXISTED.
# Line 92B at stop Neue Donau Mitte ALREADY EXISTED.
# run 454
# Line N90 ALREADY EXISTED.
# Line N90 at stop Neue Donau Mitte ALREADY EXISTED.
# run 455
# Line N90 ALREADY EXISTED.
# Line N90 at stop Neue Donau Mitte ALREADY EXISTED.
# run 456
# Line N90 ALREADY EXISTED.
# Line N90 at stop Neue Donau Mitte ALREADY EXISTED.
# run 457
# Line N90 ALREADY EXISTED.
# Line N90 at stop Neue Donau Mitte ALREADY EXISTED.
# run 458
# Stop Laxenburger Str./Troststr. NOT FOUND in the database.
# run 459
# Stop Laxenburger Str./Troststr. NOT FOUND in the database.
# run 460
# Stop Laxenburger Str./Troststr. NOT FOUND in the database.
# run 461
# Stop Laxenburger Str./Troststr. NOT FOUND in the database.
# run 462
# Stop Laxenburger Str./Troststr. NOT FOUND in the database.
# run 463
# Stop Laxenburger Str./Troststr. NOT FOUND in the database.
# run 464
# Stop Laxenburger Str./Troststr. NOT FOUND in the database.
# run 465
# Stop Laxenburger Str./Troststr. NOT FOUND in the database.
# run 466
# Stop Laxenburger Str./Troststr. NOT FOUND in the database.
# run 467
# Stop Laxenburger Str./Troststr. NOT FOUND in the database.
# run 468
# Stop Laxenburger Str./Troststr. NOT FOUND in the database.
# run 469
# Stop Laxenburger Str./Troststr. NOT FOUND in the database.
# run 470
# Stop Laxenburger Str./Raxstr. NOT FOUND in the database.
# run 471
# Stop Laxenburger Str./Raxstr. NOT FOUND in the database.
# run 472
# Stop Laxenburger Str./Raxstr. NOT FOUND in the database.
# run 473
# Stop Laxenburger Str./Raxstr. NOT FOUND in the database.
# run 474
# Stop Laxenburger Str./Raxstr. NOT FOUND in the database.
# run 475
# Stop Laxenburger Str./Raxstr. NOT FOUND in the database.
# run 476
# Stop Laxenburger Str./Raxstr. NOT FOUND in the database.
# run 477
# Stop Laxenburger Str./Raxstr. NOT FOUND in the database.
# run 478
# Stop Laxenburger Str./Raxstr. NOT FOUND in the database.
# run 479
# Stop Laxenburger Str./Raxstr. NOT FOUND in the database.
# run 480
# Stop Laxenburger Str./Raxstr. NOT FOUND in the database.
# run 481
# Stop Laxenburger Str./Raxstr. NOT FOUND in the database.
# run 482
# Line 33 ALREADY EXISTED.
# Line 33 at stop Lazarettgasse ALREADY EXISTED.
# Line 5 ALREADY EXISTED.
# Line 5 at stop Lazarettgasse ALREADY EXISTED.
# run 483
# Line 33 ALREADY EXISTED.
# Line 33 at stop Lazarettgasse ALREADY EXISTED.
# Line 5 ALREADY EXISTED.
# Line 5 at stop Lazarettgasse ALREADY EXISTED.
# run 484
# Stop St. Marx/Leberstraße NOT FOUND in the database.
# run 485
# Line 51A ALREADY EXISTED.
# Line 51A at stop Lebingergasse ALREADY EXISTED.
# run 486
# Line 51A ALREADY EXISTED.
# Line 51A at stop Lebingergasse ALREADY EXISTED.
# run 487
# Line 77A ALREADY EXISTED.
# Line 77A at stop Lechnerstraße ALREADY EXISTED.
# Line N75 ALREADY EXISTED.
# Line N75 at stop Lechnerstraße ALREADY EXISTED.
# run 488
# Line N75 ALREADY EXISTED.
# Line N75 at stop Lechnerstraße ALREADY EXISTED.
# run 489
# Line N75 ALREADY EXISTED.
# Line N75 at stop Lechnerstraße ALREADY EXISTED.
# run 490
# Line 77A ALREADY EXISTED.
# Line 77A at stop Lechnerstraße ALREADY EXISTED.
# Line N75 ALREADY EXISTED.
# Line N75 at stop Lechnerstraße ALREADY EXISTED.
# run 491
# Line N75 ALREADY EXISTED.
# Line N75 at stop Lechnerstraße ALREADY EXISTED.
# run 492
# Line N75 ALREADY EXISTED.
# Line N75 at stop Lechnerstraße ALREADY EXISTED.
# run 493
# Line 98A ALREADY EXISTED.
# Line 98A at stop Rosenbergstraße ALREADY EXISTED.
# run 494
# Stop Himmelteich NOT FOUND in the database.
# run 495
# Stop Himmelteich NOT FOUND in the database.
# run 496
# Stop Leibenfrostgasse (Ziegelofeng.) NOT FOUND in the database.
# run 497
# Stop Leibenfrostgasse (Phorusgasse) NOT FOUND in the database.
# run 498
# Line 32A ALREADY EXISTED.
# Line 32A at stop Leopoldau ALREADY EXISTED.
# run 499
# Line 29B ALREADY EXISTED.
# Line 29B at stop Leopoldau ALREADY EXISTED.
# Line N25 ALREADY EXISTED.
# Line N25 at stop Leopoldau ALREADY EXISTED.
# Line 29A ALREADY EXISTED.
# Line 29A at stop Leopoldau ALREADY EXISTED.
# run 500
# Line N25 ALREADY EXISTED.
# Line N25 at stop Leopoldau ALREADY EXISTED.
# run 501
# Line N25 ALREADY EXISTED.
# Line N25 at stop Leopoldau ALREADY EXISTED.
# run 502
# Line 510 ALREADY EXISTED.
# Line 510 at stop Leopoldau ALREADY EXISTED.
# run 503
# Line SV901 ALREADY EXISTED.
# Line SV901 at stop Leopoldau ALREADY EXISTED.
# Line 29B ALREADY EXISTED.
# Line 29B at stop Leopoldau ALREADY EXISTED.
# Line 29A ALREADY EXISTED.
# Line 29A at stop Leopoldau ALREADY EXISTED.
# run 504
# Stop Leopoldau S+U (Möllplatz) NOT FOUND in the database.
# run 505
# Line 98A ALREADY EXISTED.
# Line 98A at stop Wehrbrücklstraße/Gernotgasse ALREADY EXISTED.
# run 506
# Line N25 ALREADY EXISTED.
# Line N25 at stop Leopoldauer Platz ALREADY EXISTED.
# run 507
# Line N25 ALREADY EXISTED.
# Line N25 at stop Leopoldauer Platz ALREADY EXISTED.
# run 508
# Line 29A ALREADY EXISTED.
# Line 29A at stop Leopoldauer Platz ALREADY EXISTED.
# Line 28A ALREADY EXISTED.
# Line 28A at stop Leopoldauer Platz ALREADY EXISTED.
# run 509
# Line N25 ALREADY EXISTED.
# Line N25 at stop Leopoldauer Platz ALREADY EXISTED.
# run 510
# Line N25 ALREADY EXISTED.
# Line N25 at stop Leopoldauer Platz ALREADY EXISTED.
# run 511
# Line 29A ALREADY EXISTED.
# Line 29A at stop Leopoldauer Platz ALREADY EXISTED.
# run 512
# Line 97A ALREADY EXISTED.
# Line 97A at stop Resedaweg ALREADY EXISTED.
# run 513
# Line 31A ALREADY EXISTED.
# Line 31A at stop Leopoldauer Straße ALREADY EXISTED.
# Line 27A ALREADY EXISTED.
# Line 27A at stop Leopoldauer Straße ALREADY EXISTED.
# run 514
# Line 31A ALREADY EXISTED.
# Line 31A at stop Leopoldauer Straße ALREADY EXISTED.
# run 515
# Line 62A ALREADY EXISTED.
# Line 62A at stop Leopoldigasse ALREADY EXISTED.
# Line N65 ALREADY EXISTED.
# Line N65 at stop Leopoldigasse ALREADY EXISTED.
# run 516
# Line N65 ALREADY EXISTED.
# Line N65 at stop Leopoldigasse ALREADY EXISTED.
# run 517
# Line N65 ALREADY EXISTED.
# Line N65 at stop Leopoldigasse ALREADY EXISTED.
# run 518
# Line 60A ALREADY EXISTED.
# Line 60A at stop Leopoldigasse ALREADY EXISTED.
# run 519
# Line 62A ALREADY EXISTED.
# Line 62A at stop Leopoldigasse ALREADY EXISTED.
# Line N65 ALREADY EXISTED.
# Line N65 at stop Leopoldigasse ALREADY EXISTED.
# run 520
# Line N65 ALREADY EXISTED.
# Line N65 at stop Leopoldigasse ALREADY EXISTED.
# run 521
# Line N65 ALREADY EXISTED.
# Line N65 at stop Leopoldigasse ALREADY EXISTED.
# run 522
# Line 60A ALREADY EXISTED.
# Line 60A at stop Leopoldigasse ALREADY EXISTED.
# run 523
# Line 38A ALREADY EXISTED.
# Line 38A at stop Leopoldsberg ALREADY EXISTED.
# run 524
# Line N17 ALREADY EXISTED.
# Line N17 at stop Leopoldsdorfer Straße ALREADY EXISTED.
# Line 17A ALREADY EXISTED.
# Line 17A at stop Leopoldsdorfer Straße ALREADY EXISTED.
# run 525
# Line N17 ALREADY EXISTED.
# Line N17 at stop Leopoldsdorfer Straße ALREADY EXISTED.
# run 526
# Line N17 ALREADY EXISTED.
# Line N17 at stop Leopoldsdorfer Straße ALREADY EXISTED.
# run 527
# Line N17 ALREADY EXISTED.
# Line N17 at stop Leopoldsdorfer Straße ALREADY EXISTED.
# run 528
# Line N17 ALREADY EXISTED.
# Line N17 at stop Leopoldsdorfer Straße ALREADY EXISTED.
# run 529
# Line 70A ALREADY EXISTED.
# Line 70A at stop Leopoldsdorfer Straße ALREADY EXISTED.
# Line 266 ALREADY EXISTED.
# Line 266 at stop Leopoldsdorfer Straße ALREADY EXISTED.
# run 530
# ...
# Line 26A ALREADY EXISTED.
# Line 26A at stop Kagran ALREADY EXISTED.
# Line 93A ALREADY EXISTED.
# Line 93A at stop Kagran ALREADY EXISTED.
# Line 2 ALREADY EXISTED.
# Line 2 at stop Kagran ALREADY EXISTED.
# run 10029
# Line 26A ALREADY EXISTED.
# Line 26A at stop Kagran ALREADY EXISTED.
# Line 93A ALREADY EXISTED.
# Line 93A at stop Kagran ALREADY EXISTED.
# Line N26 ALREADY EXISTED.
# Line N26 at stop Kagran ALREADY EXISTED.
# run 10030
# Line N26 ALREADY EXISTED.
# Line N26 at stop Kagran ALREADY EXISTED.
# run 10031
# Line N26 ALREADY EXISTED.
# Line N26 at stop Kagran ALREADY EXISTED.
# run 10032
# Line N25 ALREADY EXISTED.
# Line N25 at stop Kagran ALREADY EXISTED.
# run 10033
# Line N25 ALREADY EXISTED.
# Line N25 at stop Kagran ALREADY EXISTED.
# run 10034
# Line 94A ALREADY EXISTED.
# Line 94A at stop Kagran ALREADY EXISTED.
# run 10035
# Stop Kaltenleutgebner Straße 137 NOT FOUND in the database.
# run 10036
# Stop Salvigasse NOT FOUND in the database.
# run 10037
# Stop Salvigasse NOT FOUND in the database.
# run 10038
# Line 35A ALREADY EXISTED.
# Line 35A at stop Gatterburggasse ADDED.
# Line 10A ALREADY EXISTED.
# Line 10A at stop Gatterburggasse ADDED.
# run 10039
# Line N35 ALREADY EXISTED.
# Line N35 at stop Gatterburggasse ADDED.
# run 10040
# Line N35 ALREADY EXISTED.
# Line N35 at stop Gatterburggasse ALREADY EXISTED.
# run 10041
# Line N35 ALREADY EXISTED.
# Line N35 at stop Gatterburggasse ALREADY EXISTED.
# run 10042
# Line N35 ALREADY EXISTED.
# Line N35 at stop Gatterburggasse ALREADY EXISTED.
# run 10043
# Line 38 ALREADY EXISTED.
# Line 38 at stop Gatterburggasse ADDED.
# run 10044
# Line 10A ALREADY EXISTED.
# Line 10A at stop Gatterburggasse ALREADY EXISTED.
# Line N38 ALREADY EXISTED.
# Line N38 at stop Gatterburggasse ADDED.
# run 10045
# Line N38 ALREADY EXISTED.
# Line N38 at stop Gatterburggasse ALREADY EXISTED.
# run 10046
# Line N38 ALREADY EXISTED.
# Line N38 at stop Gatterburggasse ALREADY EXISTED.
# run 10047
# Line N35 ALREADY EXISTED.
# Line N35 at stop Gatterburggasse ALREADY EXISTED.
# Line N38 ALREADY EXISTED.
# Line N38 at stop Gatterburggasse ALREADY EXISTED.
# run 10048
# Line N35 ALREADY EXISTED.
# Line N35 at stop Gatterburggasse ALREADY EXISTED.
# Line N38 ALREADY EXISTED.
# Line N38 at stop Gatterburggasse ALREADY EXISTED.
# run 10049
# Line N35 ALREADY EXISTED.
# Line N35 at stop Gatterburggasse ALREADY EXISTED.
# Line N38 ALREADY EXISTED.
# Line N38 at stop Gatterburggasse ALREADY EXISTED.
# run 10050
# Line N35 ALREADY EXISTED.
# Line N35 at stop Gatterburggasse ALREADY EXISTED.
# Line N38 ALREADY EXISTED.
# Line N38 at stop Gatterburggasse ALREADY EXISTED.
# run 10051
# Line N35 ALREADY EXISTED.
# Line N35 at stop Gatterburggasse ALREADY EXISTED.
# Line N38 ALREADY EXISTED.
# Line N38 at stop Gatterburggasse ALREADY EXISTED.
# run 10052
# Line 38 ALREADY EXISTED.
# Line 38 at stop Gatterburggasse ALREADY EXISTED.
# run 10053
# Line 69A ALREADY EXISTED.
# Line 69A at stop Gattergasse ADDED.
# run 10054
# Line 69A ALREADY EXISTED.
# Line 69A at stop Gattergasse ALREADY EXISTED.
# run 10055
# Line 63A ALREADY EXISTED.
# Line 63A at stop Gatterhölzl ADDED.
# Line 8A ALREADY EXISTED.
# Line 8A at stop Gatterhölzl ADDED.
# run 10056
# Stop Gaudenzdorfer Gürtel (Arndtstraße) NOT FOUND in the database.
# run 10057
# Line N6 ALREADY EXISTED.
# Line N6 at stop Gaudenzdorfer Gürtel ADDED.
# run 10058
# Line N6 ALREADY EXISTED.
# Line N6 at stop Gaudenzdorfer Gürtel ALREADY EXISTED.
# run 10059
# Stop Gaudenzdorfer Gürtel (Schönbrunner Str.) NOT FOUND in the database.
# run 10060
# Stop Gaudenzdorfer Gürtel (Schönbrunner Str.) NOT FOUND in the database.
# run 10061
# Stop Gaudenzdorfer Gürtel (Schönbrunner Str.) NOT FOUND in the database.
# run 10062
# Line N6 ALREADY EXISTED.
# Line N6 at stop Gaudenzdorfer Gürtel ALREADY EXISTED.
# run 10063
# Line N6 ALREADY EXISTED.
# Line N6 at stop Gaudenzdorfer Gürtel ALREADY EXISTED.
# run 10064
# Stop Gaußplatz (Wasnergasse) NOT FOUND in the database.
# run 10065
# Stop Freudenauer Hafenstr. NOT FOUND in the database.
# run 10066
# Stop Freudenauer Hafenstr. NOT FOUND in the database.
# run 10067
# Line 1 ALREADY EXISTED.
# Line 1 at stop Hetzgasse ADDED.
# run 10068
# Line 1 ALREADY EXISTED.
# Line 1 at stop Hetzgasse ALREADY EXISTED.
# run 10069
# Line N29 ALREADY EXISTED.
# Line N29 at stop Hetzgasse ADDED.
# run 10070
# Line N29 ALREADY EXISTED.
# Line N29 at stop Hetzgasse ALREADY EXISTED.
# run 10071
# Line N29 ALREADY EXISTED.
# Line N29 at stop Hetzgasse ALREADY EXISTED.
# run 10072
# Line N29 ALREADY EXISTED.
# Line N29 at stop Hetzgasse ALREADY EXISTED.
# run 10073
# Stop Heuberg NOT FOUND in the database.
# run 10074
# Stop Heuberg NOT FOUND in the database.
# run 10075
# Line 44A ALREADY EXISTED.
# Line 44A at stop Heuberggasse ADDED.
# run 10076
# Line 44A ALREADY EXISTED.
# Line 44A at stop Heuberggasse ALREADY EXISTED.
# run 10077
# Line 56A ALREADY EXISTED.
# Line 56A at stop Heudörfelgasse ADDED.
# run 10078
# Line 56A ALREADY EXISTED.
# Line 56A at stop Heudörfelgasse ALREADY EXISTED.
# run 10079
# Stop Schönbrunner Straße/Kettenbrückengasse NOT FOUND in the database.
# run 10080
# Line 93A ALREADY EXISTED.
# Line 93A at stop Husarenweg ADDED.
# Line N91 ALREADY EXISTED.
# Line N91 at stop Husarenweg ADDED.
# run 10081
# Line N91 ALREADY EXISTED.
# Line N91 at stop Husarenweg ALREADY EXISTED.
# run 10082
# Line N91 ALREADY EXISTED.
# Line N91 at stop Husarenweg ALREADY EXISTED.
# run 10083
# Line N91 ALREADY EXISTED.
# Line N91 at stop Husarenweg ALREADY EXISTED.
# run 10084
# Line N91 ALREADY EXISTED.
# Line N91 at stop Husarenweg ALREADY EXISTED.
# run 10085
# Line 93A ALREADY EXISTED.
# Line 93A at stop Husarenweg ALREADY EXISTED.
# Line N91 ALREADY EXISTED.
# Line N91 at stop Husarenweg ALREADY EXISTED.
# run 10086
# Line N91 ALREADY EXISTED.
# Line N91 at stop Husarenweg ALREADY EXISTED.
# run 10087
# Line N91 ALREADY EXISTED.
# Line N91 at stop Husarenweg ALREADY EXISTED.
# run 10088
# Line N91 ALREADY EXISTED.
# Line N91 at stop Husarenweg ALREADY EXISTED.
# run 10089
# Line N91 ALREADY EXISTED.
# Line N91 at stop Husarenweg ALREADY EXISTED.
# run 10090
# Line 50A ALREADY EXISTED.
# Line 50A at stop Hütteldorf ADDED.
# run 10091
# Line 450 ALREADY EXISTED.
# Line 450 at stop Hütteldorf ALREADY EXISTED.
# run 10092
# Line 50B ALREADY EXISTED.
# Line 50B at stop Hütteldorf ALREADY EXISTED.
# run 10093
# Line 145 ALREADY EXISTED.
# Line 145 at stop Hütteldorf ALREADY EXISTED.
# Line 451 ALREADY EXISTED.
# Line 451 at stop Hütteldorf ALREADY EXISTED.
# run 10094
# Line 50B ALREADY EXISTED.
# Line 50B at stop Hütteldorf ALREADY EXISTED.
# Line 49A ALREADY EXISTED.
# Line 49A at stop Hütteldorf ALREADY EXISTED.
# run 10095
# Line 76B ALREADY EXISTED.
# Line 76B at stop Krausegasse ADDED.
# Line 76A ALREADY EXISTED.
# Line 76A at stop Krausegasse ADDED.
# run 10096
# Line 22A ALREADY EXISTED.
# Line 22A at stop Kraygasse ADDED.
# Line N24 ALREADY EXISTED.
# Line N24 at stop Kraygasse ADDED.
# Line N23 ALREADY EXISTED.
# Line N23 at stop Kraygasse ADDED.
# Line 24A ALREADY EXISTED.
# Line 24A at stop Kraygasse ADDED.
# Line 26E ALREADY EXISTED.
# Line 26E at stop Kraygasse ADDED.
# run 10097
# Line 22A ALREADY EXISTED.
# Line 22A at stop Kraygasse ALREADY EXISTED.
# Line N24 ALREADY EXISTED.
# Line N24 at stop Kraygasse ALREADY EXISTED.
# Line N23 ALREADY EXISTED.
# Line N23 at stop Kraygasse ALREADY EXISTED.
# Line 24A ALREADY EXISTED.
# Line 24A at stop Kraygasse ALREADY EXISTED.
# Line 26E ALREADY EXISTED.
# Line 26E at stop Kraygasse ALREADY EXISTED.
# run 10098
# Line N24 ALREADY EXISTED.
# Line N24 at stop Kraygasse ALREADY EXISTED.
# Line N23 ALREADY EXISTED.
# Line N23 at stop Kraygasse ALREADY EXISTED.
# run 10099
# Line N24 ALREADY EXISTED.
# Line N24 at stop Kraygasse ALREADY EXISTED.
# Line N23 ALREADY EXISTED.
# Line N23 at stop Kraygasse ALREADY EXISTED.
# run 10100
# Line N24 ALREADY EXISTED.
# Line N24 at stop Kraygasse ALREADY EXISTED.
# Line N23 ALREADY EXISTED.
# Line N23 at stop Kraygasse ALREADY EXISTED.
# run 10101
# Line N24 ALREADY EXISTED.
# Line N24 at stop Kraygasse ALREADY EXISTED.
# Line N23 ALREADY EXISTED.
# Line N23 at stop Kraygasse ALREADY EXISTED.
# run 10102
# Line 26 ALREADY EXISTED.
# Line 26 at stop Kraygasse ADDED.
# run 10103
# Line 22A ALREADY EXISTED.
# Line 22A at stop Kraygasse ALREADY EXISTED.
# Line N24 ALREADY EXISTED.
# Line N24 at stop Kraygasse ALREADY EXISTED.
# Line N23 ALREADY EXISTED.
# Line N23 at stop Kraygasse ALREADY EXISTED.
# Line 24A ALREADY EXISTED.
# Line 24A at stop Kraygasse ALREADY EXISTED.
# run 10104
# Line N24 ALREADY EXISTED.
# Line N24 at stop Kraygasse ALREADY EXISTED.
# Line N23 ALREADY EXISTED.
# Line N23 at stop Kraygasse ALREADY EXISTED.
# run 10105
# Line N24 ALREADY EXISTED.
# Line N24 at stop Kraygasse ALREADY EXISTED.
# Line N23 ALREADY EXISTED.
# Line N23 at stop Kraygasse ALREADY EXISTED.
# run 10106
# Line N24 ALREADY EXISTED.
# Line N24 at stop Kraygasse ALREADY EXISTED.
# Line N23 ALREADY EXISTED.
# Line N23 at stop Kraygasse ALREADY EXISTED.
# run 10107
# Line N24 ALREADY EXISTED.
# Line N24 at stop Kraygasse ALREADY EXISTED.
# Line N23 ALREADY EXISTED.
# Line N23 at stop Kraygasse ALREADY EXISTED.
# run 10108
# Line 26 ALREADY EXISTED.
# Line 26 at stop Kraygasse ALREADY EXISTED.
# run 10109
# Line 5B ALREADY EXISTED.
# Line 5B at stop Kreilplatz ADDED.
# Line 38A ALREADY EXISTED.
# Line 38A at stop Kreilplatz ADDED.
# Line 400 ALREADY EXISTED.
# Line 400 at stop Kreilplatz ADDED.
# run 10110
# Line 5B ALREADY EXISTED.
# Line 5B at stop Kreilplatz ALREADY EXISTED.
# Line 38A ALREADY EXISTED.
# Line 38A at stop Kreilplatz ALREADY EXISTED.
# Line 400 ALREADY EXISTED.
# Line 400 at stop Kreilplatz ALREADY EXISTED.
# run 10111
# Line 42A ALREADY EXISTED.
# Line 42A at stop Krenngasse ADDED.
# run 10112
# Line 42A ALREADY EXISTED.
# Line 42A at stop Krenngasse ALREADY EXISTED.
# run 10113
# Stop Röntgengasse NOT FOUND in the database.
# run 10114
# Stop Röntgengasse NOT FOUND in the database.
# run 10115
# Line 95A ALREADY EXISTED.
# Line 95A at stop Podhagskygasse ADDED.
# run 10116
# Line 68B ALREADY EXISTED.
# Line 68B at stop Kronawettergasse ADDED.
# Line N68 ALREADY EXISTED.
# Line N68 at stop Kronawettergasse ADDED.
# Line 68A ALREADY EXISTED.
# Line 68A at stop Kronawettergasse ADDED.
# run 10117
# Line N68 ALREADY EXISTED.
# Line N68 at stop Kronawettergasse ALREADY EXISTED.
# run 10118
# Line N68 ALREADY EXISTED.
# Line N68 at stop Kronawettergasse ALREADY EXISTED.
# run 10119
# Line N68 ALREADY EXISTED.
# Line N68 at stop Kronawettergasse ALREADY EXISTED.
# run 10120
# Line N68 ALREADY EXISTED.
# Line N68 at stop Kronawettergasse ALREADY EXISTED.
# run 10121
# Line 68B ALREADY EXISTED.
# Line 68B at stop Kronawettergasse ALREADY EXISTED.
# Line N68 ALREADY EXISTED.
# Line N68 at stop Kronawettergasse ALREADY EXISTED.
# Line 68A ALREADY EXISTED.
# Line 68A at stop Kronawettergasse ALREADY EXISTED.
# run 10122
# Line N68 ALREADY EXISTED.
# Line N68 at stop Kronawettergasse ALREADY EXISTED.
# run 10123
# Line N68 ALREADY EXISTED.
# Line N68 at stop Kronawettergasse ALREADY EXISTED.
# run 10124
# Line N68 ALREADY EXISTED.
# Line N68 at stop Kronawettergasse ALREADY EXISTED.
# run 10125
# Line N68 ALREADY EXISTED.
# Line N68 at stop Kronawettergasse ALREADY EXISTED.
# run 10126
# Line 67B ALREADY EXISTED.
# Line 67B at stop Kronfußgasse ADDED.
# run 10127
# Line N67 ALREADY EXISTED.
# Line N67 at stop Kronfußgasse ADDED.
# Line 67B ALREADY EXISTED.
# Line 67B at stop Kronfußgasse ALREADY EXISTED.
# run 10128
# Line N67 ALREADY EXISTED.
# Line N67 at stop Kronfußgasse ALREADY EXISTED.
# run 10129
# Line N67 ALREADY EXISTED.
# Line N67 at stop Kronfußgasse ALREADY EXISTED.
# run 10130
# Stop Neulerchenfelder Straße/Haberlgasse NOT FOUND in the database.
# run 10131
# Line 2A ALREADY EXISTED.
# Line 2A at stop Habsburgergasse ADDED.
# Line 1A ALREADY EXISTED.
# Line 1A at stop Habsburgergasse ADDED.
# run 10132
# Line N49 ALREADY EXISTED.
# Line N49 at stop Beingasse ADDED.
# run 10133
# Line N49 ALREADY EXISTED.
# Line N49 at stop Beingasse ALREADY EXISTED.
# run 10134
# Line 49 ALREADY EXISTED.
# Line 49 at stop Beingasse ADDED.
# Line 9 ALREADY EXISTED.
# Line 9 at stop Beingasse ADDED.
# run 10135
# Line N49 ALREADY EXISTED.
# Line N49 at stop Beingasse ALREADY EXISTED.
# run 10136
# Line N49 ALREADY EXISTED.
# Line N49 at stop Beingasse ALREADY EXISTED.
# run 10137
# Line 49 ALREADY EXISTED.
# Line 49 at stop Beingasse ALREADY EXISTED.
# Line 9 ALREADY EXISTED.
# Line 9 at stop Beingasse ALREADY EXISTED.
# run 10138
# Line 453 ALREADY EXISTED.
# Line 453 at stop Hadersdorfer Hauptstraße ADDED.
# Line 451 ALREADY EXISTED.
# Line 451 at stop Hadersdorfer Hauptstraße ADDED.
# Line 50A ALREADY EXISTED.
# Line 50A at stop Hadersdorfer Hauptstraße ADDED.
# run 10139
# Line 453 ALREADY EXISTED.
# Line 453 at stop Hadersdorfer Hauptstraße ALREADY EXISTED.
# Line 451 ALREADY EXISTED.
# Line 451 at stop Hadersdorfer Hauptstraße ALREADY EXISTED.
# Line 50A ALREADY EXISTED.
# Line 50A at stop Hadersdorfer Hauptstraße ALREADY EXISTED.
# run 10140
# Line 451 ALREADY EXISTED.
# Line 451 at stop Hadersdorfer Hauptstraße ALREADY EXISTED.
# Line N49 ALREADY EXISTED.
# Line N49 at stop Hadersdorfer Hauptstraße ADDED.
# Line 50A ALREADY EXISTED.
# Line 50A at stop Hadersdorfer Hauptstraße ALREADY EXISTED.
# run 10141
# Line 451 ALREADY EXISTED.
# Line 451 at stop Hadersdorfer Hauptstraße ALREADY EXISTED.
# Line N49 ALREADY EXISTED.
# Line N49 at stop Hadersdorfer Hauptstraße ALREADY EXISTED.
# Line 50A ALREADY EXISTED.
# Line 50A at stop Hadersdorfer Hauptstraße ALREADY EXISTED.
# run 10142
# Line N49 ALREADY EXISTED.
# Line N49 at stop Hadersdorfer Hauptstraße ALREADY EXISTED.
# run 10143
# Line N49 ALREADY EXISTED.
# Line N49 at stop Hadersdorfer Hauptstraße ALREADY EXISTED.
# run 10144
# Stop Hadersdorf NOT FOUND in the database.
# run 10145
# Stop Hadersdorf NOT FOUND in the database.
# run 10146
# Stop Hadersdorf NOT FOUND in the database.
# run 10147
# Line 77A ALREADY EXISTED.
# Line 77A at stop Oberzellergasse ADDED.
# run 10148
# Line 71 ALREADY EXISTED.
# Line 71 at stop Oberzellergasse ADDED.
# run 10149
# Line N71 ALREADY EXISTED.
# Line N71 at stop Oberzellergasse ADDED.
# run 10150
# Line N71 ALREADY EXISTED.
# Line N71 at stop Oberzellergasse ALREADY EXISTED.
# run 10151
# Line 71 ALREADY EXISTED.
# Line 71 at stop Oberzellergasse ALREADY EXISTED.
# run 10152
# Line N71 ALREADY EXISTED.
# Line N71 at stop Oberzellergasse ALREADY EXISTED.
# run 10153
# Line N71 ALREADY EXISTED.
# Line N71 at stop Oberzellergasse ALREADY EXISTED.
# run 10154
# Line 501 ALREADY EXISTED.
# Line 501 at stop Stammersdorfer Kellergasse ADDED.
# run 10155
# Line 501 ALREADY EXISTED.
# Line 501 at stop Stammersdorfer Kellergasse ALREADY EXISTED.
# run 10156
# Line 76B ALREADY EXISTED.
# Line 76B at stop 11. Haidequerstraße ADDED.
# Line 76A ALREADY EXISTED.
# Line 76A at stop 11. Haidequerstraße ADDED.
# run 10157
# Line 76B ALREADY EXISTED.
# Line 76B at stop 11. Haidequerstraße ALREADY EXISTED.
# Line 76A ALREADY EXISTED.
# Line 76A at stop 11. Haidequerstraße ALREADY EXISTED.
# run 10158
# Line 76B ALREADY EXISTED.
# Line 76B at stop 7. Haidequerstraße ALREADY EXISTED.
# Line 76A ALREADY EXISTED.
# Line 76A at stop 7. Haidequerstraße ALREADY EXISTED.
# run 10159
# Stop Johann-Strauß-Gasse (Klagbaumg.) NOT FOUND in the database.
# run 10160
# Line 303 ALREADY EXISTED.
# Line 303 at stop Johann-Strauß-Gasse ADDED.
# Line N62 ALREADY EXISTED.
# Line N62 at stop Johann-Strauß-Gasse ADDED.
# run 10161
# Line 303 ALREADY EXISTED.
# Line 303 at stop Johann-Strauß-Gasse ALREADY EXISTED.
# Line N62 ALREADY EXISTED.
# Line N62 at stop Johann-Strauß-Gasse ALREADY EXISTED.
# run 10162
# Line N62 ALREADY EXISTED.
# Line N62 at stop Johann-Strauß-Gasse ALREADY EXISTED.
# run 10163
# Line N62 ALREADY EXISTED.
# Line N62 at stop Johann-Strauß-Gasse ALREADY EXISTED.
# run 10164
# Stop Johann-Strauß-Gasse (Lambrechtg.) NOT FOUND in the database.
# run 10165
# Line 1 ALREADY EXISTED.
# Line 1 at stop Johann-Strauß-Gasse ALREADY EXISTED.
# Line 62 ALREADY EXISTED.
# Line 62 at stop Johann-Strauß-Gasse ALREADY EXISTED.
# run 10166
# Line 303 ALREADY EXISTED.
# Line 303 at stop Johann-Strauß-Gasse ALREADY EXISTED.
# Line N62 ALREADY EXISTED.
# Line N62 at stop Johann-Strauß-Gasse ALREADY EXISTED.
# run 10167
# Line 303 ALREADY EXISTED.
# Line 303 at stop Johann-Strauß-Gasse ALREADY EXISTED.
# Line N62 ALREADY EXISTED.
# Line N62 at stop Johann-Strauß-Gasse ALREADY EXISTED.
# run 10168
# Line N62 ALREADY EXISTED.
# Line N62 at stop Johann-Strauß-Gasse ALREADY EXISTED.
# run 10169
# Line N62 ALREADY EXISTED.
# Line N62 at stop Johann-Strauß-Gasse ALREADY EXISTED.
# run 10170
# Stop Kirsteweg NOT FOUND in the database.
# run 10171
# Stop Kirsteweg NOT FOUND in the database.
# run 10172
# Stop Kirsteweg NOT FOUND in the database.
# run 10173
# Stop Kirsteweg NOT FOUND in the database.
